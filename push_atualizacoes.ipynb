# %%
import re
import requests
from urllib.parse import urljoin
import pandas as pd
import schedule
import time
from datetime import datetime, timedelta
import os
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.image import MIMEImage
from email.mime.base import MIMEBase
from email import encoders
import dotenv
from log_envios import registrar

# %% [markdown]
# *** Acesso a PoloTrial (API)

# %%
#ROTA GERAL
dotenv.load_dotenv()

session = requests.Session()

polotrial_url = os.getenv("POLOTRIAL_URL")

if not polotrial_url:
    raise ValueError("POLOTRIAL_URL não definida")

payload = {
    "nome": os.getenv("POLOTRIAL_USER"),
    "password": os.getenv("POLOTRIAL_PASSWORD")
}

headers = {
    "Content-Type": "application/json"
}

session_url = f"{polotrial_url}/sessions"

try:
    login_response = requests.post(
        session_url,
        json=payload,
        headers=headers,
        timeout=30
    )
    login_response.raise_for_status()

except Exception as e:
    raise

auth_cookie = login_response.cookies.get("userId")

if not auth_cookie:
    raise Exception("Falha na autenticação")

endpoint_headers = {
    "cookie": f"userId={auth_cookie}"
}

if endpoint_headers['cookie']:
    print(endpoint_headers)
    print(polotrial_url)
# Out:
# {'cookie': 'userId=s%3AaPFB85Di3p_4H0JeSDJv80PNWBM4gK3b.Dk%2BtllqR5Tnh0rrVc67%2FYu0YHqe2jfdZ9zm7hkwLPz0'}
# https://api.polotrial.com/beta

# %%
protocolo_url = f"{polotrial_url}/protocolo"

protocolos_ativos = [
    "161",  # Aguardando iniciação
    "39",   # Recrutamento aberto
    "9236", # Recrutamento aberto
    "9263", # Aguardando Ativação do Centro
    "393",  # Aguardando Ativação do Centro
    "9294", # Fase Contratual
    "819",  # Aguardando o Pacote Regulatório
    "739",  # Aprovação Anvisa
    "6",    # Aprovação Regulatória
    "912",  # Em apreciação ética
    "9163"  # Aprovado pelo CEP
]

df_protocolos = []

for co_status in protocolos_ativos:

    query_params = {
        "nested": "true",
        "status_protocolo": co_status
    }

    try:
        response = requests.get(
            protocolo_url,
            headers=endpoint_headers,
            params=query_params,
            timeout=30
        )

        response.raise_for_status()

        protocolo_json = response.json()

        if not protocolo_json:
            continue

        if isinstance(protocolo_json, dict):
            protocolo_json = [protocolo_json]

        df_temp = pd.DataFrame(protocolo_json)
        df_protocolos.append(df_temp)

    except Exception as e:
        print(f"Erro ao buscar protocolos para status {co_status}: {e}")

if df_protocolos:
    protocolos_dataframe = pd.concat(df_protocolos, ignore_index=True)
    print(f"DataFrame final de protocolos criado com {len(protocolos_dataframe)} registros")
else:
    print("Nenhum protocolo retornado pela API para os status consultados")
# Out:
# DataFrame final de protocolos criado com 38 registros

# %%
#ROTA PESSOAS
pessoas_url = f"{polotrial_url}/pessoas"

query_params = {
    "nested": "true",
}

try:
    response = requests.get(
        pessoas_url,
        headers=endpoint_headers,
        params=query_params,
        timeout=30
    )

    response.raise_for_status()

    pessoas = response.json()

    pessoas_df = pd.DataFrame(pessoas)

except Exception as e:
    raise

# %%
#ROTA AGENDA
agenda_url = f"{polotrial_url}/participante_visita"

query_params = {
    "nested": "true",
}

try:
    response = requests.get(
        agenda_url,
        headers=endpoint_headers,
        params=query_params,
        timeout=30
    )

    response.raise_for_status()

    agenda = response.json()

    agenda_df = pd.DataFrame(agenda)

except Exception as e:
    raise

# %%
particpantes_url = f"{polotrial_url}/participantes"

query_params = {
    "nested": "true",
}

try:
    response = requests.get(
        particpantes_url,
        headers=endpoint_headers,
        params=query_params,
        timeout=30
    )

    response.raise_for_status()

    participantes = response.json()

    if isinstance(participantes, dict):
        participantes = [participantes]

    participantes_df = pd.DataFrame(participantes)

except Exception as e:
    raise

# %%
monitoria_url = f"{polotrial_url}/agenda"

query_params = {
    "nested": "true",
}

try:
    response = requests.get(
        monitoria_url,
        headers=endpoint_headers,
        params=query_params,
        timeout=30
    )

    response.raise_for_status()

    monitoria = response.json()

    if isinstance(monitoria, dict):
        monitoria = [monitoria]

    monitoria_df = pd.DataFrame(monitoria)

except Exception as e:
    raise

# %% [markdown]
# *** Visualização e modelagem para extração de GCP (cadastros ativos)

# %%
pessoas_df.head(5)
# Out:
#             dados_ativo    id                 ds_nome  co_tipo_gn  \
# 0  {'descricao': 'Sim'}  2978                     NaN       562.0
# 1  {'descricao': 'Sim'}  3545                     NaN       562.0
# 2  {'descricao': 'Sim'}  1332                               649.0
# 3  {'descricao': 'Sim'}  3118   Alex Gonçalves Macedo       387.0
# 4  {'descricao': 'Sim'}  1554    Alex Vladimir Dudzic       649.0
#
#   co_equipe_gn  co_formacao_maior_nivel_gn dt_ultimo_certificado_gcp  \
# 0         None                         NaN                       NaN
# 1         None                         NaN                       NaN
# 2         None                         NaN                       NaN
# 3         None                        31.0                2023-09-06
# 4         None                         NaN                       NaN
#
#   registro_profissional declaracao_confidencialidade custo_mensal_estimado  \
# 0                   NaN                         None                  None
# 1                   NaN                         None                  None
# 2                   NaN                         None                  None
# 3             74.334/SP                         None                  None
# 4                   NaN                         None                  None
#
#    ...  user_id_log                                   dados_co_tipo_gn  \
# 0  ...         None  {'id': 562, 'ds_descricao': 'Equipe padrão (ad...
# 1  ...         None  {'id': 562, 'ds_descricao': 'Equipe padrão (ad...
# 2  ...         None        {'id': 649, 'ds_descricao': 'Participante'}
# 3  ...         None  {'id': 387, 'ds_descricao': 'Pesquisador Princ...
# 4  ...         None        {'id': 649, 'ds_descricao': 'Participante'}
#
#    dados_co_equipe_gn        dados_co_formacao_maior_nivel_gn  \
# 0                None                                    None
# 1                None                                    None
# 2                None                                    None
# 3                None  {'id': 31, 'ds_descricao': 'Mestrado'}
# 4                None                                    None
#
#                             dados_status  \
# 0                                   None
# 1                                   None
# 2                                   None
# 3  {'id': 9404, 'ds_descricao': 'Ativo'}
# 4                                   None
#
#                                      dados_centro  \
# 0                                            None
# 1                                            None
# 2                                            None
# 3  {'id': 4, 'descricao': 'Santa Casa de Santos'}
# 4                                            None
#
#   dados_equipe_padrao_farmacia  dados_equipe_padrao_kits  dados_equipe_padrao  \
# 0                         None                      None                 None
# 1                         None                      None                 None
# 2                         None                      None                 None
# 3                         None                      None                 None
# 4                         None                      None                 None
#
#                           dados_pessoa_especialidade
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [{'id': 150, 'co_pessoa': 3118, 'co_pessoa_esp...
# 4                                                 []
#
# [5 rows x 31 columns]

# %%
colunas = [
    'dados_centro',
    'dt_ultimo_certificado_gcp',
    'ds_nome',
    'dados_co_tipo_gn',
    'dados_status'
]

faltantes = [c for c in colunas if c not in pessoas_df.columns]
if faltantes:
    raise Exception(f"Colunas ausentes: {faltantes}")
gcp = pessoas_df[colunas].copy()

gcp.loc[:, 'dados_centro_id'] = gcp['dados_centro'].apply(lambda x: x['id'] if x is not None else None)
gcp.loc[:, 'dados_centro_descricao'] = gcp['dados_centro'].apply(lambda x: x['descricao'] if x is not None else None)
gcp.loc[:, 'tipo_gn'] = gcp['dados_co_tipo_gn'].apply(lambda x: x['ds_descricao'] if x is not None else None)
gcp.loc[:, 'status'] = gcp['dados_status'].apply(lambda x: x['ds_descricao'] if x is not None else None)

gcp_ativos = gcp.drop(['dados_centro', 'dados_centro_id', 'dados_co_tipo_gn', 'dados_status'], axis=1)
gcp_modelado = gcp_ativos[gcp_ativos['status'] == 'Ativo']

gcp_modelado.head(5)
# Out:
#     dt_ultimo_certificado_gcp                 ds_nome  \
# 3                  2023-09-06   Alex Gonçalves Macedo
# 5                         NaN   Augusto Ferreira José
# 6                         NaN        Dr. Ricardo Moro
# 374                       NaN    Adão Castelo Antônio
# 448                2025-06-26      Alessandro Vengjer
#
#                         dados_centro_descricao                tipo_gn status
# 3                         Santa Casa de Santos  Pesquisador Principal  Ativo
# 5                         Santa Casa de Santos        Subinvestigador  Ativo
# 6    Clinica de Ortopedia Campo Largo S/S LTDA  Pesquisador Principal  Ativo
# 374              Hospital Municipal de Barueri  Pesquisador Principal  Ativo
# 448                       Santa Casa de Santos  Pesquisador Principal  Ativo

# %%
venc_gcp = gcp_modelado[gcp_modelado['tipo_gn'] != 'Equipe padrão (adicionada automaticamente para todos os protocolos)']
venc_gcp["Cadastro de data"] = venc_gcp["dt_ultimo_certificado_gcp"].apply(
    lambda x: "Não há data cadastrada" if pd.isna(x) else "Data cadastrada"
)

venc_gcp.rename(columns={'dt_ultimo_certificado_gcp': 'Assinatura do GCP', 'ds_nome': 'Nome', 'dados_centro_descricao': 'Centro','tipo_gn': 'Função', 'status': 'Status do Cadastro'}, inplace=True)

nova_ordem = ['Centro', 'Nome', 'Função','Status do Cadastro', 'Assinatura do GCP', "Cadastro de data"]
venc_gcp = venc_gcp[nova_ordem]
venc_gcp = venc_gcp.sort_values(by="Centro")
venc_gcp
# Out:
#                                                  Centro  \
# 1192  A2Z Clinical Centro Avancado De Pesquisa Clini...
# 1375                              Centro Médico Sinapse
# 1285                                Centro Vila Olimpia
# 1413                      Centro de Oncologia do Paraná
# 1190                                          Clin Kids
# ...                                                 ...
# 1894                                                NaN
# 1896                                                NaN
# 2782                                                NaN
# 3272                                                NaN
# 3385                                                NaN
#
#                                           Nome                 Função  \
# 1192  Dr. Fernando Henrique de Carvalho Gouvêa          Equipe Médica
# 1375             Dr. Ricardo Moutte de Freitas  Pesquisador Principal
# 1285             Dr. Leandro Tuzuki Cavalheiro  Pesquisador Principal
# 1413                  Dr. Thadeu Tiessi Suzuki  Pesquisador Principal
# 1190                      Dr. Fernando Bedoni   Pesquisador Principal
# ...                                        ...                    ...
# 1894                            Francine Heiko        Subinvestigador
# 1896             Francine Heiko Alves Perpétuo        Subinvestigador
# 2782                            Marcelo Nagase             Financeiro
# 3272         Nathalia de Oliveira Westphalen          Subinvestigador
# 3385                          Paula Sant' Anna        Subinvestigador
#
#      Status do Cadastro Assinatura do GCP        Cadastro de data
# 1192              Ativo               NaN  Não há data cadastrada
# 1375              Ativo               NaN  Não há data cadastrada
# 1285              Ativo               NaN  Não há data cadastrada
# 1413              Ativo        2025-11-10         Data cadastrada
# 1190              Ativo               NaN  Não há data cadastrada
# ...                 ...               ...                     ...
# 1894              Ativo               NaN  Não há data cadastrada
# 1896              Ativo               NaN  Não há data cadastrada
# 2782              Ativo               NaN  Não há data cadastrada
# 3272              Ativo               NaN  Não há data cadastrada
# 3385              Ativo               NaN  Não há data cadastrada
#
# [359 rows x 6 columns]

# %%
hmcg = ['Leforte HMCG','Leforte Morumbi','Hospital Municipal de Barueri', 'Leforte Liberdade', 'Clínica CardialMed','Clínica CardialMed']
filtro1 = venc_gcp['Centro'].isin(hmcg)
venc_gcp_hmcg = venc_gcp[filtro1]
venc_gcp_hmcg=venc_gcp_hmcg.sort_values(by=['Centro', 'Nome'], ascending= [True, True])
venc_gcp_hmcg
# Out:
#                              Centro  \
# 1237             Clínica CardialMed
# 1560             Clínica CardialMed
# 2138             Clínica CardialMed
# 2226             Clínica CardialMed
# 374   Hospital Municipal de Barueri
# ...                             ...
# 1195                Leforte Morumbi
# 1562                Leforte Morumbi
# 1595                Leforte Morumbi
# 1872                Leforte Morumbi
# 3028                Leforte Morumbi
#
#                                            Nome                 Função  \
# 1237               Dr. Heron Rhydan Saad Rached  Pesquisador Principal
# 1560            Dra. Maristela Gomes de Almeida  Pesquisador Principal
# 2138                   Heron Rhydan Saad Rached  Pesquisador Principal
# 2226       Izabella Cordeiro Freire Saad Rached  Pesquisador Principal
# 374                        Adão Castelo Antônio  Pesquisador Principal
# ...                                         ...                    ...
# 1195                  Dr. Fernando Reis Menezes  Pesquisador Principal
# 1562  Dra. Mayara de Almeida Rodrigues da Costa  Pesquisador Principal
# 1595      Dra. Samantha Rodrigues Camargo Neves  Pesquisador Principal
# 1872                      Fernando Reis Menezes  Pesquisador Principal
# 3028       Mayara de Almeida Rodrigues da Costa  Pesquisador Principal
#
#      Status do Cadastro Assinatura do GCP        Cadastro de data
# 1237              Ativo               NaN  Não há data cadastrada
# 1560              Ativo               NaN  Não há data cadastrada
# 2138              Ativo               NaN  Não há data cadastrada
# 2226              Ativo               NaN  Não há data cadastrada
# 374               Ativo               NaN  Não há data cadastrada
# ...                 ...               ...                     ...
# 1195              Ativo               NaN  Não há data cadastrada
# 1562              Ativo               NaN  Não há data cadastrada
# 1595              Ativo               NaN  Não há data cadastrada
# 1872              Ativo               NaN  Não há data cadastrada
# 3028              Ativo               NaN  Não há data cadastrada
#
# [87 rows x 6 columns]

# %%
rocio = ['Maternidade e Cirurgia Nossa Senhora do Rocio SA']
filtro2 = venc_gcp['Centro'].isin(rocio)
venc_gcp_rocio = venc_gcp[filtro2]
venc_gcp_rocio=venc_gcp_rocio.sort_values(by=['Centro', 'Nome'], ascending= [True, True])
venc_gcp_rocio
# Out:
#                                                 Centro  \
# 596   Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 598   Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 747   Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 748   Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 827   Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 889   Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 968   Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 990   Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 998   Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1084  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1090  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1117  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1118  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1132  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1153  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1154  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1189  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1188  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1229  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1257  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1281  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1289  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1376  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1380  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1388  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1441  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1482  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1525  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1534  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1662  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1816  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1815  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 2492  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 2668  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 2753  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 2787  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 2788  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 3440  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 3524  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 3546  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 3620  Maternidade e Cirurgia Nossa Senhora do Rocio SA
#
#                                                    Nome  \
# 596                           Andre Luiz Santos Cerneck
# 598                                  André Ricardo Fuck
# 747                    Brenno Giovanni Hernando Vidotti
# 748                    Brenno Giovanni Hernando Vidotti
# 827                      Carlos Alberto Kenji Nakashima
# 889                     César de Oliveira Lopes Dusilek
# 968                          Dalton Luiz Rivabem Júnior
# 990               Daniele Nogueira Rodrigues dos Santos
# 998               Danillo Taiguara Ramos Gomes da Silva
# 1084                             Dr. Alvaro Viera Moura
# 1090                             Dr. André Ricardo Fuck
# 1117                      Dr. Carlos A. Kenji Nakashima
# 1118                 Dr. Carlos Alberto Kenji Nakashima
# 1132                Dr. César de Oliveira Lopes Dusilek
# 1153                     Dr. Diego Carvalho Duarte Mari
# 1154                   Dr. Diego Roberto Rolim Vaciloto
# 1189                      Dr. Felipe Fernandes Monteiro
# 1188                      Dr. Felipe Fernandes Monteiro
# 1229          Dr. Guilherme Vinicius de Andrade Barbosa
# 1257                 Dr. João Guilherme de Toledo Justo
# 1281             Dr. Leandro Cardoso Canuto Vasconcelos
# 1289                         Dr. Leonardo Ferreira Dias
# 1376                        Dr. Ricardo Nascimento Riet
# 1380                                   Dr. Ricardo Riet
# 1388                              Dr. Roberto Tauchmann
# 1441                    Dra. Amanda Pizzato da Silveira
# 1482                       Dra. Daniele Nogueira Santos
# 1525  Dra. Juliana Graziele Nogueira Rodrigues dos S...
# 1534                            Dra. Lais Prigol Ruzzon
# 1662                                  Eduardo Hummelgen
# 1816                      Fabiola Pedron Peres da Costa
# 1815                      Fabiola Pedron Peres da Costa
# 2492                                      Kengi Itinose
# 2668                     Lucas Roberto Rivabem Ferreira
# 2753                                      Maikele Ertel
# 2787                Marcelo Sávio Paiva Do Amaral Filho
# 2788                Marcelo Sávio Paiva do Amaral Filho
# 3440                            Rafael Pasini Del Claro
# 3524                            Ricardo Nascimento Riet
# 3546                                  Roberto Tauchmann
# 3620                          Rui Portes da Silva Filho
#
#                      Função Status do Cadastro Assinatura do GCP  \
# 596         Subinvestigador              Ativo        2021-09-16
# 598   Pesquisador Principal              Ativo               NaN
# 747         Subinvestigador              Ativo               NaN
# 748         Subinvestigador              Ativo               NaN
# 827         Subinvestigador              Ativo               NaN
# 889   Pesquisador Principal              Ativo               NaN
# 968   Pesquisador Principal              Ativo               NaN
# 990         Subinvestigador              Ativo               NaN
# 998   Pesquisador Principal              Ativo               NaN
# 1084        Subinvestigador              Ativo               NaN
# 1090  Pesquisador Principal              Ativo        2023-03-14
# 1117        Subinvestigador              Ativo               NaN
# 1118        Subinvestigador              Ativo               NaN
# 1132  Pesquisador Principal              Ativo               NaN
# 1153  Pesquisador Principal              Ativo        2022-09-06
# 1154        Subinvestigador              Ativo               NaN
# 1189  Pesquisador Principal              Ativo        2020-08-21
# 1188        Subinvestigador              Ativo               NaN
# 1229          Equipe Médica              Ativo        2021-09-16
# 1257        Subinvestigador              Ativo               NaN
# 1281        Subinvestigador              Ativo               NaN
# 1289        Subinvestigador              Ativo               NaN
# 1376        Subinvestigador              Ativo        2021-09-10
# 1380  Pesquisador Principal              Ativo               NaN
# 1388  Pesquisador Principal              Ativo               NaN
# 1441        Subinvestigador              Ativo        2021-06-21
# 1482        Subinvestigador              Ativo        2021-06-06
# 1525        Subinvestigador              Ativo        2021-09-16
# 1534        Subinvestigador              Ativo               NaN
# 1662  Pesquisador Principal              Ativo               NaN
# 1816        Subinvestigador              Ativo               NaN
# 1815  Pesquisador Principal              Ativo               NaN
# 2492  Pesquisador Principal              Ativo               NaN
# 2668        Subinvestigador              Ativo               NaN
# 2753        Subinvestigador              Ativo               NaN
# 2787          Equipe Médica              Ativo               NaN
# 2788        Subinvestigador              Ativo               NaN
# 3440  Pesquisador Principal              Ativo               NaN
# 3524        Subinvestigador              Ativo               NaN
# 3546  Pesquisador Principal              Ativo               NaN
# 3620        Subinvestigador              Ativo               NaN
#
#             Cadastro de data
# 596          Data cadastrada
# 598   Não há data cadastrada
# 747   Não há data cadastrada
# 748   Não há data cadastrada
# 827   Não há data cadastrada
# 889   Não há data cadastrada
# 968   Não há data cadastrada
# 990   Não há data cadastrada
# 998   Não há data cadastrada
# 1084  Não há data cadastrada
# 1090         Data cadastrada
# 1117  Não há data cadastrada
# 1118  Não há data cadastrada
# 1132  Não há data cadastrada
# 1153         Data cadastrada
# 1154  Não há data cadastrada
# 1189         Data cadastrada
# 1188  Não há data cadastrada
# 1229         Data cadastrada
# 1257  Não há data cadastrada
# 1281  Não há data cadastrada
# 1289  Não há data cadastrada
# 1376         Data cadastrada
# 1380  Não há data cadastrada
# 1388  Não há data cadastrada
# 1441         Data cadastrada
# 1482         Data cadastrada
# 1525         Data cadastrada
# 1534  Não há data cadastrada
# 1662  Não há data cadastrada
# 1816  Não há data cadastrada
# 1815  Não há data cadastrada
# 2492  Não há data cadastrada
# 2668  Não há data cadastrada
# 2753  Não há data cadastrada
# 2787  Não há data cadastrada
# 2788  Não há data cadastrada
# 3440  Não há data cadastrada
# 3524  Não há data cadastrada
# 3546  Não há data cadastrada
# 3620  Não há data cadastrada

# %%
iir_coord = ['Hospital das Clínicas de Itajubá', 'Saint-Beauté Clinique', 'Hospital Salvalus','Consultório Lopes e Sartorelli', 'Clínica Berger', 
            'QualiVida Higienópolis','Endolap Saúde' ]
filtro3 = venc_gcp['Centro'].isin(iir_coord)
venc_gcp_iir_coord = venc_gcp[filtro3] 
venc_gcp_iir_coord=venc_gcp_iir_coord.sort_values(by=['Centro', 'Nome'], ascending= [True, True])
venc_gcp_iir_coord
# Out:
#                               Centro                 Nome  \
# 1133                  Clínica Berger   Dr. Charles Berger
# 3277  Consultório Lopes e Sartorelli  Nathalia Westphalen
#
#                      Função Status do Cadastro Assinatura do GCP  \
# 1133  Pesquisador Principal              Ativo               NaN
# 3277          Equipe Médica              Ativo               NaN
#
#             Cadastro de data
# 1133  Não há data cadastrada
# 3277  Não há data cadastrada

# %%
envio_viviane = ['Otorhinus Clínica Médica', 'Unimed Brusque']
filtro4 = venc_gcp['Centro'].isin(envio_viviane)
venc_gcp_envio_viviane = venc_gcp[filtro4]
venc_gcp_envio_viviane=venc_gcp_envio_viviane.sort_values(by=['Centro', 'Nome'], ascending= [True, True])
venc_gcp_envio_viviane
# Out:
#                         Centro                                       Nome  \
# 1355  Otorhinus Clínica Médica  Dr. Rafael Leonardo Emerich Lentz Martins
# 3437  Otorhinus Clínica Médica      Rafael Leonardo Emerich Lentz Martins
# 1097            Unimed Brusque          Dr. Antonio Carlos de Mattos Roxo
# 1145            Unimed Brusque                   Dr. Daniel Rodrigo Klein
# 1180            Unimed Brusque                        Dr. Fabio Benedetti
# 1194            Unimed Brusque       Dr. Fernando Kamimoto Eckmann Helene
# 1181            Unimed Brusque              Dr. Fábio Benedetti Rodrigues
# 1230            Unimed Brusque                     Dr. Gustavo Caon Loeff
# 1244            Unimed Brusque                    Dr. Ismael Paulo Búrigo
# 1279            Unimed Brusque                         Dr. Laércio Cadore
# 1307            Unimed Brusque         Dr. Luiz Fernando Silveira Parrela
# 1327            Unimed Brusque                  Dr. Marcus Vitor Oliveira
# 1347            Unimed Brusque         Dr. Paulo Cesar de Campos Ferreira
# 1391            Unimed Brusque                   Dr. Rodrigo Kraft Rovere
# 1405            Unimed Brusque       Dr. Sebastião Dutra de Morais Júnior
# 1411            Unimed Brusque                 Dr. Sílvio Soares Nogueira
# 1423            Unimed Brusque       Dr. Victor Daniel Schiocchet Monarim
# 1446            Unimed Brusque           Dra. Ana Kris da Silva Sommariva
# 1453            Unimed Brusque    Dra. Angelica Cristina da Silva Nóbrega
# 1454            Unimed Brusque  Dra. Angelica Cristina dos Santos Nóbrega
# 1455            Unimed Brusque              Dra. Anita Silva Brunel Alves
# 1459            Unimed Brusque      Dra. Barbara Fiorentin Giordani Gamba
# 1480            Unimed Brusque                Dra. Daniela Salvador Alves
# 1499            Unimed Brusque               Dra. Fernanda Arns de Castro
# 1559            Unimed Brusque                  Dra. Marina Passos Seixas
# 1561            Unimed Brusque         Dra. Marta Amaro da Silveira Duval
# 1597            Unimed Brusque        Dra. Sura Amélia Barbosa Félix Leão
#
#                      Função Status do Cadastro Assinatura do GCP  \
# 1355  Pesquisador Principal              Ativo               NaN
# 3437  Pesquisador Principal              Ativo               NaN
# 1097  Pesquisador Principal              Ativo               NaN
# 1145  Pesquisador Principal              Ativo               NaN
# 1180  Pesquisador Principal              Ativo               NaN
# 1194  Pesquisador Principal              Ativo               NaN
# 1181  Pesquisador Principal              Ativo               NaN
# 1230  Pesquisador Principal              Ativo               NaN
# 1244  Pesquisador Principal              Ativo               NaN
# 1279  Pesquisador Principal              Ativo               NaN
# 1307  Pesquisador Principal              Ativo               NaN
# 1327  Pesquisador Principal              Ativo               NaN
# 1347  Pesquisador Principal              Ativo               NaN
# 1391  Pesquisador Principal              Ativo               NaN
# 1405  Pesquisador Principal              Ativo               NaN
# 1411  Pesquisador Principal              Ativo               NaN
# 1423  Pesquisador Principal              Ativo               NaN
# 1446  Pesquisador Principal              Ativo               NaN
# 1453  Pesquisador Principal              Ativo               NaN
# 1454  Pesquisador Principal              Ativo               NaN
# 1455  Pesquisador Principal              Ativo               NaN
# 1459  Pesquisador Principal              Ativo               NaN
# 1480  Pesquisador Principal              Ativo               NaN
# 1499  Pesquisador Principal              Ativo               NaN
# 1559  Pesquisador Principal              Ativo               NaN
# 1561  Pesquisador Principal              Ativo               NaN
# 1597  Pesquisador Principal              Ativo               NaN
#
#             Cadastro de data
# 1355  Não há data cadastrada
# 3437  Não há data cadastrada
# 1097  Não há data cadastrada
# 1145  Não há data cadastrada
# 1180  Não há data cadastrada
# 1194  Não há data cadastrada
# 1181  Não há data cadastrada
# 1230  Não há data cadastrada
# 1244  Não há data cadastrada
# 1279  Não há data cadastrada
# 1307  Não há data cadastrada
# 1327  Não há data cadastrada
# 1347  Não há data cadastrada
# 1391  Não há data cadastrada
# 1405  Não há data cadastrada
# 1411  Não há data cadastrada
# 1423  Não há data cadastrada
# 1446  Não há data cadastrada
# 1453  Não há data cadastrada
# 1454  Não há data cadastrada
# 1455  Não há data cadastrada
# 1459  Não há data cadastrada
# 1480  Não há data cadastrada
# 1499  Não há data cadastrada
# 1559  Não há data cadastrada
# 1561  Não há data cadastrada
# 1597  Não há data cadastrada

# %%
stacasa_santos = ['Santa Casa de Santos']
filtro5 = venc_gcp['Centro'].isin(stacasa_santos)
venc_gcp_stacasa_santos = venc_gcp[filtro5]
venc_gcp_stacasa_santos=venc_gcp_stacasa_santos.sort_values(by=['Centro', 'Nome'], ascending= [True, True])
venc_gcp_stacasa_santos
# Out:
#                     Centro                             Nome  \
# 3     Santa Casa de Santos            Alex Gonçalves Macedo
# 5     Santa Casa de Santos            Augusto Ferreira José
# 448   Santa Casa de Santos               Alessandro Vengjer
# 583   Santa Casa de Santos     André Galante Alencar Aranha
# 585   Santa Casa de Santos  André Gustavo Pereira Magalhães
# ...                    ...                              ...
# 3544  Santa Casa de Santos              Roberto Higa Junior
# 3634  Santa Casa de Santos        Samuel Brunini Petrarolha
# 3635  Santa Casa de Santos        Samuel Brunini Petrarolha
# 3939  Santa Casa de Santos                Vitor Hugo Straub
# 3940  Santa Casa de Santos       Vitor Hugo Straub Canasiro
#
#                      Função Status do Cadastro Assinatura do GCP  \
# 3     Pesquisador Principal              Ativo        2023-09-06
# 5           Subinvestigador              Ativo               NaN
# 448   Pesquisador Principal              Ativo        2025-06-26
# 583   Pesquisador Principal              Ativo        2021-09-23
# 585         Subinvestigador              Ativo               NaN
# ...                     ...                ...               ...
# 3544        Subinvestigador              Ativo               NaN
# 3634  Pesquisador Principal              Ativo               NaN
# 3635  Pesquisador Principal              Ativo               NaN
# 3939  Pesquisador Principal              Ativo               NaN
# 3940  Pesquisador Principal              Ativo               NaN
#
#             Cadastro de data
# 3            Data cadastrada
# 5     Não há data cadastrada
# 448          Data cadastrada
# 583          Data cadastrada
# 585   Não há data cadastrada
# ...                      ...
# 3544  Não há data cadastrada
# 3634  Não há data cadastrada
# 3635  Não há data cadastrada
# 3939  Não há data cadastrada
# 3940  Não há data cadastrada
#
# [114 rows x 6 columns]

# %%
capibaribe = ['Hospital do Capibaribe']
filtro6 = venc_gcp['Centro'].isin(capibaribe)
venc_gcp_capibaribe = venc_gcp[filtro6]
venc_gcp_capibaribe=venc_gcp_capibaribe.sort_values(by=['Centro', 'Nome'], ascending= [True, True])
venc_gcp_capibaribe
# Out:
#                       Centro                                      Nome  \
# 1252  Hospital do Capibaribe              Dr. Jayme José Gouveia Filho
# 1557  Hospital do Capibaribe  Dra. Mariane Teodoro Fernandes Rodrigues
# 2942  Hospital do Capibaribe       Mariane Teodoro Fernandes Rodrigues
#
#                      Função Status do Cadastro Assinatura do GCP  \
# 1252          Equipe Médica              Ativo        2024-09-23
# 1557  Pesquisador Principal              Ativo        2024-06-14
# 2942  Pesquisador Principal              Ativo               NaN
#
#             Cadastro de data
# 1252         Data cadastrada
# 1557         Data cadastrada
# 2942  Não há data cadastrada

# %% [markdown]
# ***Função para cálculo da data de vencimento de GCP.

# %%
def verificar_vencimento_contratos(df_contratos, nome_centro, dias_para_vencimento=30):

    if df_contratos.empty:
        return df_contratos

    df_contratos = df_contratos.copy()

    df_contratos['Assinatura do GCP'] = pd.to_datetime(
        df_contratos['Assinatura do GCP'],
        errors='coerce'
    )

    hoje = datetime.today()
    limite_vencimento = hoje + timedelta(days=dias_para_vencimento)

    df_contratos['data_vencimento'] = (
        df_contratos['Assinatura do GCP'] + timedelta(days=2 * 365)
    )

    filtro_vencendo = (
        (df_contratos['data_vencimento'] > hoje) &
        (df_contratos['data_vencimento'] <= limite_vencimento)
    )

    filtro_sem_data = df_contratos['Assinatura do GCP'].isna()

    contratos_relevantes = df_contratos[filtro_vencendo | filtro_sem_data]

    return contratos_relevantes

# %%
contratos_hmcg = verificar_vencimento_contratos(venc_gcp_hmcg, "HMCG", dias_para_vencimento=30)
contratos_rocio = verificar_vencimento_contratos(venc_gcp_rocio, "Rocío", dias_para_vencimento=30)
contratos_iir_coord = verificar_vencimento_contratos(venc_gcp_iir_coord, "IRR COORD", dias_para_vencimento=30)
contratos_vivi = verificar_vencimento_contratos(venc_gcp_envio_viviane, "Envio Viviane", dias_para_vencimento=30)
contratos_stacsantos = verificar_vencimento_contratos(venc_gcp_stacasa_santos, "Santa Casa de Santos", dias_para_vencimento=30)
contratos_capibaribe = verificar_vencimento_contratos(venc_gcp_capibaribe, "Capibaribe", dias_para_vencimento=30)

# %% [markdown]
# ***Função para envio dos emails de GCP

# %%
css_hover = """
<style>
/* Reset e fonte */
body, table, td, th, p {
    font-family: Arial, Helvetica, sans-serif;
    margin: 0;
    padding: 0;
}

/* Container do email */
.email-wrapper {
    background-color: #f4f6f4;
    padding: 24px;
}

/* Card principal */
.email-card {
    background-color: #ffffff;
    border-radius: 8px;
    padding: 28px 32px;
    max-width: 680px;
    margin: 0 auto;
    border: 1px solid #dde8d4;
}

/* Cabeçalho */
.email-header {
    border-bottom: 1px solid #dde8d4;
    padding-bottom: 16px;
    margin-bottom: 20px;
}

.email-header h2 {
    font-size: 17px;
    font-weight: 600;
    color: #1a2e1a;
    margin: 0 0 4px;
}

.email-header p {
    font-size: 12px;
    color: #6b7b6b;
    margin: 0;
}

/* Texto do corpo */
.email-body p {
    font-size: 14px;
    color: #3a4a3a;
    margin: 0 0 14px;
    line-height: 1.5;
}

/* Tabela */
table {
    border-collapse: collapse;
    width: 100%;
    font-size: 13px;
    margin-bottom: 24px;
}

th {
    background-color: #3B6D11;
    color: #ffffff;
    padding: 10px 12px;
    text-align: left;
    font-weight: 500;
    font-size: 12px;
    letter-spacing: 0.03em;
    border: none;
}

td {
    padding: 10px 12px;
    border-bottom: 1px solid #dde8d4;
    color: #1a1a1a;
    vertical-align: middle;
    text-align: left;
}

tr:nth-child(even) td {
    background-color: #f4f8f0;
}

tr:nth-child(odd) td {
    background-color: #ffffff;
}

/* Hover (funciona em Gmail/Web, ignorado no Outlook) */
tr:hover td {
    background-color: #e8f2de;
}

/* Rodapé */
.email-footer {
    border-top: 1px solid #dde8d4;
    padding-top: 16px;
    margin-top: 8px;
}

.email-footer p {
    font-size: 12px;
    color: #6b7b6b;
    margin: 0 0 4px;
    line-height: 1.5;
}

.email-footer strong {
    color: #3a4a3a;
}

/* Responsividade */
@media screen and (max-width: 600px) {
    .email-card { padding: 16px; }
    table { font-size: 12px; }
    th, td { padding: 8px; }
}
</style>
"""

# %% [markdown]
# Variáveis de envio de email

# %%
smtp_server   = os.getenv("EMAIL_SERVER")
email_port    = int(os.getenv("EMAIL_PORT", "587").strip())
email_usuario = os.getenv("EMAIL_USERNAME")
email_senha   = os.getenv("EMAIL_PASSWORD")

# Destinatários GCP
enviar_para          = os.getenv("ENVIAR_PARA", "")
destinatario_hmcg    = os.getenv("DESTINATARIO_HMCG", "")
destinatario_rocio   = os.getenv("DESTINATARIO_ROCIO", "")
destinatario_scs     = os.getenv("DESTINATARIO_SCS", "")
destinatario_iir     = os.getenv("DESTINATARIO_IIR", "")
destinatario_vivi    = os.getenv("DESTINATARIO_VIVIANE", "")
destinatario_capibaribe = os.getenv("DESTINATARIO_CAPIBARIBE", "")

# Destinatário monitoria
envio_para = os.getenv("ENVIO_PARA", "")

# Validação das variáveis obrigatórias de SMTP
_vars_obrigatorias = {
    "EMAIL_SERVER": smtp_server,
    "EMAIL_USERNAME": email_usuario,
    "EMAIL_PASSWORD": email_senha,
}
_faltando = [k for k, v in _vars_obrigatorias.items() if not v]
if _faltando:
    raise ValueError(f"Variáveis ausentes no .env: {_faltando}")

def _parse_destinatarios(valor):
    """Converte string 'a@b.com,c@d.com' em lista de emails válidos."""
    email_regex = r'^[\w\.-]+@[\w\.-]+\.\w+$'
    if not valor:
        return []
    emails = [e.strip() for e in valor.split(",") if e.strip()]
    validos = [e for e in emails if re.match(email_regex, e)]
    invalidos = set(emails) - set(validos)
    if invalidos:
        print(f"Emails ignorados por formato inválido: {invalidos}")
    return validos

# %%
def enviar_email(destinatarios, df_tratado, nome_grupo):

    if df_tratado is None or df_tratado.empty:
        registrar("Push Campo", nome_grupo, "PULADO", observacao="Sem registros")
        return

    try:
        if isinstance(destinatarios, str):
            destinatarios = _parse_destinatarios(destinatarios)
        else:
            destinatarios = _parse_destinatarios(", ".join([d for d in destinatarios if d]))

        if not destinatarios:
            registrar("Push Campo", nome_grupo, "PULADO", observacao="Nenhum destinatário válido")
            return

        colunas = [
            'Centro',
            'Nome',
            'Função',
            'Status do Cadastro',
            'Assinatura do GCP',
            'Cadastro de data'
        ]

        tabela_html = df_tratado[colunas].to_html(
            index=False,
            escape=False,
            border=0,
            justify="left",
            classes="table"
        )

        msg = MIMEMultipart("alternative")
        msg["From"]    = email_usuario
        msg["To"]      = email_usuario
        msg["Bcc"]     = ", ".join(destinatarios)
        msg["Subject"] = f"[{nome_grupo}] GCP sem data registrada ou com vencimento próximo"

        body = f"""
        <html>
            <head>{css_hover}</head>
            <body>
                <div class="email-wrapper">
                    <div class="email-card">
                        <div class="email-header">
                            <h2>Vencimento de GCP &mdash; {nome_grupo}</h2>
                            <p>GCP sem data registrada ou com vencimento próximo</p>
                        </div>
                        <div class="email-body">
                            <p>Bom dia,</p>
                            <p>Segue abaixo relação de GCPs que não possuem data registrada
                            no sistema ou que apresentam vencimento próximo:</p>
                        </div>
                        {tabela_html}
                        <div class="email-footer">
                            <p>Este e-mail é gerado automaticamente a partir de informações inseridas na <strong>Polo Trial</strong>.</p>
                            <p>Qualquer dúvida, contate o <strong>time BI - SVRI</strong>.</p>
                        </div>
                    </div>
                </div>
            </body>
        </html>
        """

        msg.attach(MIMEText(body, "html"))

        destinatarios_finais = [email_usuario] + destinatarios
        with smtplib.SMTP(smtp_server, email_port) as server:
            server.starttls()
            server.login(email_usuario, email_senha)
            server.sendmail(email_usuario, destinatarios_finais, msg.as_string())

        registrar(
            projeto="Push Campo",
            grupo=nome_grupo,
            status="ENVIADO",
            destinatarios=destinatarios_finais,
            num_registros=len(df_tratado),
        )

    except Exception as e:
        registrar("Push Campo", nome_grupo, "ERRO", observacao=str(e))
        print(f"{nome_grupo}: erro ao enviar email -> {str(e)}")

# %%
enviar_email([destinatario_hmcg], contratos_hmcg, "HMCG")
enviar_email([destinatario_rocio], contratos_rocio, "Rocio")
enviar_email([destinatario_iir], contratos_iir_coord, "IIR")
enviar_email([destinatario_scs], contratos_stacsantos, "Sta. Santos")
enviar_email([destinatario_vivi], contratos_vivi, "Viviane")
enviar_email([destinatario_capibaribe], contratos_capibaribe, "Capibaribe")

# %% [markdown]
# ***Modelagem para envio de Visitas de Seguimento

# %%
protocolo = pd.DataFrame(protocolos_dataframe)
protocolo.head(5)
# Out:
#      id                                   titulo_protocolo cor_agenda  \
# 0  2305  Ensaio de plataforma de fase 2 para avaliar a ...    #d93f3f
# 1   234  Um estudo multicêntrico, randomizado e aberto ...    #25a2c1
# 2   468  Um estudo de Fase 3, prospectivo, randomizado,...    #cd4b13
# 3   655  Um ensaio de fase III, duplo-cego, randomizado...    #01d3ef
# 4   784  Um estudo randomizado, duplo-cego, controlado ...    #000000
#
#    numero_protocolo        apelido_protocolo  coordenador    pi  \
# 0        SPY123-201  SKYLINE-UC (SPY123-201)       2622.0  2384
# 1          20190341           Code Break 202       2622.0   280
# 2      TAK-330-3001             TAK-330-3001       2622.0  3136
# 3         1378-0020      EASi-HF - 1378-0020       2508.0   256
# 4  LX4211.1-314-HCM               SONATA-HCM       2829.0   271
#
#   pesquisador_backup  co_pessoa_regulatorio             data_cadastro  ...  \
# 0               None                 2631.0  2025-02-20T14:20:48.000Z  ...
# 1             2829.0                  214.0  2022-05-26T09:12:12.000Z  ...
# 2                NaN                  214.0  2023-04-05T11:13:09.000Z  ...
# 3              239.0                 2807.0  2023-06-12T10:16:37.000Z  ...
# 4                NaN                 4618.0  2023-07-17T10:14:16.000Z  ...
#
#                 dados_medicamento_do_estudo  \
# 0                                      None
# 1                                      None
# 2  {'id': 9311, 'ds_descricao': 'OCTAPLEX'}
# 3                                      None
# 4                                      None
#
#         dados_pendencias_regulatorio  \
# 0                               None
# 1  {'id': 41, 'ds_descricao': 'Não'}
# 2  {'id': 41, 'ds_descricao': 'Não'}
# 3  {'id': 40, 'ds_descricao': 'Sim'}
# 4  {'id': 40, 'ds_descricao': 'Sim'}
#
#                     dados_status_feasibility  \
# 0  {'id': 824, 'ds_descricao': 'Respondido'}
# 1  {'id': 824, 'ds_descricao': 'Respondido'}
# 2  {'id': 824, 'ds_descricao': 'Respondido'}
# 3  {'id': 824, 'ds_descricao': 'Respondido'}
# 4  {'id': 824, 'ds_descricao': 'Respondido'}
#
#                                dados_status_contrato  \
# 0        {'id': 903, 'ds_descricao': 'Não recebido'}
# 1            {'id': 908, 'ds_descricao': 'Assinado'}
# 2            {'id': 908, 'ds_descricao': 'Assinado'}
# 3            {'id': 908, 'ds_descricao': 'Assinado'}
# 4  {'id': 9, 'ds_descricao': 'Em negociação com o...
#
#                               dados_status_orcamento  \
# 0  {'id': 9171, 'ds_descricao': 'Aguardando envio '}
# 1            {'id': 877, 'ds_descricao': 'Aprovado'}
# 2            {'id': 877, 'ds_descricao': 'Aprovado'}
# 3            {'id': 877, 'ds_descricao': 'Aprovado'}
# 4                                               None
#
#                            dados_status_regulatorio  \
# 0  {'id': 918, 'ds_descricao': 'Em análise do CEP'}
# 1           {'id': 914, 'ds_descricao': 'Aprovado'}
# 2           {'id': 914, 'ds_descricao': 'Aprovado'}
# 3           {'id': 914, 'ds_descricao': 'Aprovado'}
# 4           {'id': 914, 'ds_descricao': 'Aprovado'}
#
#                            dados_status_recrutamento  \
# 0                                               None
# 1  {'id': 936, 'ds_descricao': 'Recrutamento aber...
# 2  {'id': 936, 'ds_descricao': 'Recrutamento aber...
# 3  {'id': 936, 'ds_descricao': 'Recrutamento aber...
# 4                                               None
#
#                     dados_status_financeiro  dados_assistente_de_pesquisa  \
# 0                                      None                          None
# 1                                      None                          None
# 2  {'id': 9279, 'ds_descricao': 'Aprovado'}                          None
# 3  {'id': 9279, 'ds_descricao': 'Aprovado'}                          None
# 4                                      None                          None
#
#              dados_dificuldade_recrutamento
# 0   {'id': 9291, 'ds_descricao': 'Difícil'}
# 1   {'id': 9291, 'ds_descricao': 'Difícil'}
# 2  {'id': 9292, 'ds_descricao': 'Moderado'}
# 3  {'id': 9292, 'ds_descricao': 'Moderado'}
# 4  {'id': 9292, 'ds_descricao': 'Moderado'}
#
# [5 rows x 141 columns]

# %%
centros = protocolo[['id','apelido_protocolo', 'numero_protocolo','co_externo','apelido_centro']].copy()
centros.head(5)
# Out:
#      id        apelido_protocolo  numero_protocolo        co_externo  \
# 0  2305  SKYLINE-UC (SPY123-201)        SPY123-201        SPY123-201
# 1   234           Code Break 202          20190341          20190341
# 2   468             TAK-330-3001      TAK-330-3001      TAK 330-3001
# 3   655      EASi-HF - 1378-0020         1378-0020           EASI HF
# 4   784               SONATA-HCM  LX4211.1-314-HCM  LX4211.1-314-HCM
#
#                                       apelido_centro
# 0     SKYLINE-UC (SPY123-201) - Santa Casa de Santos
# 1              Code Break 202 - Santa Casa de Santos
# 2                TAK-330-3001 - Santa Casa de Santos
# 3  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 4                    SONATA-HCM - Clínica CardialMed

# %%
seguimento = agenda_df[['dados_participante', 'data_estimada', 'dados_status', 'dados_visita']].copy()

seguimento.loc[:, 'dados_participante_id'] = seguimento['dados_participante'].apply(lambda x: x['id'] if x is not None else None)
seguimento.loc[:, 'id_participante'] = seguimento['dados_participante'].apply(lambda x: x['id_participante'] if x is not None else None)
seguimento.loc[:, 'dados_protocolo'] = seguimento['dados_participante'].apply(lambda x: x['dados_protocolo'] if x is not None else None)

seguimento.loc[:, 'dados_status_id'] = seguimento['dados_status'].apply(lambda x: x['id'] if x is not None else None)
seguimento.loc[:, 'ds_descricao'] = seguimento['dados_status'].apply(lambda x: x['ds_descricao'] if x is not None else None)
seguimento.loc[:, 'ds_nome_visita'] = seguimento['dados_visita'].apply(lambda x: x['ds_nome_visita'] if x is not None else None)

seguimento.loc[:, 'apelido_protocolo'] = seguimento['dados_protocolo'].apply(lambda x: x['apelido_protocolo'] if x is not None else None)
seguimento['data_estimada'] = pd.to_datetime(seguimento['data_estimada'], errors='coerce')
seguimento.head(5)
# Out:
#                                   dados_participante  \
# 0  {'id': 1706, 'co_protocolo': 105, 'id_particip...
# 1  {'id': 1707, 'co_protocolo': 105, 'id_particip...
# 2  {'id': 1708, 'co_protocolo': 105, 'id_particip...
# 3  {'id': 1709, 'co_protocolo': 105, 'id_particip...
# 4  {'id': 1706, 'co_protocolo': 105, 'id_particip...
#
#               data_estimada                             dados_status  \
# 0 2019-06-10 00:00:00+00:00  {'id': 20, 'ds_descricao': 'Realizada'}
# 1 2019-06-17 00:00:00+00:00  {'id': 20, 'ds_descricao': 'Realizada'}
# 2 2019-06-18 00:00:00+00:00  {'id': 20, 'ds_descricao': 'Realizada'}
# 3 2019-05-15 00:00:00+00:00  {'id': 20, 'ds_descricao': 'Realizada'}
# 4 2019-06-03 00:00:00+00:00  {'id': 20, 'ds_descricao': 'Realizada'}
#
#                                         dados_visita  dados_participante_id  \
# 0  {'id': 588, 'ds_nome_visita': ' S1', 'co_exter...                   1706
# 1  {'id': 588, 'ds_nome_visita': ' S1', 'co_exter...                   1707
# 2  {'id': 588, 'ds_nome_visita': ' S1', 'co_exter...                   1708
# 3  {'id': 588, 'ds_nome_visita': ' S1', 'co_exter...                   1709
# 4  {'id': 589, 'ds_nome_visita': 'S2', 'co_extern...                   1706
#
#   id_participante                                    dados_protocolo  \
# 0      4308053001  {'id': 105, 'apelido_protocolo': 'CLEAR Santa ...
# 1      4308054002  {'id': 105, 'apelido_protocolo': 'CLEAR Santa ...
# 2      4308054003  {'id': 105, 'apelido_protocolo': 'CLEAR Santa ...
# 3      4308053004  {'id': 105, 'apelido_protocolo': 'CLEAR Santa ...
# 4      4308053001  {'id': 105, 'apelido_protocolo': 'CLEAR Santa ...
#
#    dados_status_id ds_descricao ds_nome_visita apelido_protocolo
# 0               20    Realizada             S1  CLEAR Santa Casa
# 1               20    Realizada             S1  CLEAR Santa Casa
# 2               20    Realizada             S1  CLEAR Santa Casa
# 3               20    Realizada             S1  CLEAR Santa Casa
# 4               20    Realizada             S2  CLEAR Santa Casa

# %%
seguimento_tratado = seguimento.drop(['dados_participante','dados_status','id_participante','dados_status_id'], axis=1)
seguimento_tratado.loc[:, 'id'] = seguimento['dados_protocolo'].apply(lambda x: x['id'] if x is not None else None)
seguimento_tratado.head(5)
# Out:
#               data_estimada  \
# 0 2019-06-10 00:00:00+00:00
# 1 2019-06-17 00:00:00+00:00
# 2 2019-06-18 00:00:00+00:00
# 3 2019-05-15 00:00:00+00:00
# 4 2019-06-03 00:00:00+00:00
#
#                                         dados_visita  dados_participante_id  \
# 0  {'id': 588, 'ds_nome_visita': ' S1', 'co_exter...                   1706
# 1  {'id': 588, 'ds_nome_visita': ' S1', 'co_exter...                   1707
# 2  {'id': 588, 'ds_nome_visita': ' S1', 'co_exter...                   1708
# 3  {'id': 588, 'ds_nome_visita': ' S1', 'co_exter...                   1709
# 4  {'id': 589, 'ds_nome_visita': 'S2', 'co_extern...                   1706
#
#                                      dados_protocolo ds_descricao  \
# 0  {'id': 105, 'apelido_protocolo': 'CLEAR Santa ...    Realizada
# 1  {'id': 105, 'apelido_protocolo': 'CLEAR Santa ...    Realizada
# 2  {'id': 105, 'apelido_protocolo': 'CLEAR Santa ...    Realizada
# 3  {'id': 105, 'apelido_protocolo': 'CLEAR Santa ...    Realizada
# 4  {'id': 105, 'apelido_protocolo': 'CLEAR Santa ...    Realizada
#
#   ds_nome_visita apelido_protocolo   id
# 0             S1  CLEAR Santa Casa  105
# 1             S1  CLEAR Santa Casa  105
# 2             S1  CLEAR Santa Casa  105
# 3             S1  CLEAR Santa Casa  105
# 4             S2  CLEAR Santa Casa  105

# %%
seguimentos = pd.merge(centros, seguimento_tratado, on='id', how='inner')
seguimentos
# Out:
#         id apelido_protocolo_x numero_protocolo co_externo  \
# 0      234      Code Break 202         20190341   20190341
# 1      234      Code Break 202         20190341   20190341
# 2      234      Code Break 202         20190341   20190341
# 3      234      Code Break 202         20190341   20190341
# 4      234      Code Break 202         20190341   20190341
# ...    ...                 ...              ...        ...
# 1249  2651         Oxandrolona                         NaN
# 1250  2651         Oxandrolona                         NaN
# 1251  2651         Oxandrolona                         NaN
# 1252  2651         Oxandrolona                         NaN
# 1253  2651         Oxandrolona                         NaN
#
#                                    apelido_centro             data_estimada  \
# 0           Code Break 202 - Santa Casa de Santos 2024-12-03 00:00:00+00:00
# 1           Code Break 202 - Santa Casa de Santos 2024-12-09 00:00:00+00:00
# 2           Code Break 202 - Santa Casa de Santos 2025-04-29 00:00:00+00:00
# 3           Code Break 202 - Santa Casa de Santos 2025-05-06 00:00:00+00:00
# 4           Code Break 202 - Santa Casa de Santos 2025-11-24 00:00:00+00:00
# ...                                           ...                       ...
# 1249  Oxandrolona - Centro de Oncologia do Paraná                       NaT
# 1250  Oxandrolona - Centro de Oncologia do Paraná                       NaT
# 1251  Oxandrolona - Centro de Oncologia do Paraná                       NaT
# 1252  Oxandrolona - Centro de Oncologia do Paraná                       NaT
# 1253  Oxandrolona - Centro de Oncologia do Paraná                       NaT
#
#                                            dados_visita  \
# 0     {'id': 2435, 'ds_nome_visita': 'Pré-Triagem co...
# 1     {'id': 2435, 'ds_nome_visita': 'Pré-Triagem co...
# 2     {'id': 2435, 'ds_nome_visita': 'Pré-Triagem co...
# 3     {'id': 2249, 'ds_nome_visita': 'Pré-Triagem co...
# 4     {'id': 2435, 'ds_nome_visita': 'Pré-Triagem co...
# ...                                                 ...
# 1249  {'id': 3992, 'ds_nome_visita': 'Não Programada...
# 1250  {'id': 3997, 'ds_nome_visita': 'VR/V2', 'co_ex...
# 1251  {'id': 3998, 'ds_nome_visita': 'Data da Cirurg...
# 1252  {'id': 3992, 'ds_nome_visita': 'Não Programada...
# 1253  {'id': 3992, 'ds_nome_visita': 'Não Programada...
#
#       dados_participante_id  \
# 0                      2944
# 1                      2950
# 2                      3041
# 3                      3042
# 4                      3272
# ...                     ...
# 1249                   3396
# 1250                   3401
# 1251                   3401
# 1252                   3404
# 1253                   3405
#
#                                         dados_protocolo ds_descricao  \
# 0     {'id': 234, 'apelido_protocolo': 'Code Break 2...    Realizada
# 1     {'id': 234, 'apelido_protocolo': 'Code Break 2...    Realizada
# 2     {'id': 234, 'apelido_protocolo': 'Code Break 2...    Realizada
# 3     {'id': 234, 'apelido_protocolo': 'Code Break 2...    Realizada
# 4     {'id': 234, 'apelido_protocolo': 'Code Break 2...    Realizada
# ...                                                 ...          ...
# 1249  {'id': 2651, 'apelido_protocolo': 'Oxandrolona...     Pendente
# 1250  {'id': 2651, 'apelido_protocolo': 'Oxandrolona...     Pendente
# 1251  {'id': 2651, 'apelido_protocolo': 'Oxandrolona...     Pendente
# 1252  {'id': 2651, 'apelido_protocolo': 'Oxandrolona...     Pendente
# 1253  {'id': 2651, 'apelido_protocolo': 'Oxandrolona...     Pendente
#
#                                          ds_nome_visita apelido_protocolo_y
# 0     Pré-Triagem com tecido de arquivo para PD-L1 I...      Code Break 202
# 1     Pré-Triagem com tecido de arquivo para PD-L1 I...      Code Break 202
# 2     Pré-Triagem com tecido de arquivo para PD-L1 I...      Code Break 202
# 3     Pré-Triagem com biópsia nova para PD-L1 IHC e ...      Code Break 202
# 4     Pré-Triagem com tecido de arquivo para PD-L1 I...      Code Break 202
# ...                                                 ...                 ...
# 1249                                     Não Programada         Oxandrolona
# 1250                                              VR/V2         Oxandrolona
# 1251                            Data da Cirurgia de LCA         Oxandrolona
# 1252                                     Não Programada         Oxandrolona
# 1253                                     Não Programada         Oxandrolona
#
# [1254 rows x 12 columns]

# %%
seguimentos['apelido_protocolo_x'] = seguimentos['apelido_protocolo_x'].str.strip()
visitas_filtrado = seguimentos[seguimentos['ds_descricao'].str.contains('Pendente')]
nova_ordem = ["apelido_centro", "dados_participante_id", "ds_nome_visita","data_estimada","ds_descricao"]
visitas_reordenado = visitas_filtrado[nova_ordem].rename(
    columns={
        'apelido_centro':'Estudo/Centro',
        'dados_participante_id': 'ID Participante',
        'ds_nome_visita': 'Tipo Visita',
        'data_estimada':'Data Estimada',
        'ds_descricao':'Status'
    }
)
visitas_reordenado['Data Estimada'] = pd.to_datetime(visitas_reordenado['Data Estimada'], errors='coerce')
visitas_reordenado
# Out:
#                                     Estudo/Centro  ID Participante  \
# 8           Code Break 202 - Santa Casa de Santos             3377
# 9           Code Break 202 - Santa Casa de Santos             3377
# 10          Code Break 202 - Santa Casa de Santos             3377
# 11          Code Break 202 - Santa Casa de Santos             3377
# 12          Code Break 202 - Santa Casa de Santos             3377
# ...                                           ...              ...
# 1249  Oxandrolona - Centro de Oncologia do Paraná             3396
# 1250  Oxandrolona - Centro de Oncologia do Paraná             3401
# 1251  Oxandrolona - Centro de Oncologia do Paraná             3401
# 1252  Oxandrolona - Centro de Oncologia do Paraná             3404
# 1253  Oxandrolona - Centro de Oncologia do Paraná             3405
#
#                                             Tipo Visita Data Estimada  \
# 8                           Particularidades Financeiro           NaT
# 9                                     Unscheduled Visit           NaT
# 10    Pré-Triagem com biópsia nova para PD-L1 IHC e ...           NaT
# 11                                              Triagem           NaT
# 12                                                  SFU           NaT
# ...                                                 ...           ...
# 1249                                     Não Programada           NaT
# 1250                                              VR/V2           NaT
# 1251                            Data da Cirurgia de LCA           NaT
# 1252                                     Não Programada           NaT
# 1253                                     Não Programada           NaT
#
#         Status
# 8     Pendente
# 9     Pendente
# 10    Pendente
# 11    Pendente
# 12    Pendente
# ...        ...
# 1249  Pendente
# 1250  Pendente
# 1251  Pendente
# 1252  Pendente
# 1253  Pendente
#
# [646 rows x 5 columns]

# %%
datas_visitas = visitas_reordenado.copy()
datas_visitas['Data Estimada'] = pd.to_datetime(datas_visitas['Data Estimada'], errors='coerce')
datas_visitas = visitas_reordenado.dropna(subset=["Data Estimada"])
datas_visitas = datas_visitas.sort_values(by= "Data Estimada", ascending=True)
datas_visitas = datas_visitas[~datas_visitas["Tipo Visita"].isin(["Unscheduled", "Triagem", "End of Study"])]
valores_contagem = datas_visitas['Tipo Visita'].value_counts()
datas_visitas
# Out:
#                                           Estudo/Centro  ID Participante  \
# 970                          Oxandrolona - Leforte HMCG             3333
# 972                          Oxandrolona - Leforte HMCG             3330
# 1006                         Oxandrolona - Leforte HMCG             3435
# 827                  Oxandrolona - Santa Casa de Santos             3319
# 826                  Oxandrolona - Santa Casa de Santos             3323
# ...                                                 ...              ...
# 486   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...             3336
# 487   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...             3387
# 735   EASi-HF reduzido - 1378-0018 - Maternidade e C...             3399
# 488   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...             3434
# 489   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...             3436
#
#                                             Tipo Visita  \
# 970                                               VR/V2
# 972                                               VR/V2
# 1006                                              VR/V2
# 827   8 semanas após a inserção do implante de oxand...
# 826                                               VR/V2
# ...                                                 ...
# 486                                           Visita 16
# 487                                           Visita 16
# 735                                           Visita 16
# 488                                           Visita 16
# 489                                           Visita 16
#
#                  Data Estimada    Status
# 970  2025-12-11 00:00:01+00:00  Pendente
# 972  2025-12-25 00:00:01+00:00  Pendente
# 1006 2026-03-01 00:00:01+00:00  Pendente
# 827  2026-03-20 00:00:00+00:00  Pendente
# 826  2026-03-20 00:00:00+00:00  Pendente
# ...                        ...       ...
# 486  2029-01-18 00:00:00+00:00  Pendente
# 487  2029-02-08 00:00:00+00:00  Pendente
# 735  2029-02-15 00:00:00+00:00  Pendente
# 488  2029-03-15 00:00:00+00:00  Pendente
# 489  2029-03-27 00:00:00+00:00  Pendente
#
# [522 rows x 5 columns]

# %%
def verificar_visitas_proximos_dias(datas_visitas, dias_para_visita=20):

    if datas_visitas is None or datas_visitas.empty:
        return pd.DataFrame()

    df = datas_visitas.copy()

    df['Data Estimada'] = (
        pd.to_datetime(df['Data Estimada'], errors='coerce')
        .dt.tz_localize(None)
    )

    hoje = pd.Timestamp.today().normalize()
    limite_visita = hoje + pd.Timedelta(days=dias_para_visita)

    visitas_futuras = df[
        (df['Data Estimada'] >= hoje) &
        (df['Data Estimada'] <= limite_visita)
    ]

    return visitas_futuras

visitas_20_dias = verificar_visitas_proximos_dias(datas_visitas, dias_para_visita=20)

# %%
def enviar_emails_visitas(proximas_visitas):

    destinatarios = _parse_destinatarios(enviar_para)

    try:
        if proximas_visitas is None or proximas_visitas.empty:
            registrar("Push Campo", "Visitas", "PULADO", observacao="Sem visitas nos próximos 20 dias")
            return

        colunas_esperadas = ['Estudo/Centro', 'ID Participante', 'Tipo Visita', 'Data Estimada', 'Status']
        faltantes = [c for c in colunas_esperadas if c not in proximas_visitas.columns]
        if faltantes:
            registrar("Push Campo", "Visitas", "ERRO", observacao=f"Colunas ausentes: {faltantes}")
            return

        if not all([smtp_server, email_usuario, email_senha, email_port]):
            registrar("Push Campo", "Visitas", "ERRO", observacao="Configurações SMTP incompletas")
            return

        if not destinatarios:
            registrar("Push Campo", "Visitas", "PULADO", observacao="Nenhum destinatário válido")
            return

        tabela_html = proximas_visitas[colunas_esperadas].to_html(
            index=False, escape=False, justify="left", border=0, classes="table"
        )

        msg = MIMEMultipart("alternative")
        msg['From']    = email_usuario
        msg['To']      = email_usuario
        msg['Bcc']     = ', '.join(destinatarios)
        msg['Subject'] = "Visitas de Seguimento - próximos 20 dias"

        body = f"""
        <html>
            <head>{css_hover}</head>
            <body>
                <div class="email-wrapper">
                    <div class="email-card">
                        <div class="email-header">
                            <h2>Visitas de Seguimento</h2>
                            <p>Programadas para os próximos 20 dias</p>
                        </div>
                        <div class="email-body">
                            <p>Olá,</p>
                            <p>Segue abaixo lista com visitas de seguimento programadas para os próximos 20 dias.</p>
                        </div>
                        {tabela_html}
                        <div class="email-footer">
                            <p>Este e-mail é gerado automaticamente a partir de informações inseridas na <strong>Polo Trial</strong>.</p>
                            <p>Qualquer dúvida, contate o <strong>time BI - SVRI</strong>.</p>
                        </div>
                    </div>
                </div>
            </body>
        </html>
        """
        msg.attach(MIMEText(body, 'html'))

        destinatarios_finais = [email_usuario] + destinatarios
        with smtplib.SMTP(smtp_server, email_port) as server:
            server.starttls()
            server.login(email_usuario, email_senha)
            server.sendmail(email_usuario, destinatarios_finais, msg.as_string())

        registrar(
            projeto="Push Campo",
            grupo="Visitas",
            status="ENVIADO",
            destinatarios=destinatarios_finais,
            num_registros=len(proximas_visitas),
        )

    except Exception as e:
        registrar("Push Campo", "Visitas", "ERRO", observacao=str(e))
        print(f"Erro ao enviar email de visitas: {str(e)}")

# Chamada da função
enviar_emails_visitas(visitas_20_dias)

# %% [markdown]
# **** Visitas de Monitoria

# %%
monitoria_df
# Out:
#           id  tipo_evento             titulo ds_co_industria ds_co_hc  \
# 0          1            1         Centriguga
# 1          4            1        contrato V6
# 2          5            1  contrato_ Graviti
# 3          6            1  contrato_ Graviti
# 4          7            1     Vencimento GCP
# ...      ...          ...                ...             ...      ...
# 18728  42535            2          Visita 12      1076012040  1076012
# 18729  42536            2          Visita 13      1076012040  1076012
# 18730  42537            2          Visita 14      1076012040  1076012
# 18731  42538            2          Visita 15      1076012040  1076012
# 18732  42539            2          Visita 16      1076012040  1076012
#
#       co_participante  tipo  status_evento             data_estimada  \
# 0                         4             20  2022-04-28T00:00:00.000Z
# 1                         6             20  2022-07-06T00:00:00.000Z
# 2                         6             20  2022-12-29T00:00:00.000Z
# 3                         6             20  2022-12-29T00:00:00.000Z
# 4                         7             20  2025-08-16T00:00:00.000Z
# ...               ...   ...            ...                       ...
# 18728            3436     1             18  2028-04-25T00:00:00.000Z
# 18729            3436     1             18  2028-07-18T00:00:00.000Z
# 18730            3436     1             18  2028-10-10T00:00:00.000Z
# 18731            3436     1             18  2029-01-02T00:00:00.000Z
# 18732            3436     1             18  2029-03-27T00:00:00.000Z
#
#               data_estimada_fim  ...           data_limite_min  \
# 0                           NaN  ...                       NaN
# 1                           NaN  ...                       NaN
# 2                           NaN  ...                       NaN
# 3                           NaN  ...                       NaN
# 4      2025-08-16T00:00:00.000Z  ...                       NaN
# ...                         ...  ...                       ...
# 18728                       NaN  ...  2028-04-04T00:00:00.000Z
# 18729                       NaN  ...  2028-06-27T00:00:00.000Z
# 18730                       NaN  ...  2028-09-19T00:00:00.000Z
# 18731                       NaN  ...  2028-12-12T00:00:00.000Z
# 18732                       NaN  ...  2029-03-06T00:00:00.000Z
#
#                 data_limite_max                data_ideal  ds_iniciais  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# ...                         ...                       ...          ...
# 18728  2028-05-16T00:00:00.000Z  2028-04-25T00:00:00.000Z        M.G.S
# 18729  2028-08-08T00:00:00.000Z  2028-07-18T00:00:00.000Z        M.G.S
# 18730  2028-10-31T00:00:00.000Z  2028-10-10T00:00:00.000Z        M.G.S
# 18731  2029-01-23T00:00:00.000Z  2029-01-02T00:00:00.000Z        M.G.S
# 18732  2029-04-17T00:00:00.000Z  2029-03-27T00:00:00.000Z        M.G.S
#
#                                 dados_tipo  \
# 0          {'id': 4, 'tipo': 'Calibração'}
# 1            {'id': 6, 'tipo': 'Contrato'}
# 2            {'id': 6, 'tipo': 'Contrato'}
# 3            {'id': 6, 'tipo': 'Contrato'}
# 4      {'id': 7, 'tipo': 'Vencimento GCP'}
# ...                                    ...
# 18728          {'id': 1, 'tipo': 'Visita'}
# 18729          {'id': 1, 'tipo': 'Visita'}
# 18730          {'id': 1, 'tipo': 'Visita'}
# 18731          {'id': 1, 'tipo': 'Visita'}
# 18732          {'id': 1, 'tipo': 'Visita'}
#
#                                             dados_status  \
# 0      {'id': 20, 'ds_descricao': 'Realizada', 'cor_s...
# 1      {'id': 20, 'ds_descricao': 'Realizada', 'cor_s...
# 2      {'id': 20, 'ds_descricao': 'Realizada', 'cor_s...
# 3      {'id': 20, 'ds_descricao': 'Realizada', 'cor_s...
# 4      {'id': 20, 'ds_descricao': 'Realizada', 'cor_s...
# ...                                                  ...
# 18728  {'id': 18, 'ds_descricao': 'Pendente', 'cor_st...
# 18729  {'id': 18, 'ds_descricao': 'Pendente', 'cor_st...
# 18730  {'id': 18, 'ds_descricao': 'Pendente', 'cor_st...
# 18731  {'id': 18, 'ds_descricao': 'Pendente', 'cor_st...
# 18732  {'id': 18, 'ds_descricao': 'Pendente', 'cor_st...
#
#                                          dados_protocolo  \
# 0                                                   None
# 1      {'id': 53, 'apelido_protocolo': 'Dipro', 'co_c...
# 2      {'id': 322, 'apelido_protocolo': 'Graviti', 'c...
# 3      {'id': 322, 'apelido_protocolo': 'Graviti', 'c...
# 4                                                   None
# ...                                                  ...
# 18728  {'id': 655, 'apelido_protocolo': 'EASi-HF - 13...
# 18729  {'id': 655, 'apelido_protocolo': 'EASi-HF - 13...
# 18730  {'id': 655, 'apelido_protocolo': 'EASi-HF - 13...
# 18731  {'id': 655, 'apelido_protocolo': 'EASi-HF - 13...
# 18732  {'id': 655, 'apelido_protocolo': 'EASi-HF - 13...
#
#                                       dados_participante  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 18728  {'id': 3436, 'id_participante': '1076012040', ...
# 18729  {'id': 3436, 'id_participante': '1076012040', ...
# 18730  {'id': 3436, 'id_participante': '1076012040', ...
# 18731  {'id': 3436, 'id_participante': '1076012040', ...
# 18732  {'id': 3436, 'id_participante': '1076012040', ...
#
#                                        dados_responsavel  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4      {'id': 239, 'ds_nome': 'Caroline Pinheiro Vian...
# ...                                                  ...
# 18728                                               None
# 18729                                               None
# 18730                                               None
# 18731                                               None
# 18732                                               None
#
#                                   dados_local
# 0                                        None
# 1                                        None
# 2                                        None
# 3                                        None
# 4      {'id': 765, 'ds_descricao': 'Virtual'}
# ...                                       ...
# 18728                                    None
# 18729                                    None
# 18730                                    None
# 18731                                    None
# 18732                                    None
#
# [18733 rows x 44 columns]

# %%
monitoria = monitoria_df[['dados_protocolo', 'dados_tipo', 'dados_status', 'data_estimada_filter']].copy()

monitoria.loc[:, 'dados_protocolo_id'] = monitoria['dados_protocolo'].apply(lambda x: x['id'] if x is not None else None)
monitoria.loc[:, 'apelido_protocolo'] = monitoria['dados_protocolo'].apply(lambda x: x['apelido_protocolo'] if x is not None else None)

monitoria.loc[:, 'dados_tipo_id'] = monitoria['dados_tipo'].apply(lambda x: x['id'] if x is not None else None)
monitoria.loc[:, 'dados_tipo_tipo'] = monitoria['dados_tipo'].apply(lambda x: x['tipo'] if x is not None else None)

monitoria.loc[:, 'dados_status_id'] = monitoria['dados_status'].apply(lambda x: x['id'] if x is not None else None)
monitoria.loc[:, 'ds_descricao'] = monitoria['dados_status'].apply(lambda x: x['ds_descricao'] if x is not None else None)

monitoria = monitoria.drop(['dados_protocolo','dados_status', 'dados_tipo_id','dados_status_id'], axis=1)
monitoria.rename(columns={'dados_protocolo_id': 'id'}, inplace=True)

monitoria.head(2)
# Out:
#                         dados_tipo data_estimada_filter    id  \
# 0  {'id': 4, 'tipo': 'Calibração'}           2022-04-28   NaN
# 1    {'id': 6, 'tipo': 'Contrato'}           2022-07-06  53.0
#
#   apelido_protocolo dados_tipo_tipo ds_descricao
# 0               NaN      Calibração    Realizada
# 1             Dipro        Contrato    Realizada

# %%
monitorias = pd.merge(centros, monitoria, on='id', how='inner')
monitorias
# Out:
#         id apelido_protocolo_x numero_protocolo co_externo  \
# 0      234      Code Break 202         20190341   20190341
# 1      234      Code Break 202         20190341   20190341
# 2      234      Code Break 202         20190341   20190341
# 3      234      Code Break 202         20190341   20190341
# 4      234      Code Break 202         20190341   20190341
# ...    ...                 ...              ...        ...
# 1307  2651         Oxandrolona                         NaN
# 1308  2651         Oxandrolona                         NaN
# 1309  2651         Oxandrolona                         NaN
# 1310  2651         Oxandrolona                         NaN
# 1311  2651         Oxandrolona                         NaN
#
#                                    apelido_centro  \
# 0           Code Break 202 - Santa Casa de Santos
# 1           Code Break 202 - Santa Casa de Santos
# 2           Code Break 202 - Santa Casa de Santos
# 3           Code Break 202 - Santa Casa de Santos
# 4           Code Break 202 - Santa Casa de Santos
# ...                                           ...
# 1307  Oxandrolona - Centro de Oncologia do Paraná
# 1308  Oxandrolona - Centro de Oncologia do Paraná
# 1309  Oxandrolona - Centro de Oncologia do Paraná
# 1310  Oxandrolona - Centro de Oncologia do Paraná
# 1311  Oxandrolona - Centro de Oncologia do Paraná
#
#                           dados_tipo data_estimada_filter apelido_protocolo_y  \
# 0     {'id': 2, 'tipo': 'Monitoria'}           2025-02-03      Code Break 202
# 1     {'id': 2, 'tipo': 'Monitoria'}           2025-08-04      Code Break 202
# 2     {'id': 2, 'tipo': 'Monitoria'}           2025-11-11      Code Break 202
# 3     {'id': 2, 'tipo': 'Monitoria'}           2026-03-30      Code Break 202
# 4        {'id': 1, 'tipo': 'Visita'}           2024-12-03      Code Break 202
# ...                              ...                  ...                 ...
# 1307     {'id': 1, 'tipo': 'Visita'}                  NaN         Oxandrolona
# 1308     {'id': 1, 'tipo': 'Visita'}           2026-06-08         Oxandrolona
# 1309     {'id': 1, 'tipo': 'Visita'}           2026-08-03         Oxandrolona
# 1310     {'id': 1, 'tipo': 'Visita'}           2026-10-26         Oxandrolona
# 1311     {'id': 1, 'tipo': 'Visita'}                  NaN         Oxandrolona
#
#      dados_tipo_tipo ds_descricao
# 0          Monitoria    Realizada
# 1          Monitoria    Realizada
# 2          Monitoria    Realizada
# 3          Monitoria    Realizada
# 4             Visita    Realizada
# ...              ...          ...
# 1307          Visita     Pendente
# 1308          Visita     Pendente
# 1309          Visita     Pendente
# 1310          Visita     Pendente
# 1311          Visita     Pendente
#
# [1312 rows x 10 columns]

# %%
monitorias_filtrado = monitorias[monitorias['dados_tipo_tipo'].str.contains('Monitoria')]
monitorias_filtrado['apelido_protocolo_x'] = monitorias_filtrado['apelido_protocolo_x'].str.strip()
monitorias_filtrado
# Out:
#        id           apelido_protocolo_x  numero_protocolo        co_externo  \
# 0     234                Code Break 202          20190341          20190341
# 1     234                Code Break 202          20190341          20190341
# 2     234                Code Break 202          20190341          20190341
# 3     234                Code Break 202          20190341          20190341
# 18    468                  TAK-330-3001      TAK-330-3001      TAK 330-3001
# 19    468                  TAK-330-3001      TAK-330-3001      TAK 330-3001
# 20    468                  TAK-330-3001      TAK-330-3001      TAK 330-3001
# 21    468                  TAK-330-3001      TAK-330-3001      TAK 330-3001
# 22    468                  TAK-330-3001      TAK-330-3001      TAK 330-3001
# 23    468                  TAK-330-3001      TAK-330-3001      TAK 330-3001
# 24    468                  TAK-330-3001      TAK-330-3001      TAK 330-3001
# 25    468                  TAK-330-3001      TAK-330-3001      TAK 330-3001
# 76    655           EASi-HF - 1378-0020         1378-0020           EASI HF
# 77    655           EASi-HF - 1378-0020         1378-0020           EASI HF
# 78    655           EASi-HF - 1378-0020         1378-0020           EASI HF
# 79    655           EASi-HF - 1378-0020         1378-0020           EASI HF
# 80    655           EASi-HF - 1378-0020         1378-0020           EASI HF
# 81    655           EASi-HF - 1378-0020         1378-0020           EASI HF
# 82    655           EASi-HF - 1378-0020         1378-0020           EASI HF
# 83    655           EASi-HF - 1378-0020         1378-0020           EASI HF
# 84    655           EASi-HF - 1378-0020         1378-0020           EASI HF
# 85    655           EASi-HF - 1378-0020         1378-0020           EASI HF
# 86    655           EASi-HF - 1378-0020         1378-0020           EASI HF
# 87    655           EASi-HF - 1378-0020         1378-0020           EASI HF
# 88    655           EASi-HF - 1378-0020         1378-0020           EASI HF
# 89    655           EASi-HF - 1378-0020         1378-0020           EASI HF
# 90    655           EASi-HF - 1378-0020         1378-0020           EASI HF
# 91    655           EASi-HF - 1378-0020         1378-0020           EASI HF
# 92    655           EASi-HF - 1378-0020         1378-0020           EASI HF
# 590   784                    SONATA-HCM  LX4211.1-314-HCM  LX4211.1-314-HCM
# 591   784                    SONATA-HCM  LX4211.1-314-HCM  LX4211.1-314-HCM
# 592   784                    SONATA-HCM  LX4211.1-314-HCM  LX4211.1-314-HCM
# 593   784                    SONATA-HCM  LX4211.1-314-HCM  LX4211.1-314-HCM
# 594   784                    SONATA-HCM  LX4211.1-314-HCM  LX4211.1-314-HCM
# 659  1531                           DLG                                 DLG
# 660  1531                           DLG                                 DLG
# 661  1531                           DLG                                 DLG
# 662  1531                           DLG                                 DLG
# 663  1531                           DLG                                 DLG
# 696  1661                   EsSCAPE-996       BIOTEST-996               996
# 697  1661                   EsSCAPE-996       BIOTEST-996               996
# 698  1661                   EsSCAPE-996       BIOTEST-996               996
# 699  1661                   EsSCAPE-996       BIOTEST-996               996
# 700  1661                   EsSCAPE-996       BIOTEST-996               996
# 701  1661                   EsSCAPE-996       BIOTEST-996               996
# 702  1661                   EsSCAPE-996       BIOTEST-996               996
# 703  1661                   EsSCAPE-996       BIOTEST-996               996
# 704  1661                   EsSCAPE-996       BIOTEST-996               996
# 705  1661                   EsSCAPE-996       BIOTEST-996               996
# 706  1661                   EsSCAPE-996       BIOTEST-996               996
# 707  1661                   EsSCAPE-996       BIOTEST-996               996
# 708  1661                   EsSCAPE-996       BIOTEST-996               996
# 755  2230  EASi-HF reduzido - 1378-0018         1378-0018         1378-0018
# 756  2230  EASi-HF reduzido - 1378-0018         1378-0018         1378-0018
# 794  2372                   Oxandrolona                                 NaN
# 795  2372                   Oxandrolona                                 NaN
#
#                                         apelido_centro  \
# 0                Code Break 202 - Santa Casa de Santos
# 1                Code Break 202 - Santa Casa de Santos
# 2                Code Break 202 - Santa Casa de Santos
# 3                Code Break 202 - Santa Casa de Santos
# 18                 TAK-330-3001 - Santa Casa de Santos
# 19                 TAK-330-3001 - Santa Casa de Santos
# 20                 TAK-330-3001 - Santa Casa de Santos
# 21                 TAK-330-3001 - Santa Casa de Santos
# 22                 TAK-330-3001 - Santa Casa de Santos
# 23                 TAK-330-3001 - Santa Casa de Santos
# 24                 TAK-330-3001 - Santa Casa de Santos
# 25                 TAK-330-3001 - Santa Casa de Santos
# 76   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 77   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 78   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 79   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 80   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 81   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 82   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 83   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 84   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 85   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 86   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 87   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 88   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 89   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 90   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 91   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 92   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 590                    SONATA-HCM - Clínica CardialMed
# 591                    SONATA-HCM - Clínica CardialMed
# 592                    SONATA-HCM - Clínica CardialMed
# 593                    SONATA-HCM - Clínica CardialMed
# 594                    SONATA-HCM - Clínica CardialMed
# 659                         DLG - Santa Casa de Santos
# 660                         DLG - Santa Casa de Santos
# 661                         DLG - Santa Casa de Santos
# 662                         DLG - Santa Casa de Santos
# 663                         DLG - Santa Casa de Santos
# 696  EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# 697  EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# 698  EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# 699  EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# 700  EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# 701  EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# 702  EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# 703  EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# 704  EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# 705  EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# 706  EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# 707  EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# 708  EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# 755  EASi-HF reduzido - 1378-0018 - Maternidade e C...
# 756  EASi-HF reduzido - 1378-0018 - Maternidade e C...
# 794                 Oxandrolona - Santa Casa de Santos
# 795                 Oxandrolona - Santa Casa de Santos
#
#                          dados_tipo data_estimada_filter  \
# 0    {'id': 2, 'tipo': 'Monitoria'}           2025-02-03
# 1    {'id': 2, 'tipo': 'Monitoria'}           2025-08-04
# 2    {'id': 2, 'tipo': 'Monitoria'}           2025-11-11
# 3    {'id': 2, 'tipo': 'Monitoria'}           2026-03-30
# 18   {'id': 2, 'tipo': 'Monitoria'}           2025-03-06
# 19   {'id': 2, 'tipo': 'Monitoria'}           2025-05-13
# 20   {'id': 2, 'tipo': 'Monitoria'}           2025-05-13
# 21   {'id': 2, 'tipo': 'Monitoria'}           2025-08-05
# 22   {'id': 2, 'tipo': 'Monitoria'}           2025-10-17
# 23   {'id': 2, 'tipo': 'Monitoria'}           2025-09-26
# 24   {'id': 2, 'tipo': 'Monitoria'}           2026-01-08
# 25   {'id': 2, 'tipo': 'Monitoria'}           2026-04-02
# 76   {'id': 2, 'tipo': 'Monitoria'}           2023-11-30
# 77   {'id': 2, 'tipo': 'Monitoria'}           2025-05-09
# 78   {'id': 2, 'tipo': 'Monitoria'}           2025-07-01
# 79   {'id': 2, 'tipo': 'Monitoria'}           2025-09-10
# 80   {'id': 2, 'tipo': 'Monitoria'}           2025-09-22
# 81   {'id': 2, 'tipo': 'Monitoria'}           2025-08-27
# 82   {'id': 2, 'tipo': 'Monitoria'}           2025-10-22
# 83   {'id': 2, 'tipo': 'Monitoria'}           2025-11-17
# 84   {'id': 2, 'tipo': 'Monitoria'}           2025-12-16
# 85   {'id': 2, 'tipo': 'Monitoria'}           2026-01-09
# 86   {'id': 2, 'tipo': 'Monitoria'}           2026-02-26
# 87   {'id': 2, 'tipo': 'Monitoria'}           2026-01-14
# 88   {'id': 2, 'tipo': 'Monitoria'}           2026-03-05
# 89   {'id': 2, 'tipo': 'Monitoria'}           2026-04-06
# 90   {'id': 2, 'tipo': 'Monitoria'}           2026-05-28
# 91   {'id': 2, 'tipo': 'Monitoria'}           2026-05-11
# 92   {'id': 2, 'tipo': 'Monitoria'}           2026-06-10
# 590  {'id': 2, 'tipo': 'Monitoria'}           2026-02-13
# 591  {'id': 2, 'tipo': 'Monitoria'}           2026-07-07
# 592  {'id': 2, 'tipo': 'Monitoria'}           2026-11-17
# 593  {'id': 2, 'tipo': 'Monitoria'}           2026-11-17
# 594  {'id': 2, 'tipo': 'Monitoria'}           2026-11-17
# 659  {'id': 2, 'tipo': 'Monitoria'}           2025-05-30
# 660  {'id': 2, 'tipo': 'Monitoria'}           2025-07-28
# 661  {'id': 2, 'tipo': 'Monitoria'}           2025-12-08
# 662  {'id': 2, 'tipo': 'Monitoria'}           2026-04-27
# 663  {'id': 2, 'tipo': 'Monitoria'}           2026-04-28
# 696  {'id': 2, 'tipo': 'Monitoria'}           2024-07-03
# 697  {'id': 2, 'tipo': 'Monitoria'}           2025-07-24
# 698  {'id': 2, 'tipo': 'Monitoria'}           2025-09-16
# 699  {'id': 2, 'tipo': 'Monitoria'}           2025-09-25
# 700  {'id': 2, 'tipo': 'Monitoria'}           2025-10-24
# 701  {'id': 2, 'tipo': 'Monitoria'}           2025-12-04
# 702  {'id': 2, 'tipo': 'Monitoria'}           2025-12-19
# 703  {'id': 2, 'tipo': 'Monitoria'}           2026-01-23
# 704  {'id': 2, 'tipo': 'Monitoria'}           2026-02-20
# 705  {'id': 2, 'tipo': 'Monitoria'}           2026-02-26
# 706  {'id': 2, 'tipo': 'Monitoria'}           2026-06-26
# 707  {'id': 2, 'tipo': 'Monitoria'}           2026-05-25
# 708  {'id': 2, 'tipo': 'Monitoria'}           2026-06-23
# 755  {'id': 2, 'tipo': 'Monitoria'}           2025-10-23
# 756  {'id': 2, 'tipo': 'Monitoria'}           2026-03-20
# 794  {'id': 2, 'tipo': 'Monitoria'}           2025-12-29
# 795  {'id': 2, 'tipo': 'Monitoria'}           2026-04-16
#
#               apelido_protocolo_y dados_tipo_tipo ds_descricao
# 0                  Code Break 202       Monitoria    Realizada
# 1                  Code Break 202       Monitoria    Realizada
# 2                  Code Break 202       Monitoria    Realizada
# 3                  Code Break 202       Monitoria    Realizada
# 18                   TAK-330-3001       Monitoria    Realizada
# 19                   TAK-330-3001       Monitoria    Realizada
# 20                   TAK-330-3001       Monitoria    Realizada
# 21                   TAK-330-3001       Monitoria    Realizada
# 22                   TAK-330-3001       Monitoria    Realizada
# 23                   TAK-330-3001       Monitoria    Realizada
# 24                   TAK-330-3001       Monitoria    Realizada
# 25                   TAK-330-3001       Monitoria    Realizada
# 76            EASi-HF - 1378-0020       Monitoria    Realizada
# 77            EASi-HF - 1378-0020       Monitoria    Realizada
# 78            EASi-HF - 1378-0020       Monitoria    Realizada
# 79            EASi-HF - 1378-0020       Monitoria    Realizada
# 80            EASi-HF - 1378-0020       Monitoria    Realizada
# 81            EASi-HF - 1378-0020       Monitoria    Realizada
# 82            EASi-HF - 1378-0020       Monitoria    Realizada
# 83            EASi-HF - 1378-0020       Monitoria    Realizada
# 84            EASi-HF - 1378-0020       Monitoria    Realizada
# 85            EASi-HF - 1378-0020       Monitoria    Realizada
# 86            EASi-HF - 1378-0020       Monitoria    Realizada
# 87            EASi-HF - 1378-0020       Monitoria    Realizada
# 88            EASi-HF - 1378-0020       Monitoria    Realizada
# 89            EASi-HF - 1378-0020       Monitoria    Realizada
# 90            EASi-HF - 1378-0020       Monitoria     Pendente
# 91            EASi-HF - 1378-0020       Monitoria    Realizada
# 92            EASi-HF - 1378-0020       Monitoria     Pendente
# 590                    SONATA-HCM       Monitoria    Realizada
# 591                    SONATA-HCM       Monitoria     Pendente
# 592                    SONATA-HCM       Monitoria     Pendente
# 593                    SONATA-HCM       Monitoria     Pendente
# 594                    SONATA-HCM       Monitoria     Pendente
# 659                           DLG       Monitoria    Realizada
# 660                           DLG       Monitoria    Realizada
# 661                           DLG       Monitoria    Realizada
# 662                           DLG       Monitoria    Realizada
# 663                           DLG       Monitoria    Realizada
# 696                   EsSCAPE-996       Monitoria    Realizada
# 697                   EsSCAPE-996       Monitoria    Realizada
# 698                   EsSCAPE-996       Monitoria    Realizada
# 699                   EsSCAPE-996       Monitoria    Realizada
# 700                   EsSCAPE-996       Monitoria    Realizada
# 701                   EsSCAPE-996       Monitoria    Realizada
# 702                   EsSCAPE-996       Monitoria    Realizada
# 703                   EsSCAPE-996       Monitoria    Realizada
# 704                   EsSCAPE-996       Monitoria    Realizada
# 705                   EsSCAPE-996       Monitoria    Realizada
# 706                   EsSCAPE-996       Monitoria     Pendente
# 707                   EsSCAPE-996       Monitoria    Realizada
# 708                   EsSCAPE-996       Monitoria     Pendente
# 755  EASi-HF reduzido - 1378-0018       Monitoria    Realizada
# 756  EASi-HF reduzido - 1378-0018       Monitoria    Realizada
# 794                   Oxandrolona       Monitoria    Realizada
# 795                   Oxandrolona       Monitoria    Realizada

# %%
def verificar_monitorias_pendentes():

    if monitorias_filtrado is None or monitorias_filtrado.empty:
        return pd.DataFrame()

    df = monitorias_filtrado.copy()

    df['data_estimada_filter'] = (
        pd.to_datetime(df['data_estimada_filter'], errors='coerce')
        .dt.tz_localize(None)
    )

    hoje = pd.Timestamp.today().normalize()

    monitorias_pendentes = df[
        (df['ds_descricao'] == 'Pendente') &
        (df['data_estimada_filter'] >= hoje)
    ].sort_values('data_estimada_filter')

    return monitorias_pendentes

# %%
monitorias_pendentes = verificar_monitorias_pendentes()
monitorias_pendentes.rename(columns={'apelido_centro':'Estudo/Centro', 'dados_tipo_tipo': 'Monitoria', 'data_estimada_filter': 'Data Estimada','ds_descricao': 'Status'}, inplace=True)
monitorias_pendentes
# Out:
#        id  apelido_protocolo_x  numero_protocolo        co_externo  \
# 90    655  EASi-HF - 1378-0020         1378-0020           EASI HF
# 92    655  EASi-HF - 1378-0020         1378-0020           EASI HF
# 708  1661          EsSCAPE-996       BIOTEST-996               996
# 706  1661          EsSCAPE-996       BIOTEST-996               996
# 591   784           SONATA-HCM  LX4211.1-314-HCM  LX4211.1-314-HCM
# 592   784           SONATA-HCM  LX4211.1-314-HCM  LX4211.1-314-HCM
# 593   784           SONATA-HCM  LX4211.1-314-HCM  LX4211.1-314-HCM
# 594   784           SONATA-HCM  LX4211.1-314-HCM  LX4211.1-314-HCM
#
#                                          Estudo/Centro  \
# 90   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 92   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 708  EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# 706  EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# 591                    SONATA-HCM - Clínica CardialMed
# 592                    SONATA-HCM - Clínica CardialMed
# 593                    SONATA-HCM - Clínica CardialMed
# 594                    SONATA-HCM - Clínica CardialMed
#
#                          dados_tipo Data Estimada  apelido_protocolo_y  \
# 90   {'id': 2, 'tipo': 'Monitoria'}    2026-05-28  EASi-HF - 1378-0020
# 92   {'id': 2, 'tipo': 'Monitoria'}    2026-06-10  EASi-HF - 1378-0020
# 708  {'id': 2, 'tipo': 'Monitoria'}    2026-06-23          EsSCAPE-996
# 706  {'id': 2, 'tipo': 'Monitoria'}    2026-06-26          EsSCAPE-996
# 591  {'id': 2, 'tipo': 'Monitoria'}    2026-07-07           SONATA-HCM
# 592  {'id': 2, 'tipo': 'Monitoria'}    2026-11-17           SONATA-HCM
# 593  {'id': 2, 'tipo': 'Monitoria'}    2026-11-17           SONATA-HCM
# 594  {'id': 2, 'tipo': 'Monitoria'}    2026-11-17           SONATA-HCM
#
#      Monitoria    Status
# 90   Monitoria  Pendente
# 92   Monitoria  Pendente
# 708  Monitoria  Pendente
# 706  Monitoria  Pendente
# 591  Monitoria  Pendente
# 592  Monitoria  Pendente
# 593  Monitoria  Pendente
# 594  Monitoria  Pendente

# %%
monitoria_envio = monitorias_pendentes.drop(columns=['apelido_protocolo_x', 'co_externo', 'dados_tipo', 'apelido_protocolo_y'],errors='ignore')

monitoria_envio = monitoria_envio[
    [
        'Monitoria',
        'id',
        'numero_protocolo',
        'Estudo/Centro',
        'Data Estimada',
        'Status'
    ]
]
monitoria_envio
# Out:
#      Monitoria    id  numero_protocolo  \
# 90   Monitoria   655         1378-0020
# 92   Monitoria   655         1378-0020
# 708  Monitoria  1661       BIOTEST-996
# 706  Monitoria  1661       BIOTEST-996
# 591  Monitoria   784  LX4211.1-314-HCM
# 592  Monitoria   784  LX4211.1-314-HCM
# 593  Monitoria   784  LX4211.1-314-HCM
# 594  Monitoria   784  LX4211.1-314-HCM
#
#                                          Estudo/Centro Data Estimada    Status
# 90   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...    2026-05-28  Pendente
# 92   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...    2026-06-10  Pendente
# 708  EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...    2026-06-23  Pendente
# 706  EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...    2026-06-26  Pendente
# 591                    SONATA-HCM - Clínica CardialMed    2026-07-07  Pendente
# 592                    SONATA-HCM - Clínica CardialMed    2026-11-17  Pendente
# 593                    SONATA-HCM - Clínica CardialMed    2026-11-17  Pendente
# 594                    SONATA-HCM - Clínica CardialMed    2026-11-17  Pendente

# %%
def enviar_emails_monitoria(monitoria_envio):

    destinatarios = _parse_destinatarios(envio_para)

    try:
        if monitoria_envio is None or monitoria_envio.empty:
            registrar("Push Campo", "Monitoria", "PULADO", observacao="Sem monitorias pendentes")
            return

        colunas = ['Estudo/Centro', 'Monitoria', 'Data Estimada', 'Status']

        faltantes = [c for c in colunas if c not in monitoria_envio.columns]
        if faltantes:
            registrar("Push Campo", "Monitoria", "ERRO", observacao=f"Colunas ausentes: {faltantes}")
            return

        if not destinatarios:
            registrar("Push Campo", "Monitoria", "PULADO", observacao="Nenhum destinatário válido")
            return

        tabela_html = monitoria_envio[colunas].to_html(
            index=False,
            escape=False,
            justify="left",
            border=0,
            classes="table"
        )

        msg = MIMEMultipart("alternative")
        msg['From']    = email_usuario
        msg['To']      = email_usuario
        msg['Subject'] = "Visitas de Monitoria Pendentes"
        msg['Bcc'] = ', '.join(destinatarios)

        destinatarios_finais = [email_usuario] + destinatarios

        body = f"""
        <html>
            <head>{css_hover}</head>
            <body>
                <div class="email-wrapper">
                    <div class="email-card">
                        <div class="email-header">
                            <h2>Visitas de Monitoria Pendentes</h2>
                            <p>Monitorias programadas para os próximos dias</p>
                        </div>
                        <div class="email-body">
                            <p>Olá,</p>
                            <p>Segue abaixo lista com visitas de monitoria programadas para os próximos dias.</p>
                        </div>
                        {tabela_html}
                        <div class="email-footer">
                            <p>Este e-mail é gerado automaticamente a partir de informações inseridas na <strong>Polo Trial</strong>.</p>
                            <p>Qualquer dúvida, contate o <strong>time BI - SVRI</strong>.</p>
                        </div>
                    </div>
                </div>
            </body>
        </html>
        """

        msg.attach(MIMEText(body, 'html'))

        with smtplib.SMTP(smtp_server, email_port) as server:
            server.starttls()
            server.login(email_usuario, email_senha)
            server.sendmail(email_usuario, destinatarios_finais, msg.as_string())

        registrar(
            projeto="Push Campo",
            grupo="Monitoria",
            status="ENVIADO",
            destinatarios=destinatarios_finais,
            num_registros=len(monitoria_envio),
        )

    except Exception as e:
        registrar("Push Campo", "Monitoria", "ERRO", observacao=str(e))
        print(f"Erro ao enviar email de monitoria: {str(e)}")

# chamada
enviar_emails_monitoria(monitoria_envio)
