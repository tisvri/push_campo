# %%
import requests # type: ignore
from urllib.parse import urljoin
import pandas as pd # type: ignore
import schedule # type: ignore
import time
from datetime import datetime, timedelta
import os
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.image import MIMEImage
from email.mime.base import MIMEBase
from email import encoders
import dotenv

# %% [markdown]
# *** Acesso a PoloTrial (API)

# %%
#ROTA GERAL

dotenv.load_dotenv(override=True)

session = requests.Session()

polotrial_url = os.getenv("POLOTRIAL_URL")
print(f" URL: {polotrial_url}")

payload = {
    "nome": os.getenv("POLOTRIAL_USER"),
    "password": os.getenv("POLOTRIAL_PASSWORD")
}

headers = {
    "Content-Type": "application/json"
}
session_url = f'{polotrial_url}/sessions'
print(f"session: {session_url}")
login_response = requests.request("POST", session_url, json=payload, headers=headers)

print(f"Status Code: {login_response.status_code}")

auth_cookie = login_response.cookies.get("userId")
endpoint_headers={
        "cookie": f"userId={auth_cookie}"
    }
print({endpoint_headers['cookie']})

# Mensagem de sucesso na optenção do cookie
if endpoint_headers['cookie']:
    print("Autenticação bem-sucedida. Cookie obtido.")
    print(endpoint_headers)
    print(polotrial_url)
else:
    print("Falha na autenticação. Verifique suas credenciais.")
# Out:
#  URL: https://api.polotrial.com/beta
# session: https://api.polotrial.com/beta/sessions
# Status Code: 200
# {'userId=s%3AQHf9PjF0vUkyjtYe6h2UddLISs_goGHT.5%2FwFEjlzCrjNHQv%2FGZnqtwybI4GVB%2B3XyhylsNRdMbo'}
# Autenticação bem-sucedida. Cookie obtido.
# {'cookie': 'userId=s%3AQHf9PjF0vUkyjtYe6h2UddLISs_goGHT.5%2FwFEjlzCrjNHQv%2FGZnqtwybI4GVB%2B3XyhylsNRdMbo'}
# https://api.polotrial.com/beta

# %%
#ROTA PROTOCOLO

protocolo_url = f"{polotrial_url}/protocolo"
protocolos_ativos = [
    "161", #Aguardando iniciação
    "39", # Recrutamento aberto
    "9236", # Recrutamento aberto
    '9263', # Aguardando Ativação do Centro
    "393", # Aguardando Ativação do Centro
    '9294', # Fase Contratual
    '819', # Aguardando o Pacote Regulatório
    '739', # Aprovação Anvisa
    '6', # Aprovação Regulatória
    '912', # Em apreciação ética
    '9163'# Aprovado pelo CEP
]
 
df_protocolos = []
 
for co_status in protocolos_ativos:
    query_params ={
        "nested":"true",
        "status_protocolo": co_status
    }
   
    try:
        response = requests.request(
            "GET",
            protocolo_url,
            headers = endpoint_headers,
            params = query_params
        )
        response.raise_for_status()
        print(f"Status {co_status} - {response.status_code}")
        protocolo_json = response.json()
        if isinstance(protocolo_json, dict):
            protocolo_json = [protocolo_json]
        df_protocolos.append(pd.DataFrame(protocolo_json))
   
    except Exception as e:
        print(f"Erro ao buscar ID {co_status}: {e}")
 
if df_protocolos:
    protocolos_dataframe = pd.concat(df_protocolos, ignore_index=True)
    print(f"DataFrame de protocolos criado com {len(protocolos_dataframe)} registros.")
else:
    protocolos_dataframe = pd.DataFrame()
    print("Nenhum dado de protocolo foi recuperado.")
# Out:
# Status 161 - 200
# Status 39 - 200
# Status 9236 - 200
# Status 9263 - 200
# Status 393 - 200
# Status 9294 - 200
# Status 819 - 200
# Status 739 - 200
# Status 6 - 200
# Status 912 - 200
# Status 9163 - 200
# DataFrame de protocolos criado com 29 registros.

# %%
#ROTA PESSOAS

pessoas_url = f"{polotrial_url}/pessoas"
query_params = {
    "nested":"true",
}
response = requests.request("GET", pessoas_url, headers=endpoint_headers, params=query_params)

print(response.status_code)
pessoas = response.json()
pessoas_df = pd.DataFrame(pessoas)
# Out:
# 200

# %%
print("SHAPE:", pessoas_df.shape)
print("COLUNAS:", pessoas_df.columns.tolist())
print(pessoas_df.head())
# Out:
# SHAPE: (3834, 30)
# COLUNAS: ['dados_ativo', 'id', 'ds_nome', 'co_tipo_gn', 'co_equipe_gn', 'co_formacao_maior_nivel_gn', 'dt_ultimo_certificado_gcp', 'registro_profissional', 'declaracao_confidencialidade', 'custo_mensal_estimado', 'co_centro', 'equipe_padrao', 'equipe_padrao_kits', 'equipe_padrao_farmacia', 'equipe_padrao_naocega', 'filter', 'prox_vencimento_treinamento', 'co_especialidade', 'ativo', 'deleted', 'status', 'dados_co_tipo_gn', 'dados_co_equipe_gn', 'dados_co_formacao_maior_nivel_gn', 'dados_status', 'dados_centro', 'dados_equipe_padrao_farmacia', 'dados_equipe_padrao_kits', 'dados_equipe_padrao', 'dados_pessoa_especialidade']
#             dados_ativo    id                 ds_nome  co_tipo_gn  \
# 0  {'descricao': 'Sim'}  2978                     NaN       562.0
# 1  {'descricao': 'Sim'}  3545                     NaN       562.0
# 2  {'descricao': 'Sim'}  1332                               649.0
# 3  {'descricao': 'Sim'}  3118   Alex Gonçalves Macedo       387.0
# 4  {'descricao': 'Sim'}  1554    Alex Vladimir Dudzic       649.0
#
#   co_equipe_gn  co_formacao_maior_nivel_gn dt_ultimo_certificado_gcp  \
# 0         None                         NaN                       NaN
# 1         None                         NaN                       NaN
# 2         None                         NaN                       NaN
# 3         None                        31.0                2023-09-06
# 4         None                         NaN                       NaN
#
#   registro_profissional declaracao_confidencialidade custo_mensal_estimado  \
# 0                   NaN                         None                  None
# 1                   NaN                         None                  None
# 2                   NaN                         None                  None
# 3             74.334/SP                         None                  None
# 4                   NaN                         None                  None
#
#    ...  status                                   dados_co_tipo_gn  \
# 0  ...     NaN  {'id': 562, 'ds_descricao': 'Equipe padrão (ad...
# 1  ...     NaN  {'id': 562, 'ds_descricao': 'Equipe padrão (ad...
# 2  ...     NaN        {'id': 649, 'ds_descricao': 'Participante'}
# 3  ...  9404.0  {'id': 387, 'ds_descricao': 'Pesquisador Princ...
# 4  ...     NaN        {'id': 649, 'ds_descricao': 'Participante'}
#
#    dados_co_equipe_gn        dados_co_formacao_maior_nivel_gn  \
# 0                None                                    None
# 1                None                                    None
# 2                None                                    None
# 3                None  {'id': 31, 'ds_descricao': 'Mestrado'}
# 4                None                                    None
#
#                             dados_status  \
# 0                                   None
# 1                                   None
# 2                                   None
# 3  {'id': 9404, 'ds_descricao': 'Ativo'}
# 4                                   None
#
#                                      dados_centro  \
# 0                                            None
# 1                                            None
# 2                                            None
# 3  {'id': 4, 'descricao': 'Santa Casa de Santos'}
# 4                                            None
#
#   dados_equipe_padrao_farmacia  dados_equipe_padrao_kits  dados_equipe_padrao  \
# 0                         None                      None                 None
# 1                         None                      None                 None
# 2                         None                      None                 None
# 3                         None                      None                 None
# 4                         None                      None                 None
#
#                           dados_pessoa_especialidade
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [{'id': 150, 'co_pessoa': 3118, 'co_pessoa_esp...
# 4                                                 []
#
# [5 rows x 30 columns]

# %%
#ROTA AGENDA

agenda_url = f"{polotrial_url}/participante_visita"
query_params = {
    "nested":"true",
}
response = requests.request("GET", agenda_url, headers=endpoint_headers, params=query_params)

print(response.status_code)
agenda = response.json()
agenda_df = pd.DataFrame(agenda)
# Out:
# 200

# %%
#ROTA PARTICIPANTES

particpantes_url = f"{polotrial_url}/participantes"
query_params = {
    "nested":"true",
}
response = requests.request("GET", particpantes_url, headers=endpoint_headers, params=query_params)

print(response.status_code)
participantes = response.json()
participantes_df = pd.DataFrame([participantes])
# Out:
# 200

# %%
monitoria_url = f"{polotrial_url}/agenda"
query_params = {
    "nested":"true",
}
response = requests.request("GET", monitoria_url, headers=endpoint_headers, params=query_params)

print(response.status_code)
monitoria = response.json()
monitoria_df = pd.DataFrame(monitoria)
# Out:
# 200

# %% [markdown]
# *** Visualização e modelagem para extração de GCP (cadastros ativos)

# %%
pessoas_df.head(5)
# Out:
#             dados_ativo    id                 ds_nome  co_tipo_gn  \
# 0  {'descricao': 'Sim'}  2978                     NaN       562.0
# 1  {'descricao': 'Sim'}  3545                     NaN       562.0
# 2  {'descricao': 'Sim'}  1332                               649.0
# 3  {'descricao': 'Sim'}  3118   Alex Gonçalves Macedo       387.0
# 4  {'descricao': 'Sim'}  1554    Alex Vladimir Dudzic       649.0
#
#   co_equipe_gn  co_formacao_maior_nivel_gn dt_ultimo_certificado_gcp  \
# 0         None                         NaN                       NaN
# 1         None                         NaN                       NaN
# 2         None                         NaN                       NaN
# 3         None                        31.0                2023-09-06
# 4         None                         NaN                       NaN
#
#   registro_profissional declaracao_confidencialidade custo_mensal_estimado  \
# 0                   NaN                         None                  None
# 1                   NaN                         None                  None
# 2                   NaN                         None                  None
# 3             74.334/SP                         None                  None
# 4                   NaN                         None                  None
#
#    ...  status                                   dados_co_tipo_gn  \
# 0  ...     NaN  {'id': 562, 'ds_descricao': 'Equipe padrão (ad...
# 1  ...     NaN  {'id': 562, 'ds_descricao': 'Equipe padrão (ad...
# 2  ...     NaN        {'id': 649, 'ds_descricao': 'Participante'}
# 3  ...  9404.0  {'id': 387, 'ds_descricao': 'Pesquisador Princ...
# 4  ...     NaN        {'id': 649, 'ds_descricao': 'Participante'}
#
#    dados_co_equipe_gn        dados_co_formacao_maior_nivel_gn  \
# 0                None                                    None
# 1                None                                    None
# 2                None                                    None
# 3                None  {'id': 31, 'ds_descricao': 'Mestrado'}
# 4                None                                    None
#
#                             dados_status  \
# 0                                   None
# 1                                   None
# 2                                   None
# 3  {'id': 9404, 'ds_descricao': 'Ativo'}
# 4                                   None
#
#                                      dados_centro  \
# 0                                            None
# 1                                            None
# 2                                            None
# 3  {'id': 4, 'descricao': 'Santa Casa de Santos'}
# 4                                            None
#
#   dados_equipe_padrao_farmacia  dados_equipe_padrao_kits  dados_equipe_padrao  \
# 0                         None                      None                 None
# 1                         None                      None                 None
# 2                         None                      None                 None
# 3                         None                      None                 None
# 4                         None                      None                 None
#
#                           dados_pessoa_especialidade
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [{'id': 150, 'co_pessoa': 3118, 'co_pessoa_esp...
# 4                                                 []
#
# [5 rows x 30 columns]

# %%
colunas = [
    'dados_centro',
    'dt_ultimo_certificado_gcp',
    'ds_nome',
    'dados_co_tipo_gn',
    'dados_status'
]

faltantes = [c for c in colunas if c not in pessoas_df.columns]
if faltantes:
    raise Exception(f"Colunas ausentes: {faltantes}")
gcp = pessoas_df[colunas].copy()

gcp.loc[:, 'dados_centro_id'] = gcp['dados_centro'].apply(lambda x: x['id'] if x is not None else None)
gcp.loc[:, 'dados_centro_descricao'] = gcp['dados_centro'].apply(lambda x: x['descricao'] if x is not None else None)
gcp.loc[:, 'tipo_gn'] = gcp['dados_co_tipo_gn'].apply(lambda x: x['ds_descricao'] if x is not None else None)
gcp.loc[:, 'status'] = gcp['dados_status'].apply(lambda x: x['ds_descricao'] if x is not None else None)

gcp_ativos = gcp.drop(['dados_centro', 'dados_centro_id', 'dados_co_tipo_gn', 'dados_status'], axis=1)
gcp_modelado = gcp_ativos[gcp_ativos['status'] == 'Ativo']

gcp_modelado.head(5)
# Out:
#     dt_ultimo_certificado_gcp                 ds_nome  \
# 3                  2023-09-06   Alex Gonçalves Macedo
# 5                         NaN   Augusto Ferreira José
# 6                         NaN        Dr. Ricardo Moro
# 312                       NaN    Adão Castelo Antônio
# 383                2025-06-26      Alessandro Vengjer
#
#                         dados_centro_descricao                tipo_gn status
# 3                         Santa Casa de Santos  Pesquisador Principal  Ativo
# 5                         Santa Casa de Santos        Subinvestigador  Ativo
# 6    Clinica de Ortopedia Campo Largo S/S LTDA  Pesquisador Principal  Ativo
# 312              Hospital Municipal de Barueri  Pesquisador Principal  Ativo
# 383                       Santa Casa de Santos  Pesquisador Principal  Ativo

# %%
venc_gcp = gcp_modelado[gcp_modelado['tipo_gn'] != 'Equipe padrão (adicionada automaticamente para todos os protocolos)']
venc_gcp["Cadastro de data"] = venc_gcp["dt_ultimo_certificado_gcp"].apply(
    lambda x: "Não há data cadastrada" if pd.isna(x) else "Data cadastrada"
)

venc_gcp.rename(columns={'dt_ultimo_certificado_gcp': 'Assinatura do GCP', 'ds_nome': 'Nome', 'dados_centro_descricao': 'Centro','tipo_gn': 'Função', 'status': 'Status do Cadastro'}, inplace=True)

nova_ordem = ['Centro', 'Nome', 'Função','Status do Cadastro', 'Assinatura do GCP', "Cadastro de data"]
venc_gcp = venc_gcp[nova_ordem]
venc_gcp = venc_gcp.sort_values(by="Centro")
venc_gcp
# Out:
#                                                  Centro  \
# 1109  A2Z Clinical Centro Avancado De Pesquisa Clini...
# 1276                              Centro Médico Sinapse
# 1192                                Centro Vila Olimpia
# 1312                      Centro de Oncologia do Panará
# 1108                                          Clin Kids
# ...                                                 ...
# 1559                                                NaN
# 1773                                                NaN
# 1775                                                NaN
# 3128                                                NaN
# 3239                                                NaN
#
#                                           Nome                 Função  \
# 1109  Dr. Fernando Henrique de Carvalho Gouvêa          Equipe Médica
# 1276             Dr. Ricardo Moutte de Freitas  Pesquisador Principal
# 1192             Dr. Leandro Tuzuki Cavalheiro  Pesquisador Principal
# 1312                  Dr. Thadeu Tiessi Suzuki  Pesquisador Principal
# 1108                      Dr. Fernando Bedoni   Pesquisador Principal
# ...                                        ...                    ...
# 1559                       Eduardo Ramacciotti  Pesquisador Principal
# 1773                            Francine Heiko        Subinvestigador
# 1775             Francine Heiko Alves Perpétuo        Subinvestigador
# 3128         Nathalia de Oliveira Westphalen          Subinvestigador
# 3239                          Paula Sant' Anna        Subinvestigador
#
#      Status do Cadastro Assinatura do GCP        Cadastro de data
# 1109              Ativo               NaN  Não há data cadastrada
# 1276              Ativo               NaN  Não há data cadastrada
# 1192              Ativo               NaN  Não há data cadastrada
# 1312              Ativo        2025-11-10         Data cadastrada
# 1108              Ativo               NaN  Não há data cadastrada
# ...                 ...               ...                     ...
# 1559              Ativo               NaN  Não há data cadastrada
# 1773              Ativo               NaN  Não há data cadastrada
# 1775              Ativo               NaN  Não há data cadastrada
# 3128              Ativo               NaN  Não há data cadastrada
# 3239              Ativo               NaN  Não há data cadastrada
#
# [357 rows x 6 columns]

# %%
hmcg = ['Leforte HMCG','Leforte Morumbi','Hospital Municipal de Barueri', 'Leforte Liberdade', 'Clínica CardialMed']
filtro1 = venc_gcp['Centro'].isin(hmcg)
venc_gcp_hmcg = venc_gcp[filtro1]
venc_gcp_hmcg=venc_gcp_hmcg.sort_values(by=['Centro', 'Nome'], ascending= [True, True])
venc_gcp_hmcg
# Out:
#                              Centro  \
# 1149             Clínica CardialMed
# 1450             Clínica CardialMed
# 2015             Clínica CardialMed
# 2100             Clínica CardialMed
# 312   Hospital Municipal de Barueri
# ...                             ...
# 1112                Leforte Morumbi
# 1452                Leforte Morumbi
# 1482                Leforte Morumbi
# 1751                Leforte Morumbi
# 2884                Leforte Morumbi
#
#                                            Nome                 Função  \
# 1149               Dr. Heron Rhydan Saad Rached  Pesquisador Principal
# 1450            Dra. Maristela Gomes de Almeida  Pesquisador Principal
# 2015                   Heron Rhydan Saad Rached  Pesquisador Principal
# 2100       Izabella Cordeiro Freire Saad Rached  Pesquisador Principal
# 312                        Adão Castelo Antônio  Pesquisador Principal
# ...                                         ...                    ...
# 1112                  Dr. Fernando Reis Menezes  Pesquisador Principal
# 1452  Dra. Mayara de Almeida Rodrigues da Costa  Pesquisador Principal
# 1482                        Dra. Samantha Neves  Pesquisador Principal
# 1751                      Fernando Reis Menezes  Pesquisador Principal
# 2884       Mayara de Almeida Rodrigues da Costa  Pesquisador Principal
#
#      Status do Cadastro Assinatura do GCP        Cadastro de data
# 1544  Não há data cadastrada
# 1693  Não há data cadastrada
# 1694  Não há data cadastrada
# 2360  Não há data cadastrada
# 2533  Não há data cadastrada
# 2616  Não há data cadastrada
# 2648  Não há data cadastrada
# 2649  Não há data cadastrada
# 3292  Não há data cadastrada
# 3372  Não há data cadastrada
# 3394  Não há data cadastrada
# 3465  Não há data cadastrada

# %%
iir_coord = ['Hospital das Clínicas de Itajubá', 'Saint-Beauté Clinique', 'Hospital Salvalus','Consultório Lopes e Sartorelli', 'Clínica Berger', 
            'QualiVida Higienópolis','Endolap Saúde' ]
filtro3 = venc_gcp['Centro'].isin(iir_coord)
venc_gcp_iir_coord = venc_gcp[filtro3] 
venc_gcp_iir_coord=venc_gcp_iir_coord.sort_values(by=['Centro', 'Nome'], ascending= [True, True])
venc_gcp_iir_coord
# Out:
#                               Centro                 Nome  \
# 1051                  Clínica Berger   Dr. Charles Berger
# 3133  Consultório Lopes e Sartorelli  Nathalia Westphalen
#
#                      Função Status do Cadastro Assinatura do GCP  \
# 1051  Pesquisador Principal              Ativo               NaN
# 3133          Equipe Médica              Ativo               NaN
#
#             Cadastro de data
# 1051  Não há data cadastrada
# 3133  Não há data cadastrada

# %%
envio_viviane = ['Hospital Pilar','Santa casa de São Paulo','Hospital São Francisco de Ribeirão Preto',
                'Hospital Antônio Prudente','Clínica CardialMed','CLINAR - Clínica de Aparelhos RespiratÃ³rios',
                'Santa Casa de Fortaleza','Hospital Vera Cruz','Hapvida','Unimed Brusque',
                'Hospital São José das Doenças Infecciosas','Otorhinus Clínica Médica','Hospital São Francisco de Araraquara',
                'Maternidade Octaviano Neves','Clínica Infectologie','Hospital Teresa de Lisieux',
                'Hospital RioMar de Belém','Hospital e Maternidade Eugênia Pinheiro',
                'Hospital São Francisco Saúde','Hospital do Coração de Campinas','Aliança Cavernoma Brasil',
                'Faculdade de Medicina de Ribeirão Preto - USP ','Centro Clínico Zona Sul ']
filtro4 = venc_gcp['Centro'].isin(envio_viviane)
venc_gcp_envio_viviane = venc_gcp[filtro4]
venc_gcp_envio_viviane=venc_gcp_envio_viviane.sort_values(by=['Centro', 'Nome'], ascending= [True, True])
venc_gcp_envio_viviane
# Out:
#                                               Centro  \
# 1149                              Clínica CardialMed
# 1450                              Clínica CardialMed
# 2015                              Clínica CardialMed
# 2100                              Clínica CardialMed
# 1743  Faculdade de Medicina de Ribeirão Preto - USP
# 761                               Hospital Vera Cruz
# 1257                        Otorhinus Clínica Médica
# 3289                        Otorhinus Clínica Médica
# 1017                                  Unimed Brusque
# 1063                                  Unimed Brusque
# 1098                                  Unimed Brusque
# 1111                                  Unimed Brusque
# 1099                                  Unimed Brusque
# 1155                                  Unimed Brusque
# 1187                                  Unimed Brusque
# 1211                                  Unimed Brusque
# 1231                                  Unimed Brusque
# 1249                                  Unimed Brusque
# 1291                                  Unimed Brusque
# 1305                                  Unimed Brusque
# 1310                                  Unimed Brusque
# 1321                                  Unimed Brusque
# 1341                                  Unimed Brusque
# 1348                                  Unimed Brusque
# 1098              Ativo               NaN  Não há data cadastrada
# 1111              Ativo               NaN  Não há data cadastrada
# 1099              Ativo               NaN  Não há data cadastrada
# 1155              Ativo               NaN  Não há data cadastrada
# 1187              Ativo               NaN  Não há data cadastrada
# 1211              Ativo               NaN  Não há data cadastrada
# 1231              Ativo               NaN  Não há data cadastrada
# 1249              Ativo               NaN  Não há data cadastrada
# 1291              Ativo               NaN  Não há data cadastrada
# 1305              Ativo               NaN  Não há data cadastrada
# 1310              Ativo               NaN  Não há data cadastrada
# 1321              Ativo               NaN  Não há data cadastrada
# 1341              Ativo               NaN  Não há data cadastrada
# 1348              Ativo               NaN  Não há data cadastrada
# 1349              Ativo               NaN  Não há data cadastrada
# 1350              Ativo               NaN  Não há data cadastrada
# 1354              Ativo               NaN  Não há data cadastrada
# 1375              Ativo               NaN  Não há data cadastrada
# 1394              Ativo               NaN  Não há data cadastrada
# 1449              Ativo               NaN  Não há data cadastrada
# 1451              Ativo               NaN  Não há data cadastrada
# 1484              Ativo               NaN  Não há data cadastrada

# %%
stacasa_santos = ['Santa Casa de Santos']
filtro5 = venc_gcp['Centro'].isin(stacasa_santos)
venc_gcp_stacasa_santos = venc_gcp[filtro5]
venc_gcp_stacasa_santos=venc_gcp_stacasa_santos.sort_values(by=['Centro', 'Nome'], ascending= [True, True])
venc_gcp_stacasa_santos
# Out:
#                     Centro                             Nome  \
# 3     Santa Casa de Santos            Alex Gonçalves Macedo
# 5     Santa Casa de Santos            Augusto Ferreira José
# 383   Santa Casa de Santos               Alessandro Vengjer
# 516   Santa Casa de Santos     André Galante Alencar Aranha
# 518   Santa Casa de Santos  André Gustavo Pereira Magalhães
# ...                    ...                              ...
# 3392  Santa Casa de Santos              Roberto Higa Junior
# 3479  Santa Casa de Santos        Samuel Brunini Petrarolha
# 3478  Santa Casa de Santos        Samuel Brunini Petrarolha
# 3771  Santa Casa de Santos                Vitor Hugo Straub
# 3772  Santa Casa de Santos       Vitor Hugo Straub Canasiro
#
#                      Função Status do Cadastro Assinatura do GCP  \
# 3     Pesquisador Principal              Ativo        2023-09-06
# 5           Subinvestigador              Ativo               NaN
# 383   Pesquisador Principal              Ativo        2025-06-26
# 516   Pesquisador Principal              Ativo        2021-09-23
# 518         Subinvestigador              Ativo               NaN
# ...                     ...                ...               ...
# 3392        Subinvestigador              Ativo               NaN
# 3479  Pesquisador Principal              Ativo               NaN
# 3478  Pesquisador Principal              Ativo               NaN
# 3771  Pesquisador Principal              Ativo               NaN
# 3772  Pesquisador Principal              Ativo               NaN
#
#             Cadastro de data
# 3            Data cadastrada
# 5     Não há data cadastrada
# 383          Data cadastrada
# 516          Data cadastrada
# 518   Não há data cadastrada
# ...                      ...
# 3392  Não há data cadastrada
# 3479  Não há data cadastrada
# 3478  Não há data cadastrada
# 3771  Não há data cadastrada
# 3772  Não há data cadastrada
#
# [114 rows x 6 columns]

# %%
capibaribe = ['Hospital do Capibaribe']
filtro6 = venc_gcp['Centro'].isin(capibaribe)
venc_gcp_capibaribe = venc_gcp[filtro6]
venc_gcp_capibaribe=venc_gcp_capibaribe.sort_values(by=['Centro', 'Nome'], ascending= [True, True])
venc_gcp_capibaribe
# Out:
#                       Centro                                      Nome  \
# 1163  Hospital do Capibaribe              Dr. Jayme José Gouveia Filho
# 1447  Hospital do Capibaribe  Dra. Mariane Teodoro Fernandes Rodrigues
# 2800  Hospital do Capibaribe       Mariane Teodoro Fernandes Rodrigues
#
#                      Função Status do Cadastro Assinatura do GCP  \
# 1163          Equipe Médica              Ativo        2024-09-23
# 1447  Pesquisador Principal              Ativo        2024-06-14
# 2800  Pesquisador Principal              Ativo               NaN
#
#             Cadastro de data
# 1163         Data cadastrada
# 1447         Data cadastrada
# 2800  Não há data cadastrada

# %% [markdown]
# ***Função para cálculo da data de vencimento de GCP.

# %%
def verificar_vencimento_contratos(df_contratos, nome_centro, dias_para_vencimento=30):

    df_contratos['Assinatura do GCP'] = pd.to_datetime(df_contratos['Assinatura do GCP'], errors='coerce')

    hoje = datetime.today()
    limite_vencimento = hoje + timedelta(days=dias_para_vencimento)

    df_contratos['data_vencimento'] = df_contratos['Assinatura do GCP'] + timedelta(days=2 * 365)

    filtro_vencendo = (df_contratos['data_vencimento'] > hoje) & (df_contratos['data_vencimento'] <= limite_vencimento)

    filtro_sem_data = df_contratos['Assinatura do GCP'].isna()

    contratos_relevantes = df_contratos[filtro_vencendo | filtro_sem_data]

    if contratos_relevantes.empty:
        print(f"🔹 Não há contratos GCP sem data registrada no sistema ou com vencimento nos próximos {dias_para_vencimento} dias para {nome_centro}.")
    else:
        print(f"⚠️{nome_centro} - Os profissionais abaixo listados não tem data de GCP na PoloTrial ou a data informada irá vencer nos próximos {dias_para_vencimento} dias:")
        print(contratos_relevantes[['Centro', 'Nome', 'Função','Status do Cadastro', 'Assinatura do GCP', "Cadastro de data"]])

    return contratos_relevantes

# %%
contratos_hmcg = verificar_vencimento_contratos(venc_gcp_hmcg, "HMCG", dias_para_vencimento=30)
contratos_rocio = verificar_vencimento_contratos(venc_gcp_rocio, "Rocío", dias_para_vencimento=30)
contratos_iir_coord = verificar_vencimento_contratos(venc_gcp_iir_coord, "IRR COORD", dias_para_vencimento=30)
contratos_vivi = verificar_vencimento_contratos(venc_gcp_envio_viviane, "Envio Viviane", dias_para_vencimento=30)
contratos_stacsantos = verificar_vencimento_contratos(venc_gcp_stacasa_santos, "Santa Casa de Santos", dias_para_vencimento=30)
contratos_capibaribe = verificar_vencimento_contratos(venc_gcp_capibaribe, "Capibaribe", dias_para_vencimento=30)
# Out:
# ⚠️HMCG - Os profissionais abaixo listados não tem data de GCP na PoloTrial ou a data informada irá vencer nos próximos 30 dias:
#                              Centro  \
# 1149             Clínica CardialMed
# 1450             Clínica CardialMed
# 2015             Clínica CardialMed
# 2100             Clínica CardialMed
# 312   Hospital Municipal de Barueri
# ...                             ...
# 1112                Leforte Morumbi
# 1452                Leforte Morumbi
# 1482                Leforte Morumbi
# 1751                Leforte Morumbi
# 1065  Não há data cadastrada
# 1100  Não há data cadastrada
# 1114         Data cadastrada
# 1153  Não há data cadastrada
# 1165  Não há data cadastrada
# 1184  Não há data cadastrada
# 1194  Não há data cadastrada
# 1195  Não há data cadastrada
# 1201  Não há data cadastrada
# 1236  Não há data cadastrada
# 1286  Não há data cadastrada
# 1290  Não há data cadastrada
# 1294  Não há data cadastrada
# 1308  Não há data cadastrada
# 1314  Não há data cadastrada
# 1359  Não há data cadastrada
# 1352  Não há data cadastrada
# 1363  Não há data cadastrada
# 1365  Não há data cadastrada
# 1380  Não há data cadastrada
# 1383  Não há data cadastrada
# 1396  Não há data cadastrada
# 1401  Não há data cadastrada
# 1403  Não há data cadastrada
# 1455  Não há data cadastrada
# 1483  Não há data cadastrada
# 1576  Não há data cadastrada
# 1580  Não há data cadastrada
# 1676  Não há data cadastrada
# 1675  Não há data cadastrada
# 1707  Não há data cadastrada
# 2751  Não há data cadastrada
# 2761  Não há data cadastrada
# 2762  Não há data cadastrada
# 2763  Não há data cadastrada
# 2877  Não há data cadastrada
# 3171  Não há data cadastrada
# 3338  Não há data cadastrada
# 3388  Não há data cadastrada
# 3391  Não há data cadastrada
# 3392  Não há data cadastrada
# 3479  Não há data cadastrada
# 3478  Não há data cadastrada
# 3771  Não há data cadastrada
# 3772  Não há data cadastrada
# ⚠️Capiberibe - Os profissionais abaixo listados não tem data de GCP na PoloTrial ou a data informada irá vencer nos próximos 30 dias:
#                       Centro                                 Nome  \
# 2800  Hospital do Capibaribe  Mariane Teodoro Fernandes Rodrigues
#
#                      Função Status do Cadastro Assinatura do GCP  \
# 2800  Pesquisador Principal              Ativo               NaT
#
#             Cadastro de data
# 2800  Não há data cadastrada

# %% [markdown]
# ***Função para envio dos emails de GCP

# %%
css_hover = """
<style>
/* Reset básico */
table {
    border-collapse: collapse;
    width: 100%;
    font-family: Arial, Helvetica, sans-serif;
    font-size: 13px;
}

/* Cabeçalho */
th {
    background-color: #007bff;
    color: #ffffff;
    border: 1px solid #d0d0d0;
    padding: 8px;
    text-align: left;
    font-weight: bold;
}

/* Células */
td {
    border: 1px solid #d0d0d0;
    padding: 8px;
    text-align: left;
    vertical-align: middle;
    color: #000000;
}

/* Linhas alternadas (mais compatível que hover) */
tr:nth-child(even) {
    background-color: #f8f9fa;
}

/* Hover (funciona em Gmail/Web, ignorado no Outlook) */
tr:hover {
    background-color: #fff3cd;
}

/* Responsividade simples */
@media screen and (max-width: 600px) {
    table {
        font-size: 12px;
    }
}
</style>
"""

# %% [markdown]
# Variáveis de envio de email

# %%
smtp_server = os.getenv("EMAIL_SERVER")
email_port = int(os.getenv("EMAIL_PORT"))
email_usuario = os.getenv("EMAIL_USERNAME")
email_senha = os.getenv("EMAIL_PASSWORD")
enviar_para = os.getenv('ENVIAR_PARA')
destinatario_hmcg = os.getenv('DESTINATARIO_HMCG')
destinatario_rocio =  os.getenv('DESTINATARIO_ROCIO')
destinatario_scs = os.getenv('DESTINATARIO_SCS')
destinatario_iir =  os.getenv('DESTINATARIO_IIR')
destinatario_vivi =  os.getenv('DESTINATARIO_VIVIANE')
destinatario_capibaribe =  os.getenv('DESTINATARIO_CAPIBARIBE')

# %%
def enviar_email(destinatarios, df_tratado, nome_grupo):
    if df_tratado is None or df_tratado.empty:
        print("Não há contratos vencidos para enviar por e-mail.")
        return

    try:
        # Garante lista de destinatários
        if isinstance(destinatarios, str):
            destinatarios = [destinatarios]

        # Tabela HTML
        colunas = ['Centro', 'Nome', 'Função','Status do Cadastro', 'Assinatura do GCP', "Cadastro de data"]
        tabela_html = df_tratado[colunas].to_html(
            index=False,
            escape=False,
            border=0,
            justify="left",
            classes="table"
        )

        # Configuração do e-mail
        msg = MIMEMultipart("alternative")
        msg["From"] = email_usuario
        msg["To"] = email_usuario
        msg["Bcc"] = ", ".join(destinatarios)
        msg["Subject"] = f"[{nome_grupo}] GCP sem data registrada ou com vencimento próximo"

        body = f"""
        <html>
            <head>{css_hover}</head>
            <body>
                <h2>Vencimento de GCP - {nome_grupo}</h2>

                <p>Bom dia,</p>

                <p>
                    Segue abaixo relação de GCPs que não possuem data registradano sistema ou que apresentam vencimento próximo:
                </p>
                {tabela_html}
                <br>
                <p>
                    Este e-mail é gerado automaticamente a partir de informações inseridas na <strong>Polo Trial</strong>.
                </p>
                <p>
                    Qualquer dúvida, por favor, contate o <strong><u>time BI - SVRI</u></strong>.
                </p>
            </body>
        </html>
        """

        msg.attach(MIMEText(body, "html"))

        # Envio
        with smtplib.SMTP(smtp_server, email_port) as server:
            server.starttls()
            server.login(email_usuario, email_senha)
            server.send_message(msg)

        print(f"E-mail enviado com sucesso para o grupo: {nome_grupo}")

    except Exception as e:
        print(f"Erro ao enviar o e-mail: {e}")

# %%
enviar_email([destinatario_hmcg], contratos_hmcg, "HMCG")
enviar_email([destinatario_rocio], contratos_rocio, "Rocio")
enviar_email([destinatario_iir], contratos_iir_coord, "IIR")
enviar_email([destinatario_scs], contratos_stacsantos, "Sta. Santos")
enviar_email([destinatario_vivi], contratos_vivi, "Viviane")
enviar_email([destinatario_capibaribe], contratos_capibaribe, "Capibaribe")
# Out:
# E-mail enviado com sucesso para o grupo: HMCG
# E-mail enviado com sucesso para o grupo: Rocio
# E-mail enviado com sucesso para o grupo: IIR
# E-mail enviado com sucesso para o grupo: Sta. Santos
# E-mail enviado com sucesso para o grupo: Viviane
# E-mail enviado com sucesso para o grupo: Capiberibe

# %% [markdown]
# ***Modelagem para envio de Visitas de Seguimento

# %%
protocolo = pd.DataFrame(protocolos_dataframe)
protocolo.head(5)
# Out:
#      id                                   titulo_protocolo cor_agenda  \
# 0   784  Um estudo randomizado, duplo-cego, controlado ...    #000000
# 1  1256  Estudo VISIONAIRE (Vitamin K AntagonISt, Facto...    #000000
# 2  1661  Um ensaio randomizado, controlado por placebo,...    #9a514c
# 3  2229  Estudo de fase II, multicêntrico, duplo-cego, ...    #000000
# 4  2372  Estudo randomizado, multicêntrico, duplo cego,...    #000000
#
#    numero_protocolo apelido_protocolo  coordenador    pi pesquisador_backup  \
# 0  LX4211.1-314-HCM        SONATA-HCM       2631.0   271                NaN
# 1                          VISIONAIRE       2829.0  3050                NaN
# 2       BIOTEST-996       EsSCAPE-996        239.0   250                NaN
# 3           CS45570           CS45570       4528.0   319                NaN
# 4                         Oxandrolona       2622.0  4166             3662.0
#
#    co_pessoa_regulatorio             data_cadastro  ...  \
# 0                 2631.0  2023-07-17T10:14:16.000Z  ...
# 1                 2631.0  2023-11-30T09:28:12.000Z  ...
# 2                 2807.0  2024-06-07T14:43:21.000Z  ...
# 3                 2631.0  2024-11-26T11:25:36.000Z  ...
# 4                 2631.0  2025-03-17T15:54:16.000Z  ...
#
#    dados_medicamento_do_estudo       dados_pendencias_regulatorio  \
# 0                         None  {'id': 40, 'ds_descricao': 'Sim'}
# 1                         None  {'id': 40, 'ds_descricao': 'Sim'}
# 2                         None  {'id': 40, 'ds_descricao': 'Sim'}
# 3                         None  {'id': 40, 'ds_descricao': 'Sim'}
# 4                         None  {'id': 41, 'ds_descricao': 'Não'}
#
#                     dados_status_feasibility  \
# 0  {'id': 824, 'ds_descricao': 'Respondido'}
# 1  {'id': 824, 'ds_descricao': 'Respondido'}
# 2  {'id': 824, 'ds_descricao': 'Respondido'}
# 3  {'id': 824, 'ds_descricao': 'Respondido'}
# 4  {'id': 824, 'ds_descricao': 'Respondido'}
#
#                                dados_status_contrato  \
# 0  {'id': 9, 'ds_descricao': 'Em negociação com o...
# 1            {'id': 908, 'ds_descricao': 'Assinado'}
# 2                                               None
# 3            {'id': 908, 'ds_descricao': 'Assinado'}
# 4            {'id': 908, 'ds_descricao': 'Assinado'}
#
#                     dados_status_orcamento  \
# 0                                     None
# 1  {'id': 877, 'ds_descricao': 'Aprovado'}
# 2                                     None
# 3                                     None
# 4                                     None
#
#                            dados_status_regulatorio  \
# 0           {'id': 914, 'ds_descricao': 'Aprovado'}
# 1  {'id': 918, 'ds_descricao': 'Em análise do CEP'}
# 2           {'id': 914, 'ds_descricao': 'Aprovado'}
# 3           {'id': 914, 'ds_descricao': 'Aprovado'}
# 4           {'id': 914, 'ds_descricao': 'Aprovado'}
#
#                            dados_status_recrutamento  dados_status_financeiro  \
# 0                                               None                     None
# 1                                               None                     None
# 2  {'id': 936, 'ds_descricao': 'Recrutamento aber...                     None
# 3  {'id': 928, 'ds_descricao': 'Aguardando ativaç...                     None
# 4                                               None                     None
#
#    dados_assistente_de_pesquisa            dados_dificuldade_recrutamento
# 0                          None  {'id': 9292, 'ds_descricao': 'Moderado'}
# 1                          None                                      None
# 2                          None  {'id': 9292, 'ds_descricao': 'Moderado'}
# 3                          None   {'id': 9291, 'ds_descricao': 'Difícil'}
# 4                          None  {'id': 9292, 'ds_descricao': 'Moderado'}
#
# [5 rows x 142 columns]

# %%
centros = protocolo[['id','apelido_protocolo', 'numero_protocolo','co_externo','apelido_centro']].copy()
centros.head(5)
# Out:
#      id apelido_protocolo  numero_protocolo co_externo  \
# 0   784        SONATA-HCM  LX4211.1-314-HCM       None
# 1  1256        VISIONAIRE                         None
# 2  1661       EsSCAPE-996       BIOTEST-996       None
# 3  2229           CS45570           CS45570       None
# 4  2372       Oxandrolona                         None
#
#                                       apelido_centro
# 0                    SONATA-HCM - Clínica CardialMed
# 1                  VISIONAIRE - SVRI Clínica Morumbi
# 2  EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# 3                             CS45570 - Leforte HMCG
# 4                 Oxandrolona - Santa Casa de Santos

# %%
seguimento = agenda_df[['dados_participante', 'data_estimada', 'dados_status', 'dados_visita']].copy()

seguimento.loc[:, 'dados_participante_id'] = seguimento['dados_participante'].apply(lambda x: x['id'] if x is not None else None)
seguimento.loc[:, 'id_participante'] = seguimento['dados_participante'].apply(lambda x: x['id_participante'] if x is not None else None)
seguimento.loc[:, 'dados_protocolo'] = seguimento['dados_participante'].apply(lambda x: x['dados_protocolo'] if x is not None else None)

seguimento.loc[:, 'dados_status_id'] = seguimento['dados_status'].apply(lambda x: x['id'] if x is not None else None)
seguimento.loc[:, 'ds_descricao'] = seguimento['dados_status'].apply(lambda x: x['ds_descricao'] if x is not None else None)
seguimento.loc[:, 'ds_nome_visita'] = seguimento['dados_visita'].apply(lambda x: x['ds_nome_visita'] if x is not None else None)

seguimento.loc[:, 'apelido_protocolo'] = seguimento['dados_protocolo'].apply(lambda x: x['apelido_protocolo'] if x is not None else None)
seguimento['data_estimada'] = pd.to_datetime(seguimento['data_estimada'], errors='coerce')
seguimento.head(5)
# Out:
#                                   dados_participante  \
# 0  {'id': 54, 'co_protocolo': 4, 'id_participante...
# 1  {'id': 56, 'co_protocolo': 4, 'id_participante...
# 2  {'id': 57, 'co_protocolo': 4, 'id_participante...
# 3  {'id': 58, 'co_protocolo': 4, 'id_participante...
# 4  {'id': 59, 'co_protocolo': 4, 'id_participante...
#
#               data_estimada                             dados_status  \
# 0 2021-01-05 00:00:00+00:00  {'id': 20, 'ds_descricao': 'Realizada'}
# 1 2021-01-07 00:00:00+00:00  {'id': 20, 'ds_descricao': 'Realizada'}
# 2 2021-01-08 00:00:00+00:00  {'id': 20, 'ds_descricao': 'Realizada'}
# 3 2021-01-12 00:00:00+00:00  {'id': 20, 'ds_descricao': 'Realizada'}
# 4 2021-01-14 00:00:00+00:00  {'id': 20, 'ds_descricao': 'Realizada'}
#
#                                         dados_visita  dados_participante_id  \
# 0  {'id': 1, 'ds_nome_visita': 'Triagem ', 'co_ex...                     54
# 1  {'id': 1, 'ds_nome_visita': 'Triagem ', 'co_ex...                     56
# 2  {'id': 1, 'ds_nome_visita': 'Triagem ', 'co_ex...                     57
# 3  {'id': 1, 'ds_nome_visita': 'Triagem ', 'co_ex...                     58
# 4  {'id': 1, 'ds_nome_visita': 'Triagem ', 'co_ex...                     59
#
#   id_participante                                    dados_protocolo  \
# 0            1001  {'id': 4, 'apelido_protocolo': 'BTK', 'co_coor...
# 1            1002  {'id': 4, 'apelido_protocolo': 'BTK', 'co_coor...
# 2            1003  {'id': 4, 'apelido_protocolo': 'BTK', 'co_coor...
# 3            1004  {'id': 4, 'apelido_protocolo': 'BTK', 'co_coor...
# 4            1005  {'id': 4, 'apelido_protocolo': 'BTK', 'co_coor...
#
#    dados_status_id ds_descricao ds_nome_visita apelido_protocolo
# 0               20    Realizada       Triagem                BTK
# 1               20    Realizada       Triagem                BTK
# 2               20    Realizada       Triagem                BTK
# 3               20    Realizada       Triagem                BTK
# 4               20    Realizada       Triagem                BTK

# %%
seguimento_tratado = seguimento.drop(['dados_participante','dados_status','id_participante','dados_status_id'], axis=1)
seguimento_tratado.loc[:, 'id'] = seguimento['dados_protocolo'].apply(lambda x: x['id'] if x is not None else None)
seguimento_tratado.head(5)
# Out:
#               data_estimada  \
# 0 2021-01-05 00:00:00+00:00
# 1 2021-01-07 00:00:00+00:00
# 2 2021-01-08 00:00:00+00:00
# 3 2021-01-12 00:00:00+00:00
# 4 2021-01-14 00:00:00+00:00
#
#                                         dados_visita  dados_participante_id  \
# 0  {'id': 1, 'ds_nome_visita': 'Triagem ', 'co_ex...                     54
# 1  {'id': 1, 'ds_nome_visita': 'Triagem ', 'co_ex...                     56
# 2  {'id': 1, 'ds_nome_visita': 'Triagem ', 'co_ex...                     57
# 3  {'id': 1, 'ds_nome_visita': 'Triagem ', 'co_ex...                     58
# 4  {'id': 1, 'ds_nome_visita': 'Triagem ', 'co_ex...                     59
#
#                                      dados_protocolo ds_descricao  \
# 0  {'id': 4, 'apelido_protocolo': 'BTK', 'co_coor...    Realizada
# 1  {'id': 4, 'apelido_protocolo': 'BTK', 'co_coor...    Realizada
# 2  {'id': 4, 'apelido_protocolo': 'BTK', 'co_coor...    Realizada
# 3  {'id': 4, 'apelido_protocolo': 'BTK', 'co_coor...    Realizada
# 4  {'id': 4, 'apelido_protocolo': 'BTK', 'co_coor...    Realizada
#
#   ds_nome_visita apelido_protocolo  id
# 0       Triagem                BTK   4
# 1       Triagem                BTK   4
# 2       Triagem                BTK   4
# 3       Triagem                BTK   4
# 4       Triagem                BTK   4

# %%
seguimentos = pd.merge(centros, seguimento_tratado, on='id', how='inner')
seguimentos
# Out:
#        id apelido_protocolo_x  numero_protocolo co_externo  \
# 0     784          SONATA-HCM  LX4211.1-314-HCM       None
# 1     784          SONATA-HCM  LX4211.1-314-HCM       None
# 2     784          SONATA-HCM  LX4211.1-314-HCM       None
# 3     784          SONATA-HCM  LX4211.1-314-HCM       None
# 4     784          SONATA-HCM  LX4211.1-314-HCM       None
# ..    ...                 ...               ...        ...
# 895  1531                 DLG                          NaN
# 896  1531                 DLG                          NaN
# 897  1531                 DLG                          NaN
# 898  1531                 DLG                          NaN
# 899  1531                 DLG                          NaN
#
#                       apelido_centro             data_estimada  \
# 0    SONATA-HCM - Clínica CardialMed 2026-01-16 00:00:00+00:00
# 1    SONATA-HCM - Clínica CardialMed 2026-01-16 00:00:00+00:00
# 2    SONATA-HCM - Clínica CardialMed                       NaT
# 3    SONATA-HCM - Clínica CardialMed                       NaT
# 4    SONATA-HCM - Clínica CardialMed 2026-02-06 00:00:00+00:00
# ..                               ...                       ...
# 895       DLG - Santa Casa de Santos 2025-09-30 00:00:00+00:00
# 896       DLG - Santa Casa de Santos 2025-10-07 00:00:00+00:00
# 897       DLG - Santa Casa de Santos 2025-10-14 00:00:00+00:00
# 898       DLG - Santa Casa de Santos 2025-10-21 00:00:00+00:00
# 899       DLG - Santa Casa de Santos                       NaT
#
#                                           dados_visita  dados_participante_id  \
# 0    {'id': 3405, 'ds_nome_visita': 'Visita 1 - Tri...                   3286
# 1    {'id': 3405, 'ds_nome_visita': 'Visita 1 - Tri...                   3287
# 2    {'id': 3412, 'ds_nome_visita': 'Visita de ence...                   3287
# 3    {'id': 3414, 'ds_nome_visita': 'Unscheduled', ...                   3287
# 4    {'id': 3406, 'ds_nome_visita': 'Visita 2 - Ran...                   3287
# ..                                                 ...                    ...
# 895  {'id': 2996, 'ds_nome_visita': 'V4 - Dia 42', ...                   3192
# 896  {'id': 2997, 'ds_nome_visita': 'CT4 - Dia 49',...                   3192
# 897  {'id': 2998, 'ds_nome_visita': 'V5 - Dia 56', ...                   3192
# 898  {'id': 2999, 'ds_nome_visita': 'Visita de Desc...                   3192
# 899  {'id': 3072, 'ds_nome_visita': 'V1pk - Dia 1',...                   3192
#
#                                        dados_protocolo   ds_descricao  \
# 0    {'id': 784, 'apelido_protocolo': 'SONATA-HCM',...      Realizada
# 1    {'id': 784, 'apelido_protocolo': 'SONATA-HCM',...      Realizada
# 2    {'id': 784, 'apelido_protocolo': 'SONATA-HCM',...       Pendente
# 3    {'id': 784, 'apelido_protocolo': 'SONATA-HCM',...       Pendente
# 4    {'id': 784, 'apelido_protocolo': 'SONATA-HCM',...       Pendente
# ..                                                 ...            ...
# 895  {'id': 1531, 'apelido_protocolo': 'DLG', 'co_c...      Realizada
# 896  {'id': 1531, 'apelido_protocolo': 'DLG', 'co_c...      Realizada
# 897  {'id': 1531, 'apelido_protocolo': 'DLG', 'co_c...      Realizada
# 898  {'id': 1531, 'apelido_protocolo': 'DLG', 'co_c...      Realizada
# 899  {'id': 1531, 'apelido_protocolo': 'DLG', 'co_c...  Não realizada
#
#                                         ds_nome_visita apelido_protocolo_y
# 0                                   Visita 1 - Triagem          SONATA-HCM
# 1                                   Visita 1 - Triagem          SONATA-HCM
# 2                       Visita de encerramento precoce          SONATA-HCM
# 3                                          Unscheduled          SONATA-HCM
# 4                              Visita 2 - Randomização          SONATA-HCM
# ..                                                 ...                 ...
# 895                                        V4 - Dia 42                 DLG
# 896                                       CT4 - Dia 49                 DLG
# 897                                        V5 - Dia 56                 DLG
# 898  Visita de Descontinuação VD (Caso o paciente s...                 DLG
# 899                                       V1pk - Dia 1                 DLG
#
# [900 rows x 12 columns]

# %%
seguimentos['apelido_protocolo_x'] = seguimentos['apelido_protocolo_x'].str.strip()
visitas_filtrado = seguimentos[seguimentos['ds_descricao'].str.contains('Pendente')]
nova_ordem = ["apelido_centro", "dados_participante_id", "ds_nome_visita","data_estimada","ds_descricao"]
visitas_reordenado = visitas_filtrado[nova_ordem].rename(
    columns={
        'apelido_centro':'Estudo/Centro',
        'dados_participante_id': 'ID Participante',
        'ds_nome_visita': 'Tipo Visita',
        'data_estimada':'Data Estimada',
        'ds_descricao':'Status'
    }
)
visitas_reordenado['Data Estimada'] = pd.to_datetime(visitas_reordenado['Data Estimada'], errors='coerce')
visitas_reordenado
# Out:
#                                          Estudo/Centro  ID Participante  \
# 2                      SONATA-HCM - Clínica CardialMed             3287
# 3                      SONATA-HCM - Clínica CardialMed             3287
# 4                      SONATA-HCM - Clínica CardialMed             3287
# 5                      SONATA-HCM - Clínica CardialMed             3287
# 6                      SONATA-HCM - Clínica CardialMed             3287
# ..                                                 ...              ...
# 865  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...             3139
# 866  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...             3139
# 867  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...             3139
# 868  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...             3139
# 869  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...             3139
#
#                           Tipo Visita             Data Estimada    Status
# 2      Visita de encerramento precoce                       NaT  Pendente
# 3                         Unscheduled                       NaT  Pendente
# 4             Visita 2 - Randomização 2026-02-06 00:00:00+00:00  Pendente
# 5    Visita 3 - Semana 2 (Telefônica) 2026-02-20 00:00:00+00:00  Pendente
# 6                 Visita 4 - Semana 4 2026-03-06 00:00:00+00:00  Pendente
# ..                                ...                       ...       ...
# 865                         Visita 16 2028-06-01 00:00:00+00:00  Pendente
# 866                                FU                       NaT  Pendente
# 867            Visita Não Programada                        NaT  Pendente
# 868                               EOS                       NaT  Pendente
# 869           Visita Não Programada 2                       NaT  Pendente
#
# [485 rows x 5 columns]

# %%
datas_visitas = visitas_reordenado.copy()
datas_visitas['Data Estimada'] = pd.to_datetime(datas_visitas['Data Estimada'], errors='coerce')
datas_visitas = visitas_reordenado.dropna(subset=["Data Estimada"])
datas_visitas = datas_visitas.sort_values(by= "Data Estimada", ascending=True)
datas_visitas = datas_visitas[~datas_visitas["Tipo Visita"].isin(["Unscheduled", "Triagem", "End of Study"])]
valores_contagem = datas_visitas['Tipo Visita'].value_counts()
datas_visitas
# Out:
#                                          Estudo/Centro  ID Participante  \
# 564                             FREXALT - Leforte HMCG             3296
# 557                             FREXALT - Leforte HMCG             3291
# 535                             FREXALT - Leforte HMCG             3138
# 514                             FREXALT - Leforte HMCG             3133
# 94                              CS45570 - Leforte HMCG             3273
# ..                                                 ...              ...
# 771  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...             3265
# 801  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...             3269
# 815  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...             3268
# 829  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...             3270
# 849  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...             3282
#
#                 Tipo Visita             Data Estimada    Status
# 564  V2 - D1 - Randomização 2026-01-28 00:00:00+00:00  Pendente
# 557  V2 - D1 - Randomização 2026-02-04 00:00:00+00:00  Pendente
# 535               Semana 28 2026-02-04 00:00:00+00:00  Pendente
# 514               Semana 28 2026-02-04 00:00:00+00:00  Pendente
# 94                 Semana 6 2026-02-04 00:00:00+00:00  Pendente
# ..                      ...                       ...       ...
# 771               Visita 16 2028-09-04 00:00:00+00:00  Pendente
# 801               Visita 16 2028-09-26 00:00:00+00:00  Pendente
# 815               Visita 16 2028-09-27 00:00:00+00:00  Pendente
# 829               Visita 16 2028-10-02 00:00:00+00:00  Pendente
# 849               Visita 16 2028-11-07 00:00:00+00:00  Pendente
#
# [320 rows x 5 columns]

# %%
def verificar_visitas_proximos_dias(datas_visitas, dias_para_visita=20):
    df = datas_visitas.copy()

    df['Data Estimada'] = (
        pd.to_datetime(df['Data Estimada'], errors='coerce')
        .dt.tz_localize(None)   # 👈 REMOVE UTC
    )

    hoje = pd.Timestamp.today().normalize()
    limite_visita = hoje + pd.Timedelta(days=dias_para_visita)

    visitas_futuras = df[
        (df['Data Estimada'] >= hoje) &
        (df['Data Estimada'] <= limite_visita)
    ]

    return visitas_futuras

visitas_20_dias = verificar_visitas_proximos_dias(datas_visitas, dias_para_visita=20)

# %%
def enviar_emails(próximas_visitas):
    global enviar_para  # Acessa a variável global 'enviar_para'
    
    try:
        if próximas_visitas is None or próximas_visitas.empty:
            print("Não há visitas nos próximos dias para enviar por e-mail.")
            return

        colunas_esperadas = {'Estudo/Centro', 'ID Participante', 'Tipo Visita', 'Data Estimada', 'Status'}
        if not colunas_esperadas.issubset(próximas_visitas.columns):
            print("Erro: DataFrame não contém todas as colunas esperadas.")
            return

        if not all([smtp_server, email_usuario, email_senha, email_port]):
            print("Erro: Configurações de e-mail estão incompletas.")
            return

        # Validação de e-mails com regex
        email_regex = r'^[\w\.-]+@[\w\.-]+\.\w+$'
        if isinstance(enviar_para, list):
            enviar_para = [email.strip() for email in enviar_para if email.strip() and re.match(email_regex, email.strip())]
        else:
            enviar_para = []

        # Criação da tabela HTML
        tabela_html = próximas_visitas[list(colunas_esperadas)].to_html(
            index=False, escape=False, justify="left", border=0, classes="table"
        )

        # Montagem da mensagem
        msg = MIMEMultipart("alternative")
        msg['From'] = email_usuario
        msg['To'] = email_usuario
        msg['Subject'] = "Visitas de Seguimento - próximos 20 dias"
        
        # Define o campo BCC apenas se houver destinatários válidos
        if enviar_para:
            msg['Bcc'] = ', '.join(enviar_para)

        body = f"""
        <html>
            <head>{css_hover}</head>
            <body>
                <p>Olá,</p>
                <p>Segue abaixo lista com visitas de seguimento programadas para os próximos 20 dias.</p>
                {tabela_html}
                <p>Este email é gerado automaticamente a partir de informações inseridas na Polo Trial.</p>
                <p>Qualquer dúvida, por favor, contate o <strong><span style="text-decoration: underline;">time BI - SVRI</span></strong>.</p>
            </body>
        </html>
        """
        msg.attach(MIMEText(body, 'html'))

        # Envio de e-mail
        with smtplib.SMTP(smtp_server, email_port) as server:
            server.starttls()
            server.login(email_usuario, email_senha)
            
            # Lista final de destinatários
            destinatarios = [email_usuario] + enviar_para
            if destinatarios:
                server.sendmail(email_usuario, destinatarios, msg.as_string())
                print("E-mail de visitas pendentes enviado com sucesso!")
            else:
                print("Nenhum destinatário válido. E-mail não enviado.")

    except Exception as e:
        print(f"Erro ao enviar o e-mail: {e}")

# Chamada da função
enviar_emails(visitas_20_dias)
# Out:
# E-mail de visitas pendentes enviado com sucesso!

# %% [markdown]
# **** Visitas de Monitoria

# %%
monitoria_df
# Out:
#           id  tipo_evento                   titulo ds_co_industria ds_co_hc  \
# 0          1            1               Centriguga
# 1          4            1              contrato V6
# 2          5            1        contrato_ Graviti
# 3          6            1        contrato_ Graviti
# 4          7            1           Vencimento GCP
# ...      ...          ...                      ...             ...      ...
# 17170  40190            2                Visita 16      1076012009  1076012
# 17171  40192            2                       FU      1076012009  1076012
# 17172  40193            2   Visita Não Programada       1076012009  1076012
# 17173  40194            2                      EOS      1076012009  1076012
# 17174  40195            2  Visita Não Programada 2      1076012009  1076012
#
#       co_participante  tipo  status_evento             data_estimada  \
# 0                         4             20  2022-04-28T00:00:00.000Z
# 1                         6             20  2022-07-06T00:00:00.000Z
# 2                         6             20  2022-12-29T00:00:00.000Z
# 3                         6             20  2022-12-29T00:00:00.000Z
# 4                         7             20  2025-08-16T00:00:00.000Z
# ...               ...   ...            ...                       ...
# 17170            3139     1             18  2028-06-01T00:00:00.000Z
# 17171            3139     1             18                       NaN
# 17172            3139     1             18                       NaN
# 17173            3139     1             18                       NaN
# 17174            3139     1             18                       NaN
#
#               data_estimada_fim  ... co_externo           data_limite_min  \
# 0                           NaN  ...       None                       NaN
# 1                           NaN  ...       None                       NaN
# 2                           NaN  ...       None                       NaN
# 3                           NaN  ...       None                       NaN
# 4      2025-08-16T00:00:00.000Z  ...       None                       NaN
# ...                         ...  ...        ...                       ...
# 17170                       NaN  ...       None  2028-05-11T00:00:00.000Z
# 17171                       NaN  ...       None                       NaN
# 17172                       NaN  ...       None                       NaN
# 17173                       NaN  ...       None                       NaN
# 17174                       NaN  ...       None                       NaN
#
#                 data_limite_max                data_ideal  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# ...                         ...                       ...
# 17170  2028-06-22T00:00:00.000Z  2028-06-01T00:00:00.000Z
# 17171                       NaN                       NaN
# 17172                       NaN                       NaN
# 17173                       NaN                       NaN
# 17174                       NaN                       NaN
#
#                                 dados_tipo  \
# 0          {'id': 4, 'tipo': 'Calibração'}
# 1            {'id': 6, 'tipo': 'Contrato'}
# 2            {'id': 6, 'tipo': 'Contrato'}
# 3            {'id': 6, 'tipo': 'Contrato'}
# 4      {'id': 7, 'tipo': 'Vencimento GCP'}
# ...                                    ...
# 17170          {'id': 1, 'tipo': 'Visita'}
# 17171          {'id': 1, 'tipo': 'Visita'}
# 17172          {'id': 1, 'tipo': 'Visita'}
# 17173          {'id': 1, 'tipo': 'Visita'}
# 17174          {'id': 1, 'tipo': 'Visita'}
#
#                                   dados_status  \
# 0      {'id': 20, 'ds_descricao': 'Realizada'}
# 1      {'id': 20, 'ds_descricao': 'Realizada'}
# 2      {'id': 20, 'ds_descricao': 'Realizada'}
# 3      {'id': 20, 'ds_descricao': 'Realizada'}
# 4      {'id': 20, 'ds_descricao': 'Realizada'}
# ...                                        ...
# 17170   {'id': 18, 'ds_descricao': 'Pendente'}
# 17171   {'id': 18, 'ds_descricao': 'Pendente'}
# 17172   {'id': 18, 'ds_descricao': 'Pendente'}
# 17173   {'id': 18, 'ds_descricao': 'Pendente'}
# 17174   {'id': 18, 'ds_descricao': 'Pendente'}
#
#                                          dados_protocolo  \
# 0                                                   None
# 1      {'id': 53, 'apelido_protocolo': 'Dipro', 'co_c...
# 2      {'id': 322, 'apelido_protocolo': 'Graviti', 'c...
# 3      {'id': 322, 'apelido_protocolo': 'Graviti', 'c...
# 4                                                   None
# ...                                                  ...
# 17170  {'id': 655, 'apelido_protocolo': 'EASi-HF - 13...
# 17171  {'id': 655, 'apelido_protocolo': 'EASi-HF - 13...
# 17172  {'id': 655, 'apelido_protocolo': 'EASi-HF - 13...
# 17173  {'id': 655, 'apelido_protocolo': 'EASi-HF - 13...
# 17174  {'id': 655, 'apelido_protocolo': 'EASi-HF - 13...
#
#                                       dados_participante  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 17170  {'id': 3139, 'id_participante': '1076012009', ...
# 17171  {'id': 3139, 'id_participante': '1076012009', ...
# 17172  {'id': 3139, 'id_participante': '1076012009', ...
# 17173  {'id': 3139, 'id_participante': '1076012009', ...
# 17174  {'id': 3139, 'id_participante': '1076012009', ...
#
#                                        dados_responsavel  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4      {'id': 239, 'ds_nome': 'Caroline Pinheiro Vian...
# ...                                                  ...
# 17170                                               None
# 17171                                               None
# 17172                                               None
# 17173                                               None
# 17174                                               None
#
#                                   dados_local
# 0                                        None
# 1                                        None
# 2                                        None
# 3                                        None
# 4      {'id': 765, 'ds_descricao': 'Virtual'}
# ...                                       ...
# 17170                                    None
# 17171                                    None
# 17172                                    None
# 17173                                    None
# 17174                                    None
#
# [17175 rows x 43 columns]

# %%
monitoria = monitoria_df[['dados_protocolo', 'dados_tipo', 'dados_status', 'data_estimada_filter']].copy()

monitoria.loc[:, 'dados_protocolo_id'] = monitoria['dados_protocolo'].apply(lambda x: x['id'] if x is not None else None)
monitoria.loc[:, 'apelido_protocolo'] = monitoria['dados_protocolo'].apply(lambda x: x['apelido_protocolo'] if x is not None else None)

monitoria.loc[:, 'dados_tipo_id'] = monitoria['dados_tipo'].apply(lambda x: x['id'] if x is not None else None)
monitoria.loc[:, 'dados_tipo_tipo'] = monitoria['dados_tipo'].apply(lambda x: x['tipo'] if x is not None else None)

monitoria.loc[:, 'dados_status_id'] = monitoria['dados_status'].apply(lambda x: x['id'] if x is not None else None)
monitoria.loc[:, 'ds_descricao'] = monitoria['dados_status'].apply(lambda x: x['ds_descricao'] if x is not None else None)

monitoria = monitoria.drop(['dados_protocolo','dados_status', 'dados_tipo_id','dados_status_id'], axis=1)
monitoria.rename(columns={'dados_protocolo_id': 'id'}, inplace=True)

monitoria.head(2)
# Out:
#                         dados_tipo data_estimada_filter    id  \
# 0  {'id': 4, 'tipo': 'Calibração'}           2022-04-28   NaN
# 1    {'id': 6, 'tipo': 'Contrato'}           2022-07-06  53.0
#
#   apelido_protocolo dados_tipo_tipo ds_descricao
# 0               NaN      Calibração    Realizada
# 1             Dipro        Contrato    Realizada

# %%
monitorias = pd.merge(centros, monitoria, on='id', how='inner')
monitorias
# Out:
#        id           apelido_protocolo_x  numero_protocolo co_externo  \
# 0     784                    SONATA-HCM  LX4211.1-314-HCM       None
# 1     784                    SONATA-HCM  LX4211.1-314-HCM       None
# 2     784                    SONATA-HCM  LX4211.1-314-HCM       None
# 3     784                    SONATA-HCM  LX4211.1-314-HCM       None
# 4     784                    SONATA-HCM  LX4211.1-314-HCM       None
# ..    ...                           ...               ...        ...
# 973  1531                           DLG                          NaN
# 974  1531                           DLG                          NaN
# 975  1531                           DLG                          NaN
# 976  2230  EASi-HF reduzido - 1378-0018         1378-0018        NaN
# 977  1168                    DURAVELO-2        BT8009-230       None
#
#                                         apelido_centro  \
# 0                      SONATA-HCM - Clínica CardialMed
# 1                      SONATA-HCM - Clínica CardialMed
# 2                      SONATA-HCM - Clínica CardialMed
# 3                      SONATA-HCM - Clínica CardialMed
# 4                      SONATA-HCM - Clínica CardialMed
# ..                                                 ...
# 973                         DLG - Santa Casa de Santos
# 974                         DLG - Santa Casa de Santos
# 975                         DLG - Santa Casa de Santos
# 976  EASi-HF reduzido - 1378-0018 - Maternidade e C...
# 977                DURAVELO-2 - Hospital do Capibaribe
#
#                          dados_tipo data_estimada_filter  \
# 0    {'id': 2, 'tipo': 'Monitoria'}           2026-02-13
# 1       {'id': 1, 'tipo': 'Visita'}           2026-01-16
# 2       {'id': 1, 'tipo': 'Visita'}           2026-01-16
# 3       {'id': 1, 'tipo': 'Visita'}                  NaN
# 4       {'id': 1, 'tipo': 'Visita'}                  NaN
# ..                              ...                  ...
# 973     {'id': 1, 'tipo': 'Visita'}           2025-10-14
# 974     {'id': 1, 'tipo': 'Visita'}           2025-10-21
# 975     {'id': 1, 'tipo': 'Visita'}                  NaN
# 976  {'id': 2, 'tipo': 'Monitoria'}           2025-10-23
# 977  {'id': 2, 'tipo': 'Monitoria'}           2024-12-20
#
#               apelido_protocolo_y dados_tipo_tipo   ds_descricao
# 0                      SONATA-HCM       Monitoria       Pendente
# 1                      SONATA-HCM          Visita      Realizada
# 2                      SONATA-HCM          Visita      Realizada
# 3                      SONATA-HCM          Visita       Pendente
# 4                      SONATA-HCM          Visita       Pendente
# ..                            ...             ...            ...
# 973                           DLG          Visita      Realizada
# 974                           DLG          Visita      Realizada
# 975                           DLG          Visita  Não realizada
# 976  EASi-HF reduzido - 1378-0018       Monitoria      Realizada
# 977                    DURAVELO-2       Monitoria      Realizada
#
# [978 rows x 10 columns]

# %%
monitorias_filtrado = monitorias[monitorias['dados_tipo_tipo'].str.contains('Monitoria')]
monitorias_filtrado['apelido_protocolo_x'] = monitorias_filtrado['apelido_protocolo_x'].str.strip()
monitorias_filtrado
# Out:
#        id           apelido_protocolo_x  numero_protocolo co_externo  \
# 0     784                    SONATA-HCM  LX4211.1-314-HCM       None
# 20   1661                   EsSCAPE-996       BIOTEST-996       None
# 21   1661                   EsSCAPE-996       BIOTEST-996       None
# 22   1661                   EsSCAPE-996       BIOTEST-996       None
# 23   1661                   EsSCAPE-996       BIOTEST-996       None
# ..    ...                           ...               ...        ...
# 943  1531                           DLG                          NaN
# 944  1531                           DLG                          NaN
# 945  1531                           DLG                          NaN
# 976  2230  EASi-HF reduzido - 1378-0018         1378-0018        NaN
# 977  1168                    DURAVELO-2        BT8009-230       None
#
#                                         apelido_centro  \
# 0                      SONATA-HCM - Clínica CardialMed
# 20   EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# 21   EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# 22   EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# 23   EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# ..                                                 ...
# 943                         DLG - Santa Casa de Santos
# 944                         DLG - Santa Casa de Santos
# 945                         DLG - Santa Casa de Santos
# 976  EASi-HF reduzido - 1378-0018 - Maternidade e C...
# 977                DURAVELO-2 - Hospital do Capibaribe
#
#                          dados_tipo data_estimada_filter  \
# 0    {'id': 2, 'tipo': 'Monitoria'}           2026-02-13
# 20   {'id': 2, 'tipo': 'Monitoria'}           2024-07-03
# 21   {'id': 2, 'tipo': 'Monitoria'}           2025-07-24
# 22   {'id': 2, 'tipo': 'Monitoria'}           2025-09-16
# 23   {'id': 2, 'tipo': 'Monitoria'}           2025-09-25
# ..                              ...                  ...
# 943  {'id': 2, 'tipo': 'Monitoria'}           2025-05-30
# 944  {'id': 2, 'tipo': 'Monitoria'}           2025-07-28
# 945  {'id': 2, 'tipo': 'Monitoria'}           2025-12-08
# 976  {'id': 2, 'tipo': 'Monitoria'}           2025-10-23
# 977  {'id': 2, 'tipo': 'Monitoria'}           2024-12-20
#
#               apelido_protocolo_y dados_tipo_tipo ds_descricao
# 0                      SONATA-HCM       Monitoria     Pendente
# 20                    EsSCAPE-996       Monitoria    Realizada
# 21                    EsSCAPE-996       Monitoria    Realizada
# 22                    EsSCAPE-996       Monitoria    Realizada
# 23                    EsSCAPE-996       Monitoria    Realizada
# ..                            ...             ...          ...
# 943                           DLG       Monitoria    Realizada
# 944                           DLG       Monitoria    Realizada
# 945                           DLG       Monitoria    Realizada
# 976  EASi-HF reduzido - 1378-0018       Monitoria    Realizada
# 977                    DURAVELO-2       Monitoria    Realizada
#
# [78 rows x 10 columns]

# %%
def verificar_monitorias_pendentes():
    df = monitorias_filtrado.copy()

    df['data_estimada_filter'] = (
        pd.to_datetime(df['data_estimada_filter'], errors='coerce')
        .dt.tz_localize(None)
    )

    hoje = pd.Timestamp.today().normalize()

    monitorias_pendentes = df[
        (df['ds_descricao'] == 'Pendente') &
        (df['data_estimada_filter'] >= hoje)
    ].sort_values('data_estimada_filter')

    print(
        monitorias_pendentes[
            ['dados_tipo_tipo', 'data_estimada_filter',
             'apelido_protocolo_x', 'ds_descricao', 'apelido_centro']
        ]
    )

    return monitorias_pendentes


    schedule.every().monday.at("09:00").do(verificar_monitorias_pendentes)
monitorias_pendentes = verificar_monitorias_pendentes()
# Out:
#     dados_tipo_tipo data_estimada_filter  apelido_protocolo_x ds_descricao  \
# 0         Monitoria           2026-02-13           SONATA-HCM     Pendente
# 153       Monitoria           2026-02-13      LIBREXIA-STROKE     Pendente
# 637       Monitoria           2026-02-13  EASi-HF - 1378-0020     Pendente
# 63        Monitoria           2026-02-25              CS45570     Pendente
# 635       Monitoria           2026-02-26  EASi-HF - 1378-0020     Pendente
# 457       Monitoria           2026-03-09              FREXALT     Pendente
#
#                                         apelido_centro
# 0                      SONATA-HCM - Clínica CardialMed
# 153  LIBREXIA-STROKE - Maternidade e Cirurgia Nossa...
# 637  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 63                              CS45570 - Leforte HMCG
# 635  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 457                             FREXALT - Leforte HMCG

# %%
# Variavel de envio do email 

envio_para = os.getenv('ENVIO_PARA')

# %%
monitorias_pendentes.rename(columns={'apelido_centro':'Estudo/Centro', 'dados_tipo_tipo': 'Monitoria', 'data_estimada_filter': 'Data Estimada','ds_descricao': 'Status'}, inplace=True)

monitorias_pendentes
# Out:
#        id  apelido_protocolo_x  numero_protocolo co_externo  \
# 0     784           SONATA-HCM  LX4211.1-314-HCM       None
# 153   169      LIBREXIA-STROKE   70033093STR3001     STRUCK
# 637   655  EASi-HF - 1378-0020         1378-0020        NaN
# 63   2229              CS45570           CS45570       None
# 635   655  EASi-HF - 1378-0020         1378-0020        NaN
# 457   584              FREXALT          EFC17919        NaN
#
#                                          Estudo/Centro  \
# 0                      SONATA-HCM - Clínica CardialMed
# 153  LIBREXIA-STROKE - Maternidade e Cirurgia Nossa...
# 637  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 63                              CS45570 - Leforte HMCG
# 635  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...
# 457                             FREXALT - Leforte HMCG
#
#                          dados_tipo Data Estimada  apelido_protocolo_y  \
# 0    {'id': 2, 'tipo': 'Monitoria'}    2026-02-13           SONATA-HCM
# 153  {'id': 2, 'tipo': 'Monitoria'}    2026-02-13      LIBREXIA-STROKE
# 637  {'id': 2, 'tipo': 'Monitoria'}    2026-02-13  EASi-HF - 1378-0020
# 63   {'id': 2, 'tipo': 'Monitoria'}    2026-02-25              CS45570
# 635  {'id': 2, 'tipo': 'Monitoria'}    2026-02-26  EASi-HF - 1378-0020
# 457  {'id': 2, 'tipo': 'Monitoria'}    2026-03-09              FREXALT
#
#      Monitoria    Status
# 0    Monitoria  Pendente
# 153  Monitoria  Pendente
# 637  Monitoria  Pendente
# 63   Monitoria  Pendente
# 635  Monitoria  Pendente
# 457  Monitoria  Pendente

# %%
monitoria_envio = monitorias_pendentes.drop(columns=['apelido_protocolo_x', 'co_externo', 'dados_tipo', 'apelido_protocolo_y'],errors='ignore')

monitoria_envio = monitoria_envio[
    [
        'Monitoria',
        'id',
        'numero_protocolo',
        'Estudo/Centro',
        'Data Estimada',
        'Status'
    ]
]
monitoria_envio
# Out:
#      Monitoria    id  numero_protocolo  \
# 0    Monitoria   784  LX4211.1-314-HCM
# 153  Monitoria   169   70033093STR3001
# 637  Monitoria   655         1378-0020
# 63   Monitoria  2229           CS45570
# 635  Monitoria   655         1378-0020
# 457  Monitoria   584          EFC17919
#
#                                          Estudo/Centro Data Estimada    Status
# 0                      SONATA-HCM - Clínica CardialMed    2026-02-13  Pendente
# 153  LIBREXIA-STROKE - Maternidade e Cirurgia Nossa...    2026-02-13  Pendente
# 637  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...    2026-02-13  Pendente
# 63                              CS45570 - Leforte HMCG    2026-02-25  Pendente
# 635  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...    2026-02-26  Pendente
# 457                             FREXALT - Leforte HMCG    2026-03-09  Pendente

# %%
def enviar_emails(monitoria_envio):
    global envio_para
    try:
        if monitoria_envio is None or monitoria_envio.empty:
            print("Não há visitas nos próximos dias para enviar por e-mail.")
            return

        tabela_html = monitoria_envio[['Estudo/Centro', 'Monitoria', 'Data Estimada', 'Status']].to_html(
            index=False, escape=False, justify="left", border=0, classes="table"
        )

        msg = MIMEMultipart("alternative")
        msg['From'] = email_usuario
        msg['To'] = email_usuario
        msg['Subject'] = "Visitas de Monitoria Pendentes"

        # Validação da lista de destinatários
        if isinstance(envio_para, list):
            # Expressão regex para validar e-mails
            email_regex = r'^[\w\.-]+@[\w\.-]+\.\w+$'
            envio_para = [email.strip() for email in envio_para if email.strip() and re.match(email_regex, email.strip())]
        else:
            envio_para = []

        # Verifica se há destinatários antes de enviar
        destinatarios = [email_usuario] + envio_para
        if not destinatarios:
            print("Nenhum destinatário válido encontrado. O e-mail não foi enviado.")
            return

        # Somente adiciona Bcc se houver destinatários válidos
        if envio_para:
            msg['Bcc'] = ', '.join(envio_para)

        body = f"""
        <html>
            <head>{css_hover}</head>
            <body>
                <p>Olá,</p>
                <p>Segue abaixo lista com visitas de monitoria programadas para os pr&oacute;ximos dias.</p>
                {tabela_html}
                <p>Este email é gerado automaticamente a partir de informações inseridas na Polo Trial.</p>
                <p>Qualquer dúvida, por favor, contate o <strong><span style="text-decoration: underline;">time BI - SVRI</span></strong>.</p>
            </body>
        </html>
        """
        msg.attach(MIMEText(body, 'html'))

        with smtplib.SMTP(smtp_server, email_port) as server:
            server.starttls()
            server.login(email_usuario, email_senha)
            # Envio corrigido para passar apenas destinatários válidos
            server.sendmail(email_usuario, destinatarios, msg.as_string())

        print("E-mail de visitas pendentes enviado com sucesso!")

    except Exception as e:
        print(f"Erro ao enviar o e-mail: {e}")

# Chamada da função
enviar_emails(monitoria_envio)
# Out:
# E-mail de visitas pendentes enviado com sucesso!
