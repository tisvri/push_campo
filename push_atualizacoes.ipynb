# %%
import re
import requests
from urllib.parse import urljoin
import pandas as pd
import schedule
import time
from datetime import datetime, timedelta
import os
import smtplib
import logging
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.image import MIMEImage
from email.mime.base import MIMEBase
from email import encoders
import dotenv

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(message)s"
)

logger = logging.getLogger(__name__)

logger.info("Script iniciado")
# Out:
# 2026-03-12 16:40:48,514 | INFO | Script iniciado

# %% [markdown]
# *** Acesso a PoloTrial (API)

# %%
#ROTA GERAL
dotenv.load_dotenv(override=True)

logger.info("Iniciando sessão com a API")

session = requests.Session()

polotrial_url = os.getenv("POLOTRIAL_URL")

if not polotrial_url:
    logger.error("Variável de ambiente POLOTRIAL_URL não encontrada")
    raise ValueError("POLOTRIAL_URL não definida")

logger.info(f"URL da API carregada")

payload = {
    "nome": os.getenv("POLOTRIAL_USER"),
    "password": os.getenv("POLOTRIAL_PASSWORD")
}

headers = {
    "Content-Type": "application/json"
}

session_url = f"{polotrial_url}/sessions"

logger.info(f"Endpoint de login: {session_url}")

try:

    login_response = requests.post(
        session_url,
        json=payload,
        headers=headers,
        timeout=30
    )

    logger.info(f"Status login API: {login_response.status_code}")

    login_response.raise_for_status()

except Exception as e:
    logger.error(f"Erro na requisição de login: {e}")
    raise

auth_cookie = login_response.cookies.get("userId")

if not auth_cookie:
    logger.error("Cookie de autenticação não recebido")
    raise Exception("Falha na autenticação")

endpoint_headers = {
    "cookie": f"userId={auth_cookie}"
}

logger.info("Autenticação bem-sucedida. Cookie obtido.")

# Mensagem de sucesso na optenção do cookie
if endpoint_headers['cookie']:
    logger.info("Autenticação bem-sucedida. Cookie obtido.")
    print(endpoint_headers)
    print(polotrial_url)
else:
    logger.error("Falha na autenticação. Verifique suas credenciais.")
# Out:
# 2026-03-12 16:40:48,530 | INFO | Iniciando sessão com a API
# 2026-03-12 16:40:48,532 | INFO | URL da API carregada
# 2026-03-12 16:40:48,533 | INFO | Endpoint de login: https://api.polotrial.com/beta/sessions
# 2026-03-12 16:40:49,535 | INFO | Status login API: 200
# 2026-03-12 16:40:49,536 | INFO | Autenticação bem-sucedida. Cookie obtido.
# 2026-03-12 16:40:49,538 | INFO | Autenticação bem-sucedida. Cookie obtido.
# {'cookie': 'userId=s%3Ax3dilBfhnmP4L_nHapMeVKi7rP1QZaMp.ENzQ4IuWzmWZg92JDK0iHZ%2Fva%2FXISqiK%2FuFEcECkqFU'}
# https://api.polotrial.com/beta

# %%
protocolo_url = f"{polotrial_url}/protocolo"

logger.info("Iniciando coleta de protocolos ativos")

protocolos_ativos = [
    "161",  # Aguardando iniciação
    "39",   # Recrutamento aberto
    "9236", # Recrutamento aberto
    "9263", # Aguardando Ativação do Centro
    "393",  # Aguardando Ativação do Centro
    "9294", # Fase Contratual
    "819",  # Aguardando o Pacote Regulatório
    "739",  # Aprovação Anvisa
    "6",    # Aprovação Regulatória
    "912",  # Em apreciação ética
    "9163"  # Aprovado pelo CEP
]

df_protocolos = []

for co_status in protocolos_ativos:

    logger.info(f"Consultando protocolos com status {co_status}")

    query_params = {
        "nested": "true",
        "status_protocolo": co_status
    }

    try:

        response = requests.get(
            protocolo_url,
            headers=endpoint_headers,
            params=query_params,
            timeout=30
        )

        logger.info(
            f"Status {co_status} | HTTP {response.status_code}"
        )

        response.raise_for_status()

        protocolo_json = response.json()

        if not protocolo_json:
            logger.warning(
                f"Nenhum protocolo retornado para status {co_status}"
            )
            continue

        if isinstance(protocolo_json, dict):
            protocolo_json = [protocolo_json]

        df_temp = pd.DataFrame(protocolo_json)

        logger.info(
            f"{len(df_temp)} protocolos encontrados para status {co_status}"
        )

        df_protocolos.append(df_temp)

    except Exception as e:

        logger.error(
            f"Erro ao buscar protocolos para status {co_status}: {e}"
        )

if df_protocolos:

    protocolos_dataframe = pd.concat(
        df_protocolos,
        ignore_index=True
    )

    logger.info(
        f"DataFrame final de protocolos criado com "
        f"{len(protocolos_dataframe)} registros"
    )

else:

    logger.warning(
        "Nenhum protocolo retornado pela API para os status consultados"
    )
# Out:
# 2026-03-12 16:40:49,552 | INFO | Iniciando coleta de protocolos ativos
# 2026-03-12 16:40:49,553 | INFO | Consultando protocolos com status 161
# 2026-03-12 16:40:50,358 | INFO | Status 161 | HTTP 200
# 2026-03-12 16:40:50,358 | WARNING | Nenhum protocolo retornado para status 161
# 2026-03-12 16:40:50,359 | INFO | Consultando protocolos com status 39
# 2026-03-12 16:40:51,165 | INFO | Status 39 | HTTP 200
# 2026-03-12 16:40:51,171 | INFO | 8 protocolos encontrados para status 39
# 2026-03-12 16:40:51,171 | INFO | Consultando protocolos com status 9236
# 2026-03-12 16:40:52,076 | INFO | Status 9236 | HTTP 200
# 2026-03-12 16:40:52,081 | INFO | 7 protocolos encontrados para status 9236
# 2026-03-12 16:40:52,082 | INFO | Consultando protocolos com status 9263
# 2026-03-12 16:40:52,849 | INFO | Status 9263 | HTTP 200
# 2026-03-12 16:40:52,854 | INFO | 1 protocolos encontrados para status 9263
# 2026-03-12 16:40:52,855 | INFO | Consultando protocolos com status 393
# ...

# %%
#ROTA PESSOAS
pessoas_url = f"{polotrial_url}/pessoas"

logger.info("Iniciando coleta de pessoas")

query_params = {
    "nested": "true",
}

try:

    response = requests.get(
        pessoas_url,
        headers=endpoint_headers,
        params=query_params,
        timeout=30
    )

    logger.info(f"Status rota pessoas: {response.status_code}")

    response.raise_for_status()

    pessoas = response.json()

    if not pessoas:
        logger.warning("API retornou lista de pessoas vazia")

    pessoas_df = pd.DataFrame(pessoas)

    logger.info(
        f"DataFrame de pessoas criado com {len(pessoas_df)} registros"
    )

    logger.info(
        f"Colunas disponíveis: {pessoas_df.columns.tolist()}"
    )

except Exception as e:

    logger.error(f"Erro ao consultar rota pessoas: {e}")
    raise
# Out:
# 2026-03-12 16:40:58,301 | INFO | Iniciando coleta de pessoas
# 2026-03-12 16:41:00,036 | INFO | Status rota pessoas: 200
# 2026-03-12 16:41:00,087 | INFO | DataFrame de pessoas criado com 3894 registros
# 2026-03-12 16:41:00,091 | INFO | Colunas disponíveis: ['dados_ativo', 'id', 'ds_nome', 'co_tipo_gn', 'co_equipe_gn', 'co_formacao_maior_nivel_gn', 'dt_ultimo_certificado_gcp', 'registro_profissional', 'declaracao_confidencialidade', 'custo_mensal_estimado', 'co_centro', 'equipe_padrao', 'equipe_padrao_kits', 'equipe_padrao_farmacia', 'equipe_padrao_naocega', 'filter', 'prox_vencimento_treinamento', 'co_especialidade', 'ativo', 'deleted', 'status', 'dados_co_tipo_gn', 'dados_co_equipe_gn', 'dados_co_formacao_maior_nivel_gn', 'dados_status', 'dados_centro', 'dados_equipe_padrao_farmacia', 'dados_equipe_padrao_kits', 'dados_equipe_padrao', 'dados_pessoa_especialidade']

# %%
logger.info(f"Shape dataframe pessoas: {pessoas_df.shape}")
logger.info(f"Colunas dataframe pessoas: {pessoas_df.columns.tolist()}")
logger.info("Primeiras linhas do dataframe pessoas:")
logger.info(f"\n{pessoas_df.head()}")
# Out:
# 2026-03-12 16:41:00,099 | INFO | Shape dataframe pessoas: (3894, 30)
# 2026-03-12 16:41:00,100 | INFO | Colunas dataframe pessoas: ['dados_ativo', 'id', 'ds_nome', 'co_tipo_gn', 'co_equipe_gn', 'co_formacao_maior_nivel_gn', 'dt_ultimo_certificado_gcp', 'registro_profissional', 'declaracao_confidencialidade', 'custo_mensal_estimado', 'co_centro', 'equipe_padrao', 'equipe_padrao_kits', 'equipe_padrao_farmacia', 'equipe_padrao_naocega', 'filter', 'prox_vencimento_treinamento', 'co_especialidade', 'ativo', 'deleted', 'status', 'dados_co_tipo_gn', 'dados_co_equipe_gn', 'dados_co_formacao_maior_nivel_gn', 'dados_status', 'dados_centro', 'dados_equipe_padrao_farmacia', 'dados_equipe_padrao_kits', 'dados_equipe_padrao', 'dados_pessoa_especialidade']
# 2026-03-12 16:41:00,101 | INFO | Primeiras linhas do dataframe pessoas:
# 2026-03-12 16:41:00,106 | INFO |
#             dados_ativo    id                 ds_nome  co_tipo_gn  \
# ...

# %%
#ROTA AGENDA
agenda_url = f"{polotrial_url}/participante_visita"

logger.info("Iniciando coleta de agenda de participantes")

query_params = {
    "nested": "true",
}

try:
    response = requests.get(
        agenda_url,
        headers=endpoint_headers,
        params=query_params,
        timeout=30
    )

    logger.info(f"Status rota participante_visita: {response.status_code}")

    response.raise_for_status()

    agenda = response.json()

    if not agenda:
        logger.warning("API retornou agenda vazia")

    agenda_df = pd.DataFrame(agenda)

    logger.info(f"DataFrame agenda criado com {len(agenda_df)} registros")
    logger.info(f"Shape agenda_df: {agenda_df.shape}")
    logger.info(f"Colunas agenda_df: {agenda_df.columns.tolist()}")

    logger.info("Primeiras linhas da agenda:")
    logger.info(f"\n{agenda_df.head()}")

except Exception as e:
    logger.error(f"Erro ao consultar rota participante_visita: {e}")
    raise
# Out:
# 2026-03-12 16:41:00,121 | INFO | Iniciando coleta de agenda de participantes
# 2026-03-12 16:41:08,015 | INFO | Status rota participante_visita: 200
# 2026-03-12 16:41:08,461 | INFO | DataFrame agenda criado com 16947 registros
# 2026-03-12 16:41:08,463 | INFO | Shape agenda_df: (16947, 48)
# ...

# %%
particpantes_url = f"{polotrial_url}/participantes"

logger.info("Iniciando coleta de participantes")

query_params = {
    "nested": "true",
}

try:

    response = requests.get(
        particpantes_url,
        headers=endpoint_headers,
        params=query_params,
        timeout=30
    )

    logger.info(f"Status rota participantes: {response.status_code}")

    response.raise_for_status()

    participantes = response.json()

    if not participantes:
        logger.warning("API retornou lista de participantes vazia")

    # tratamento do formato do JSON
    if isinstance(participantes, dict):
        participantes = [participantes]

    participantes_df = pd.DataFrame(participantes)

    logger.info(f"DataFrame participantes criado com {len(participantes_df)} registros")
    logger.info(f"Shape participantes_df: {participantes_df.shape}")
    logger.info(f"Colunas participantes_df: {participantes_df.columns.tolist()}")

    logger.info("Primeiras linhas do dataframe participantes:")
    logger.info(f"\n{participantes_df.head()}")

except Exception as e:

    logger.error(f"Erro ao consultar rota participantes: {e}")
    raise
# Out:
# 2026-03-12 16:41:08,483 | INFO | Iniciando coleta de participantes
# 2026-03-12 16:41:13,054 | INFO | Status rota participantes: 200
# 2026-03-12 16:41:13,217 | INFO | DataFrame participantes criado com 2507 registros
# 2026-03-12 16:41:13,218 | INFO | Shape participantes_df: (2507, 37)
# ...

# %%
monitoria_url = f"{polotrial_url}/agenda"

logger.info("Iniciando coleta de dados de monitoria")

query_params = {
    "nested": "true",
}

try:

    response = requests.get(
        monitoria_url,
        headers=endpoint_headers,
        params=query_params,
        timeout=30
    )

    logger.info(f"Status rota agenda: {response.status_code}")

    response.raise_for_status()

    monitoria = response.json()

    if not monitoria:
        logger.warning("API retornou agenda de monitoria vazia")

    if isinstance(monitoria, dict):
        monitoria = [monitoria]

    monitoria_df = pd.DataFrame(monitoria)

    logger.info(f"DataFrame monitoria criado com {len(monitoria_df)} registros")
    logger.info(f"Shape monitoria_df: {monitoria_df.shape}")
    logger.info(f"Colunas monitoria_df: {monitoria_df.columns.tolist()}")

    logger.info("Primeiras linhas da agenda de monitoria:")
    logger.info(f"\n{monitoria_df.head()}")

except Exception as e:

    logger.error(f"Erro ao consultar rota agenda: {e}")
    raise
# Out:
# 2026-03-12 16:41:13,250 | INFO | Iniciando coleta de dados de monitoria
# 2026-03-12 16:41:20,319 | INFO | Status rota agenda: 200
# 2026-03-12 16:41:20,812 | INFO | DataFrame monitoria criado com 17920 registros
# 2026-03-12 16:41:20,813 | INFO | Shape monitoria_df: (17920, 43)
# ...

# %% [markdown]
# *** Visualização e modelagem para extração de GCP (cadastros ativos)

# %%
pessoas_df.head(5)
# Out:
#             dados_ativo    id                 ds_nome  co_tipo_gn  \
# 0  {'descricao': 'Sim'}  2978                     NaN       562.0
# 1  {'descricao': 'Sim'}  3545                     NaN       562.0
# 2  {'descricao': 'Sim'}  1332                               649.0
# 3  {'descricao': 'Sim'}  3118   Alex Gonçalves Macedo       387.0
# 4  {'descricao': 'Sim'}  1554    Alex Vladimir Dudzic       649.0
#
#   co_equipe_gn  co_formacao_maior_nivel_gn dt_ultimo_certificado_gcp  \
# 0         None                         NaN                       NaN
# 1         None                         NaN                       NaN
# 2         None                         NaN                       NaN
# 3         None                        31.0                2023-09-06
# 4         None                         NaN                       NaN
#
#   registro_profissional declaracao_confidencialidade custo_mensal_estimado  \
# ...

# %%
colunas = [
    'dados_centro',
    'dt_ultimo_certificado_gcp',
    'ds_nome',
    'dados_co_tipo_gn',
    'dados_status'
]

faltantes = [c for c in colunas if c not in pessoas_df.columns]
if faltantes:
    raise Exception(f"Colunas ausentes: {faltantes}")
gcp = pessoas_df[colunas].copy()

gcp.loc[:, 'dados_centro_id'] = gcp['dados_centro'].apply(lambda x: x['id'] if x is not None else None)
gcp.loc[:, 'dados_centro_descricao'] = gcp['dados_centro'].apply(lambda x: x['descricao'] if x is not None else None)
gcp.loc[:, 'tipo_gn'] = gcp['dados_co_tipo_gn'].apply(lambda x: x['ds_descricao'] if x is not None else None)
gcp.loc[:, 'status'] = gcp['dados_status'].apply(lambda x: x['ds_descricao'] if x is not None else None)

gcp_ativos = gcp.drop(['dados_centro', 'dados_centro_id', 'dados_co_tipo_gn', 'dados_status'], axis=1)
gcp_modelado = gcp_ativos[gcp_ativos['status'] == 'Ativo']

gcp_modelado.head(5)
# Out:
#     dt_ultimo_certificado_gcp                 ds_nome  \
# 3                  2023-09-06   Alex Gonçalves Macedo
# 5                         NaN   Augusto Ferreira José
# 6                         NaN        Dr. Ricardo Moro
# 313                       NaN    Adão Castelo Antônio
# 385                2025-06-26      Alessandro Vengjer
#
#                         dados_centro_descricao                tipo_gn status
# 3                         Santa Casa de Santos  Pesquisador Principal  Ativo
# 5                         Santa Casa de Santos        Subinvestigador  Ativo
# 6    Clinica de Ortopedia Campo Largo S/S LTDA  Pesquisador Principal  Ativo
# 313              Hospital Municipal de Barueri  Pesquisador Principal  Ativo
# 385                       Santa Casa de Santos  Pesquisador Principal  Ativo

# %%
venc_gcp = gcp_modelado[gcp_modelado['tipo_gn'] != 'Equipe padrão (adicionada automaticamente para todos os protocolos)']
venc_gcp["Cadastro de data"] = venc_gcp["dt_ultimo_certificado_gcp"].apply(
    lambda x: "Não há data cadastrada" if pd.isna(x) else "Data cadastrada"
)

venc_gcp.rename(columns={'dt_ultimo_certificado_gcp': 'Assinatura do GCP', 'ds_nome': 'Nome', 'dados_centro_descricao': 'Centro','tipo_gn': 'Função', 'status': 'Status do Cadastro'}, inplace=True)

nova_ordem = ['Centro', 'Nome', 'Função','Status do Cadastro', 'Assinatura do GCP', "Cadastro de data"]
venc_gcp = venc_gcp[nova_ordem]
venc_gcp = venc_gcp.sort_values(by="Centro")
venc_gcp
# Out:
#                                                  Centro  \
# 1124  A2Z Clinical Centro Avancado De Pesquisa Clini...
# 1296                              Centro Médico Sinapse
# 1210                                Centro Vila Olimpia
# 1332                      Centro de Oncologia do Panará
# 1122                                          Clin Kids
# ...                                                 ...
# 1583                                                NaN
# 1798                                                NaN
# 1800                                                NaN
# 3170                                                NaN
# 3281                                                NaN
#
#                                           Nome                 Função  \
# 1124  Dr. Fernando Henrique de Carvalho Gouvêa          Equipe Médica
# 1296             Dr. Ricardo Moutte de Freitas  Pesquisador Principal
# 1210             Dr. Leandro Tuzuki Cavalheiro  Pesquisador Principal
# ...

# %%
hmcg = ['Leforte HMCG','Leforte Morumbi','Hospital Municipal de Barueri', 'Leforte Liberdade', 'Clínica CardialMed','Clínica CardialMed']
filtro1 = venc_gcp['Centro'].isin(hmcg)
venc_gcp_hmcg = venc_gcp[filtro1]
venc_gcp_hmcg=venc_gcp_hmcg.sort_values(by=['Centro', 'Nome'], ascending= [True, True])
venc_gcp_hmcg
# Out:
#                              Centro  \
# 1166             Clínica CardialMed
# 1472             Clínica CardialMed
# 2042             Clínica CardialMed
# 2130             Clínica CardialMed
# 313   Hospital Municipal de Barueri
# ...                             ...
# 1127                Leforte Morumbi
# 1474                Leforte Morumbi
# 1504                Leforte Morumbi
# 1776                Leforte Morumbi
# 2926                Leforte Morumbi
#
#                                            Nome                 Função  \
# 1166               Dr. Heron Rhydan Saad Rached  Pesquisador Principal
# 1472            Dra. Maristela Gomes de Almeida  Pesquisador Principal
# 2042                   Heron Rhydan Saad Rached  Pesquisador Principal
# 2130       Izabella Cordeiro Freire Saad Rached  Pesquisador Principal
# 313                        Adão Castelo Antônio  Pesquisador Principal
# ...                                         ...                    ...
# ...

# %%
rocio = ['Maternidade e Cirurgia Nossa Senhora do Rocio SA']
filtro2 = venc_gcp['Centro'].isin(rocio)
venc_gcp_rocio = venc_gcp[filtro2]
venc_gcp_rocio=venc_gcp_rocio.sort_values(by=['Centro', 'Nome'], ascending= [True, True])
venc_gcp_rocio
# Out:
#                                                 Centro  \
# 533   Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 535   Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 683   Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 684   Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 763   Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 824   Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 903   Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 923   Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 931   Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1017  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1023  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1050  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1051  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1064  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1085  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# 1086  Maternidade e Cirurgia Nossa Senhora do Rocio SA
# ...

# %%
iir_coord = ['Hospital das Clínicas de Itajubá', 'Saint-Beauté Clinique', 'Hospital Salvalus','Consultório Lopes e Sartorelli', 'Clínica Berger', 
            'QualiVida Higienópolis','Endolap Saúde' ]
filtro3 = venc_gcp['Centro'].isin(iir_coord)
venc_gcp_iir_coord = venc_gcp[filtro3] 
venc_gcp_iir_coord=venc_gcp_iir_coord.sort_values(by=['Centro', 'Nome'], ascending= [True, True])
venc_gcp_iir_coord
# Out:
#                               Centro                 Nome  \
# 1065                  Clínica Berger   Dr. Charles Berger
# 3175  Consultório Lopes e Sartorelli  Nathalia Westphalen
#
#                      Função Status do Cadastro Assinatura do GCP  \
# 1065  Pesquisador Principal              Ativo               NaN
# 3175          Equipe Médica              Ativo               NaN
#
#             Cadastro de data
# 1065  Não há data cadastrada
# 3175  Não há data cadastrada

# %%
envio_viviane = ['Otorhinus Clínica Médica', 'Unimed Brusque']
filtro4 = venc_gcp['Centro'].isin(envio_viviane)
venc_gcp_envio_viviane = venc_gcp[filtro4]
venc_gcp_envio_viviane=venc_gcp_envio_viviane.sort_values(by=['Centro', 'Nome'], ascending= [True, True])
venc_gcp_envio_viviane
# Out:
#                         Centro                                       Nome  \
# 1277  Otorhinus Clínica Médica  Dr. Rafael Leonardo Emerich Lentz Martins
# 3333  Otorhinus Clínica Médica      Rafael Leonardo Emerich Lentz Martins
# 1030            Unimed Brusque          Dr. Antonio Carlos de Mattos Roxo
# 1077            Unimed Brusque                   Dr. Daniel Rodrigo Klein
# 1112            Unimed Brusque                        Dr. Fabio Benedetti
# 1126            Unimed Brusque       Dr. Fernando Kamimoto Eckmann Helene
# 1113            Unimed Brusque              Dr. Fábio Benedetti Rodrigues
# 1172            Unimed Brusque                    Dr. Ismael Paulo Búrigo
# 1204            Unimed Brusque                         Dr. Laércio Cadore
# 1230            Unimed Brusque         Dr. Luiz Fernando Silveira Parrela
# 1250            Unimed Brusque                  Dr. Marcus Vitor Oliveira
# 1269            Unimed Brusque         Dr. Paulo Cesar de Campos Ferreira
# ...

# %%
stacasa_santos = ['Santa Casa de Santos']
filtro5 = venc_gcp['Centro'].isin(stacasa_santos)
venc_gcp_stacasa_santos = venc_gcp[filtro5]
venc_gcp_stacasa_santos=venc_gcp_stacasa_santos.sort_values(by=['Centro', 'Nome'], ascending= [True, True])
venc_gcp_stacasa_santos
# Out:
#                     Centro                             Nome  \
# 3     Santa Casa de Santos            Alex Gonçalves Macedo
# 5     Santa Casa de Santos            Augusto Ferreira José
# 385   Santa Casa de Santos               Alessandro Vengjer
# 520   Santa Casa de Santos     André Galante Alencar Aranha
# 522   Santa Casa de Santos  André Gustavo Pereira Magalhães
# ...                    ...                              ...
# 3439  Santa Casa de Santos              Roberto Higa Junior
# 3529  Santa Casa de Santos        Samuel Brunini Petrarolha
# 3528  Santa Casa de Santos        Samuel Brunini Petrarolha
# 3826  Santa Casa de Santos                Vitor Hugo Straub
# 3827  Santa Casa de Santos       Vitor Hugo Straub Canasiro
#
#                      Função Status do Cadastro Assinatura do GCP  \
# 3     Pesquisador Principal              Ativo        2023-09-06
# 5           Subinvestigador              Ativo               NaN
# ...

# %%
capibaribe = ['Hospital do Capibaribe']
filtro6 = venc_gcp['Centro'].isin(capibaribe)
venc_gcp_capibaribe = venc_gcp[filtro6]
venc_gcp_capibaribe=venc_gcp_capibaribe.sort_values(by=['Centro', 'Nome'], ascending= [True, True])
venc_gcp_capibaribe
# Out:
#                       Centro                                      Nome  \
# 1180  Hospital do Capibaribe              Dr. Jayme José Gouveia Filho
# 1469  Hospital do Capibaribe  Dra. Mariane Teodoro Fernandes Rodrigues
# 2841  Hospital do Capibaribe       Mariane Teodoro Fernandes Rodrigues
#
#                      Função Status do Cadastro Assinatura do GCP  \
# 1180          Equipe Médica              Ativo        2024-09-23
# 1469  Pesquisador Principal              Ativo        2024-06-14
# 2841  Pesquisador Principal              Ativo               NaN
#
#             Cadastro de data
# 1180         Data cadastrada
# 1469         Data cadastrada
# 2841  Não há data cadastrada

# %% [markdown]
# ***Função para cálculo da data de vencimento de GCP.

# %%
def verificar_vencimento_contratos(df_contratos, nome_centro, dias_para_vencimento=30):

    logger.info(f"Iniciando verificação de vencimento de GCP para {nome_centro}")

    if df_contratos.empty:
        logger.warning(f"{nome_centro}: dataframe de contratos está vazio")
        return df_contratos

    df_contratos = df_contratos.copy()

    df_contratos['Assinatura do GCP'] = pd.to_datetime(
        df_contratos['Assinatura do GCP'],
        errors='coerce'
    )

    hoje = datetime.today()
    limite_vencimento = hoje + timedelta(days=dias_para_vencimento)

    df_contratos['data_vencimento'] = (
        df_contratos['Assinatura do GCP'] + timedelta(days=2 * 365)
    )

    filtro_vencendo = (
        (df_contratos['data_vencimento'] > hoje) &
        (df_contratos['data_vencimento'] <= limite_vencimento)
    )

    filtro_sem_data = df_contratos['Assinatura do GCP'].isna()

    contratos_relevantes = df_contratos[filtro_vencendo | filtro_sem_data]

    logger.info(
        f"{nome_centro}: {len(df_contratos)} contratos analisados"
    )

    logger.info(
        f"{nome_centro}: {len(contratos_relevantes)} contratos com alerta"
    )

    if contratos_relevantes.empty:

        logger.info(
            f"{nome_centro}: nenhum contrato sem data de GCP ou vencendo "
            f"nos próximos {dias_para_vencimento} dias"
        )

    else:

        logger.warning(
            f"{nome_centro}: profissionais com GCP ausente ou vencendo "
            f"nos próximos {dias_para_vencimento} dias"
        )

        logger.info(
            f"\n{contratos_relevantes[['Centro', 'Nome', 'Função','Status do Cadastro', 'Assinatura do GCP', 'Cadastro de data']]}"
        )

    return contratos_relevantes

# %%
contratos_hmcg = verificar_vencimento_contratos(venc_gcp_hmcg, "HMCG", dias_para_vencimento=30)
contratos_rocio = verificar_vencimento_contratos(venc_gcp_rocio, "Rocío", dias_para_vencimento=30)
contratos_iir_coord = verificar_vencimento_contratos(venc_gcp_iir_coord, "IRR COORD", dias_para_vencimento=30)
contratos_vivi = verificar_vencimento_contratos(venc_gcp_envio_viviane, "Envio Viviane", dias_para_vencimento=30)
contratos_stacsantos = verificar_vencimento_contratos(venc_gcp_stacasa_santos, "Santa Casa de Santos", dias_para_vencimento=30)
contratos_capibaribe = verificar_vencimento_contratos(venc_gcp_capibaribe, "Capibaribe", dias_para_vencimento=30)
# Out:
# 2026-03-12 16:41:21,166 | INFO | Iniciando verificação de vencimento de GCP para HMCG
# 2026-03-12 16:41:21,171 | INFO | HMCG: 87 contratos analisados
# 2026-03-12 16:41:21,171 | INFO | HMCG: 83 contratos com alerta
# 2026-03-12 16:41:21,171 | WARNING | HMCG: profissionais com GCP ausente ou vencendo nos próximos 30 dias
# 2026-03-12 16:41:21,180 | INFO |
#                              Centro  \
# 1166             Clínica CardialMed
# 1472             Clínica CardialMed
# 2042             Clínica CardialMed
# 2130             Clínica CardialMed
# 313   Hospital Municipal de Barueri
# ...                             ...
# 1127                Leforte Morumbi
# 1474                Leforte Morumbi
# 1504                Leforte Morumbi
# 1776                Leforte Morumbi
# 2926                Leforte Morumbi
#
#                                            Nome                 Função  \
# 1166               Dr. Heron Rhydan Saad Rached  Pesquisador Principal
# ...

# %% [markdown]
# ***Função para envio dos emails de GCP

# %%
css_hover = """
<style>
/* Reset básico */
table {
    border-collapse: collapse;
    width: 100%;
    font-family: Arial, Helvetica, sans-serif;
    font-size: 13px;
}

/* Cabeçalho */
th {
    background-color: #007bff;
    color: #ffffff;
    border: 1px solid #d0d0d0;
    padding: 8px;
    text-align: left;
    font-weight: bold;
}

/* Células */
td {
    border: 1px solid #d0d0d0;
    padding: 8px;
    text-align: left;
    vertical-align: middle;
    color: #000000;
}

/* Linhas alternadas (mais compatível que hover) */
tr:nth-child(even) {
    background-color: #f8f9fa;
}

/* Hover (funciona em Gmail/Web, ignorado no Outlook) */
tr:hover {
    background-color: #fff3cd;
}

/* Responsividade simples */
@media screen and (max-width: 600px) {
    table {
        font-size: 12px;
    }
}
</style>
"""

# %% [markdown]
# Variáveis de envio de email

# %%
smtp_server   = os.getenv("EMAIL_SERVER")
email_port    = int(os.getenv("EMAIL_PORT", "587"))
email_usuario = os.getenv("EMAIL_USERNAME")
email_senha   = os.getenv("EMAIL_PASSWORD")

# Destinatários GCP – variáveis individuais (strings simples)
enviar_para          = os.getenv("ENVIAR_PARA", "")
destinatario_hmcg    = os.getenv("DESTINATARIO_HMCG", "")
destinatario_rocio   = os.getenv("DESTINATARIO_ROCIO", "")
destinatario_scs     = os.getenv("DESTINATARIO_SCS", "")
destinatario_iir     = os.getenv("DESTINATARIO_IIR", "")
destinatario_vivi    = os.getenv("DESTINATARIO_VIVIANE", "")
destinatario_capibaribe = os.getenv("DESTINATARIO_CAPIBARIBE", "")

# Destinatário monitoria
envio_para = os.getenv("ENVIO_PARA", "")

def _parse_destinatarios(valor):
    """Converte string 'a@b.com,c@d.com' em lista de emails válidos."""
    email_regex = r'^[\w\.-]+@[\w\.-]+\.\w+$'
    if not valor:
        return []
    emails = [e.strip() for e in valor.split(",") if e.strip()]
    validos = [e for e in emails if re.match(email_regex, e)]
    invalidos = set(emails) - set(validos)
    if invalidos:
        logger.warning(f"Emails ignorados por formato inválido: {invalidos}")
    return validos

# %%
def enviar_email(destinatarios, df_tratado, nome_grupo):

    logger.info(f"Iniciando envio de email para grupo: {nome_grupo}")

    if df_tratado is None or df_tratado.empty:
        logger.info(f"{nome_grupo}: não há contratos para envio de email")
        return

    try:
        logger.info(f"{nome_grupo}: {len(df_tratado)} registros serão enviados no email")

        # garante lista e valida endereços
        if isinstance(destinatarios, str):
            destinatarios = _parse_destinatarios(destinatarios)
        else:
            destinatarios = [d for d in destinatarios if d]

        if not destinatarios:
            logger.warning(f"{nome_grupo}: nenhum destinatário válido. Email não enviado.")
            return

        logger.info(f"{nome_grupo}: destinatários -> {destinatarios}")

        colunas = [
            'Centro',
            'Nome',
            'Função',
            'Status do Cadastro',
            'Assinatura do GCP',
            'Cadastro de data'
        ]

        tabela_html = df_tratado[colunas].to_html(
            index=False,
            escape=False,
            border=0,
            justify="left",
            classes="table"
        )

        logger.info(f"{nome_grupo}: tabela HTML gerada")

        msg = MIMEMultipart("alternative")
        msg["From"]    = email_usuario
        msg["To"]      = email_usuario
        msg["Bcc"]     = ", ".join(destinatarios)
        msg["Subject"] = f"[{nome_grupo}] GCP sem data registrada ou com vencimento próximo"

        body = f"""
        <html>
            <head>{css_hover}</head>
            <body>
                <h2>Vencimento de GCP - {nome_grupo}</h2>
                <p>Bom dia,</p>
                <p>
                    Segue abaixo relação de GCPs que não possuem data registrada
                    no sistema ou que apresentam vencimento próximo:
                </p>
                {tabela_html}
                <br>
                <p>
                    Este e-mail é gerado automaticamente a partir de informações
                    inseridas na <strong>Polo Trial</strong>.
                </p>
                <p>
                    Qualquer dúvida, por favor, contate o
                    <strong><u>time BI - SVRI</u></strong>.
                </p>
            </body>
        </html>
        """

        msg.attach(MIMEText(body, "html"))

        logger.info(f"{nome_grupo}: conectando ao servidor SMTP {smtp_server}:{email_port}")

        with smtplib.SMTP(smtp_server, email_port) as server:
            server.starttls()
            logger.info(f"{nome_grupo}: TLS iniciado")
            server.login(email_usuario, email_senha)
            logger.info(f"{nome_grupo}: login SMTP realizado")
            server.send_message(msg)
            logger.info(f"{nome_grupo}: email enviado com sucesso")

    except Exception as e:
        logger.error(
            f"{nome_grupo}: erro ao enviar email -> {str(e)}",
            exc_info=True
        )

# %%
enviar_email([destinatario_hmcg], contratos_hmcg, "HMCG")
enviar_email([destinatario_rocio], contratos_rocio, "Rocio")
enviar_email([destinatario_iir], contratos_iir_coord, "IIR")
enviar_email([destinatario_scs], contratos_stacsantos, "Sta. Santos")
enviar_email([destinatario_vivi], contratos_vivi, "Viviane")
enviar_email([destinatario_capibaribe], contratos_capibaribe, "Capibaribe")
# Out:
# 2026-03-12 16:41:21,283 | INFO | Iniciando envio de email para grupo: HMCG
# 2026-03-12 16:41:21,284 | INFO | HMCG: 83 registros serão enviados no email
# 2026-03-12 16:41:21,285 | INFO | HMCG: destinatários BCC -> ['sitehmcg@svriglobal.com']
# 2026-03-12 16:41:21,296 | INFO | HMCG: tabela HTML gerada
# 2026-03-12 16:41:21,300 | INFO | HMCG: corpo do email criado
# 2026-03-12 16:41:21,300 | INFO | HMCG: conectando ao servidor SMTP
# 2026-03-12 16:41:21,351 | INFO | HMCG: TLS iniciado
# 2026-03-12 16:41:21,464 | INFO | HMCG: login SMTP realizado
# 2026-03-12 16:41:22,047 | INFO | HMCG: email enviado com sucesso
# 2026-03-12 16:41:22,064 | INFO | Iniciando envio de email para grupo: Rocio
# 2026-03-12 16:41:22,064 | INFO | Rocio: 32 registros serão enviados no email
# 2026-03-12 16:41:22,064 | INFO | Rocio: destinatários BCC -> ['siterocio@svriglobal.com']
# 2026-03-12 16:41:22,064 | INFO | Rocio: tabela HTML gerada
# 2026-03-12 16:41:22,064 | INFO | Rocio: corpo do email criado
# ...

# %% [markdown]
# ***Modelagem para envio de Visitas de Seguimento

# %%
protocolo = pd.DataFrame(protocolos_dataframe)
protocolo.head(5)
# Out:
#      id                                   titulo_protocolo cor_agenda  \
# 0   784  Um estudo randomizado, duplo-cego, controlado ...    #000000
# 1  1256  Estudo VISIONAIRE (Vitamin K AntagonISt, Facto...    #000000
# 2  1661  Um ensaio randomizado, controlado por placebo,...    #9a514c
# 3  2371  Estudo randomizado, multicêntrico, duplo cego,...    #000000
# 4  2372  Estudo randomizado, multicêntrico, duplo cego,...    #000000
#
#    numero_protocolo apelido_protocolo  coordenador    pi pesquisador_backup  \
# 0  LX4211.1-314-HCM        SONATA-HCM       2829.0   271                NaN
# 1                          VISIONAIRE       2829.0  3050                NaN
# 2       BIOTEST-996       EsSCAPE-996        239.0   250                NaN
# 3                         Oxandrolona       2631.0  4157                NaN
# 4                         Oxandrolona       2622.0  4166             3662.0
#
#    co_pessoa_regulatorio             data_cadastro  ...  \
# ...

# %%
centros = protocolo[['id','apelido_protocolo', 'numero_protocolo','co_externo','apelido_centro']].copy()
centros.head(5)
# Out:
#      id apelido_protocolo  numero_protocolo co_externo  \
# 0   784        SONATA-HCM  LX4211.1-314-HCM       None
# 1  1256        VISIONAIRE                         None
# 2  1661       EsSCAPE-996       BIOTEST-996       None
# 3  2371       Oxandrolona                         None
# 4  2372       Oxandrolona                         None
#
#                                       apelido_centro
# 0                    SONATA-HCM - Clínica CardialMed
# 1                  VISIONAIRE - SVRI Clínica Morumbi
# 2  EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...
# 3                       Oxandrolona - Unimed Brusque
# 4                 Oxandrolona - Santa Casa de Santos

# %%
seguimento = agenda_df[['dados_participante', 'data_estimada', 'dados_status', 'dados_visita']].copy()

seguimento.loc[:, 'dados_participante_id'] = seguimento['dados_participante'].apply(lambda x: x['id'] if x is not None else None)
seguimento.loc[:, 'id_participante'] = seguimento['dados_participante'].apply(lambda x: x['id_participante'] if x is not None else None)
seguimento.loc[:, 'dados_protocolo'] = seguimento['dados_participante'].apply(lambda x: x['dados_protocolo'] if x is not None else None)

seguimento.loc[:, 'dados_status_id'] = seguimento['dados_status'].apply(lambda x: x['id'] if x is not None else None)
seguimento.loc[:, 'ds_descricao'] = seguimento['dados_status'].apply(lambda x: x['ds_descricao'] if x is not None else None)
seguimento.loc[:, 'ds_nome_visita'] = seguimento['dados_visita'].apply(lambda x: x['ds_nome_visita'] if x is not None else None)

seguimento.loc[:, 'apelido_protocolo'] = seguimento['dados_protocolo'].apply(lambda x: x['apelido_protocolo'] if x is not None else None)
seguimento['data_estimada'] = pd.to_datetime(seguimento['data_estimada'], errors='coerce')
seguimento.head(5)
# Out:
#                                   dados_participante  \
# 0  {'id': 54, 'co_protocolo': 4, 'id_participante...
# 1  {'id': 56, 'co_protocolo': 4, 'id_participante...
# 2  {'id': 57, 'co_protocolo': 4, 'id_participante...
# 3  {'id': 58, 'co_protocolo': 4, 'id_participante...
# 4  {'id': 59, 'co_protocolo': 4, 'id_participante...
#
#               data_estimada                             dados_status  \
# 0 2021-01-05 00:00:00+00:00  {'id': 20, 'ds_descricao': 'Realizada'}
# 1 2021-01-07 00:00:00+00:00  {'id': 20, 'ds_descricao': 'Realizada'}
# 2 2021-01-08 00:00:00+00:00  {'id': 20, 'ds_descricao': 'Realizada'}
# 3 2021-01-12 00:00:00+00:00  {'id': 20, 'ds_descricao': 'Realizada'}
# 4 2021-01-14 00:00:00+00:00  {'id': 20, 'ds_descricao': 'Realizada'}
#
#                                         dados_visita  dados_participante_id  \
# 0  {'id': 1, 'ds_nome_visita': 'Triagem ', 'co_ex...                     54
# ...

# %%
seguimento_tratado = seguimento.drop(['dados_participante','dados_status','id_participante','dados_status_id'], axis=1)
seguimento_tratado.loc[:, 'id'] = seguimento['dados_protocolo'].apply(lambda x: x['id'] if x is not None else None)
seguimento_tratado.head(5)
# Out:
#               data_estimada  \
# 0 2021-01-05 00:00:00+00:00
# 1 2021-01-07 00:00:00+00:00
# 2 2021-01-08 00:00:00+00:00
# 3 2021-01-12 00:00:00+00:00
# 4 2021-01-14 00:00:00+00:00
#
#                                         dados_visita  dados_participante_id  \
# 0  {'id': 1, 'ds_nome_visita': 'Triagem ', 'co_ex...                     54
# 1  {'id': 1, 'ds_nome_visita': 'Triagem ', 'co_ex...                     56
# 2  {'id': 1, 'ds_nome_visita': 'Triagem ', 'co_ex...                     57
# 3  {'id': 1, 'ds_nome_visita': 'Triagem ', 'co_ex...                     58
# 4  {'id': 1, 'ds_nome_visita': 'Triagem ', 'co_ex...                     59
#
#                                      dados_protocolo ds_descricao  \
# 0  {'id': 4, 'apelido_protocolo': 'BTK', 'co_coor...    Realizada
# 1  {'id': 4, 'apelido_protocolo': 'BTK', 'co_coor...    Realizada
# 2  {'id': 4, 'apelido_protocolo': 'BTK', 'co_coor...    Realizada
# ...

# %%
seguimentos = pd.merge(centros, seguimento_tratado, on='id', how='inner')
seguimentos
# Out:
#         id apelido_protocolo_x  numero_protocolo co_externo  \
# 0      784          SONATA-HCM  LX4211.1-314-HCM       None
# 1      784          SONATA-HCM  LX4211.1-314-HCM       None
# 2      784          SONATA-HCM  LX4211.1-314-HCM       None
# 3      784          SONATA-HCM  LX4211.1-314-HCM       None
# 4      784          SONATA-HCM  LX4211.1-314-HCM       None
# ...    ...                 ...               ...        ...
# 1159  2622              NATURA                          NaN
# 1160  2622              NATURA                          NaN
# 1161  2622              NATURA                          NaN
# 1162  2622              NATURA                          NaN
# 1163  2622              NATURA                          NaN
#
#                          apelido_centro             data_estimada  \
# 0       SONATA-HCM - Clínica CardialMed 2026-01-16 00:00:00+00:00
# 1       SONATA-HCM - Clínica CardialMed 2026-01-16 00:00:00+00:00
# ...

# %%
seguimentos['apelido_protocolo_x'] = seguimentos['apelido_protocolo_x'].str.strip()
visitas_filtrado = seguimentos[seguimentos['ds_descricao'].str.contains('Pendente')]
nova_ordem = ["apelido_centro", "dados_participante_id", "ds_nome_visita","data_estimada","ds_descricao"]
visitas_reordenado = visitas_filtrado[nova_ordem].rename(
    columns={
        'apelido_centro':'Estudo/Centro',
        'dados_participante_id': 'ID Participante',
        'ds_nome_visita': 'Tipo Visita',
        'data_estimada':'Data Estimada',
        'ds_descricao':'Status'
    }
)
visitas_reordenado['Data Estimada'] = pd.to_datetime(visitas_reordenado['Data Estimada'], errors='coerce')
visitas_reordenado
# Out:
#                           Estudo/Centro  ID Participante  \
# 2       SONATA-HCM - Clínica CardialMed             3287
# 3       SONATA-HCM - Clínica CardialMed             3287
# 7       SONATA-HCM - Clínica CardialMed             3287
# 8       SONATA-HCM - Clínica CardialMed             3287
# 9       SONATA-HCM - Clínica CardialMed             3287
# ...                                 ...              ...
# 1152  NATURA - SVRI Clínica Santo André             3348
# 1155  NATURA - SVRI Clínica Santo André             3362
# 1158  NATURA - SVRI Clínica Santo André             3363
# 1161  NATURA - SVRI Clínica Santo André             3364
# 1163  NATURA - SVRI Clínica Santo André             3365
#
#                                 Tipo Visita             Data Estimada  \
# 2            Visita de encerramento precoce                       NaT
# 3                               Unscheduled                       NaT
# ...

# %%
datas_visitas = visitas_reordenado.copy()
datas_visitas['Data Estimada'] = pd.to_datetime(datas_visitas['Data Estimada'], errors='coerce')
datas_visitas = visitas_reordenado.dropna(subset=["Data Estimada"])
datas_visitas = datas_visitas.sort_values(by= "Data Estimada", ascending=True)
datas_visitas = datas_visitas[~datas_visitas["Tipo Visita"].isin(["Unscheduled", "Triagem", "End of Study"])]
valores_contagem = datas_visitas['Tipo Visita'].value_counts()
datas_visitas
# Out:
#                                           Estudo/Centro  ID Participante  \
# 267                          Oxandrolona - Leforte HMCG             3333
# 282                          Oxandrolona - Leforte HMCG             3334
# 259                          Oxandrolona - Leforte HMCG             3302
# 260                          Oxandrolona - Leforte HMCG             3302
# 291                          Oxandrolona - Leforte HMCG             3355
# ...                                                 ...              ...
# 988   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...             3290
# 1032  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...             3306
# 1051  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...             3307
# 1065  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...             3309
# 1079  EASi-HF - 1378-0020 - Maternidade e Cirurgia N...             3311
#
#                                             Tipo Visita  \
# ...

# %%
def verificar_visitas_proximos_dias(datas_visitas, dias_para_visita=20):

    logger.info("Iniciando verificação de visitas futuras")

    if datas_visitas is None or datas_visitas.empty:
        logger.warning("DataFrame de visitas está vazio ou None")
        return pd.DataFrame()

    df = datas_visitas.copy()

    logger.info(f"Total de visitas recebidas: {len(df)}")

    df['Data Estimada'] = (
        pd.to_datetime(df['Data Estimada'], errors='coerce')
        .dt.tz_localize(None)
    )

    hoje = pd.Timestamp.today().normalize()
    limite_visita = hoje + pd.Timedelta(days=dias_para_visita)

    logger.info(f"Intervalo analisado: {hoje.date()} até {limite_visita.date()}")

    visitas_futuras = df[
        (df['Data Estimada'] >= hoje) &
        (df['Data Estimada'] <= limite_visita)
    ]

    logger.info(f"Visitas encontradas nos próximos {dias_para_visita} dias: {len(visitas_futuras)}")

    if visitas_futuras.empty:
        logger.info("Nenhuma visita encontrada dentro do intervalo")

    return visitas_futuras


visitas_20_dias = verificar_visitas_proximos_dias(datas_visitas, dias_para_visita=20)

logger.info(f"DataFrame final de visitas próximas possui {len(visitas_20_dias)} registros")
# Out:
# 2026-03-12 16:41:26,372 | INFO | Iniciando verificação de visitas futuras
# 2026-03-12 16:41:26,373 | INFO | Total de visitas recebidas: 453
# 2026-03-12 16:41:26,377 | INFO | Intervalo analisado: 2026-03-12 até 2026-04-01
# 2026-03-12 16:41:26,378 | INFO | Visitas encontradas nos próximos 20 dias: 47
# 2026-03-12 16:41:26,380 | INFO | DataFrame final de visitas próximas possui 47 registros

# %%
def enviar_emails_visitas(proximas_visitas):

    logger.info("Iniciando envio de email de visitas de seguimento")

    destinatarios = _parse_destinatarios(enviar_para)

    try:
        if proximas_visitas is None or proximas_visitas.empty:
            logger.info("Não há visitas nos próximos dias para enviar por e-mail.")
            return

        colunas_esperadas = ['Estudo/Centro', 'ID Participante', 'Tipo Visita', 'Data Estimada', 'Status']
        faltantes = [c for c in colunas_esperadas if c not in proximas_visitas.columns]
        if faltantes:
            logger.error(f"Colunas ausentes no DataFrame de visitas: {faltantes}")
            return

        if not all([smtp_server, email_usuario, email_senha, email_port]):
            logger.error("Configurações de e-mail estão incompletas.")
            return

        if not destinatarios:
            logger.warning("Nenhum destinatário válido para visitas. Email não enviado.")
            return

        tabela_html = proximas_visitas[colunas_esperadas].to_html(
            index=False, escape=False, justify="left", border=0, classes="table"
        )

        msg = MIMEMultipart("alternative")
        msg['From']    = email_usuario
        msg['To']      = email_usuario
        msg['Bcc']     = ', '.join(destinatarios)
        msg['Subject'] = "Visitas de Seguimento - próximos 20 dias"

        body = f"""
        <html>
            <head>{css_hover}</head>
            <body>
                <p>Olá,</p>
                <p>Segue abaixo lista com visitas de seguimento programadas para os próximos 20 dias.</p>
                {tabela_html}
                <p>Este email é gerado automaticamente a partir de informações inseridas na Polo Trial.</p>
                <p>Qualquer dúvida, por favor, contate o <strong><span style="text-decoration: underline;">time BI - SVRI</span></strong>.</p>
            </body>
        </html>
        """
        msg.attach(MIMEText(body, 'html'))

        logger.info(f"Conectando ao servidor SMTP {smtp_server}:{email_port}")

        with smtplib.SMTP(smtp_server, email_port) as server:
            server.starttls()
            server.login(email_usuario, email_senha)
            destinatarios_finais = [email_usuario] + destinatarios
            server.sendmail(email_usuario, destinatarios_finais, msg.as_string())
            logger.info("E-mail de visitas pendentes enviado com sucesso!")

    except Exception as e:
        logger.error(f"Erro ao enviar o e-mail de visitas: {e}", exc_info=True)


# Chamada da função
enviar_emails_visitas(visitas_20_dias)
# Out:
# E-mail de visitas pendentes enviado com sucesso!

# %% [markdown]
# **** Visitas de Monitoria

# %%
monitoria_df
# Out:
#           id  tipo_evento             titulo ds_co_industria       ds_co_hc  \
# 0          1            1         Centriguga
# 1          4            1        contrato V6
# 2          5            1  contrato_ Graviti
# 3          6            1  contrato_ Graviti
# 4          7            1     Vencimento GCP
# ...      ...          ...                ...             ...            ...
# 17915  41181            2   V19 - Semana 156   0761022-10016  0761022-10016
# 17916  41182            2          Semana 14   502821-100130         100130
# 17917  41183            2          Semana 16   502821-100130         100130
# 17918  41184            2              VS/V1           93-22            NaN
# 17919  41185            2              VR/V2           93-22            NaN
#
#       co_participante  tipo  status_evento             data_estimada  \
# 0                         4             20  2022-04-28T00:00:00.000Z
# ...

# %%
monitoria = monitoria_df[['dados_protocolo', 'dados_tipo', 'dados_status', 'data_estimada_filter']].copy()

monitoria.loc[:, 'dados_protocolo_id'] = monitoria['dados_protocolo'].apply(lambda x: x['id'] if x is not None else None)
monitoria.loc[:, 'apelido_protocolo'] = monitoria['dados_protocolo'].apply(lambda x: x['apelido_protocolo'] if x is not None else None)

monitoria.loc[:, 'dados_tipo_id'] = monitoria['dados_tipo'].apply(lambda x: x['id'] if x is not None else None)
monitoria.loc[:, 'dados_tipo_tipo'] = monitoria['dados_tipo'].apply(lambda x: x['tipo'] if x is not None else None)

monitoria.loc[:, 'dados_status_id'] = monitoria['dados_status'].apply(lambda x: x['id'] if x is not None else None)
monitoria.loc[:, 'ds_descricao'] = monitoria['dados_status'].apply(lambda x: x['ds_descricao'] if x is not None else None)

monitoria = monitoria.drop(['dados_protocolo','dados_status', 'dados_tipo_id','dados_status_id'], axis=1)
monitoria.rename(columns={'dados_protocolo_id': 'id'}, inplace=True)

monitoria.head(2)
# Out:
#                         dados_tipo data_estimada_filter    id  \
# 0  {'id': 4, 'tipo': 'Calibração'}           2022-04-28   NaN
# 1    {'id': 6, 'tipo': 'Contrato'}           2022-07-06  53.0
#
#   apelido_protocolo dados_tipo_tipo ds_descricao
# 0               NaN      Calibração    Realizada
# 1             Dipro        Contrato    Realizada

# %%
monitorias = pd.merge(centros, monitoria, on='id', how='inner')
monitorias
# Out:
#         id apelido_protocolo_x  numero_protocolo co_externo  \
# 0      784          SONATA-HCM  LX4211.1-314-HCM       None
# 1      784          SONATA-HCM  LX4211.1-314-HCM       None
# 2      784          SONATA-HCM  LX4211.1-314-HCM       None
# 3      784          SONATA-HCM  LX4211.1-314-HCM       None
# 4      784          SONATA-HCM  LX4211.1-314-HCM       None
# ...    ...                 ...               ...        ...
# 1239  2622              NATURA                          NaN
# 1240  2622              NATURA                          NaN
# 1241  2622              NATURA                          NaN
# 1242  2622              NATURA                          NaN
# 1243  1168          DURAVELO-2        BT8009-230       None
#
#                            apelido_centro                      dados_tipo  \
# 0         SONATA-HCM - Clínica CardialMed  {'id': 2, 'tipo': 'Monitoria'}
# 1         SONATA-HCM - Clínica CardialMed     {'id': 1, 'tipo': 'Visita'}
# ...

# %%
monitorias_filtrado = monitorias[monitorias['dados_tipo_tipo'].str.contains('Monitoria')]
monitorias_filtrado['apelido_protocolo_x'] = monitorias_filtrado['apelido_protocolo_x'].str.strip()
monitorias_filtrado
# Out:
#         id           apelido_protocolo_x  numero_protocolo co_externo  \
# 0      784                    SONATA-HCM  LX4211.1-314-HCM       None
# 50    1661                   EsSCAPE-996       BIOTEST-996       None
# 51    1661                   EsSCAPE-996       BIOTEST-996       None
# 52    1661                   EsSCAPE-996       BIOTEST-996       None
# 53    1661                   EsSCAPE-996       BIOTEST-996       None
# ...    ...                           ...               ...        ...
# 1155  1531                           DLG                       PT1531
# 1156  1531                           DLG                       PT1531
# 1187  2230  EASi-HF reduzido - 1378-0018         1378-0018        NaN
# 1188  2230  EASi-HF reduzido - 1378-0018         1378-0018        NaN
# 1243  1168                    DURAVELO-2        BT8009-230       None
#
#                                          apelido_centro  \
# 0                       SONATA-HCM - Clínica CardialMed
# ...

# %%
def verificar_monitorias_pendentes():

    logger.info("Iniciando verificação de monitorias pendentes")

    if monitorias_filtrado is None or monitorias_filtrado.empty:
        logger.warning("DataFrame monitorias_filtrado está vazio")
        return pd.DataFrame()

    df = monitorias_filtrado.copy()

    logger.info(f"Total de monitorias recebidas: {len(df)}")

    df['data_estimada_filter'] = (
        pd.to_datetime(df['data_estimada_filter'], errors='coerce')
        .dt.tz_localize(None)
    )

    hoje = pd.Timestamp.today().normalize()

    monitorias_pendentes = df[
        (df['ds_descricao'] == 'Pendente') &
        (df['data_estimada_filter'] >= hoje)
    ].sort_values('data_estimada_filter')

    logger.info(f"Monitorias pendentes encontradas: {len(monitorias_pendentes)}")

    colunas_monitoria = [
        'dados_tipo_tipo',
        'data_estimada_filter',
        'apelido_protocolo_x',
        'ds_descricao',
        'apelido_centro'
    ]

    if monitorias_pendentes.empty:

        logger.info("Nenhuma monitoria pendente encontrada")

    else:

        logger.info(
            "\nMonitorias pendentes:\n%s",
            monitorias_pendentes[colunas_monitoria]
        )

    return monitorias_pendentes

# %%
# envio_para já foi definido na célula de variáveis de email (Cell 25)
logger.info(f"Destinatário monitoria configurado: {'sim' if envio_para else 'não'}")

# %%
monitorias_pendentes = verificar_monitorias_pendentes()
monitorias_pendentes.rename(columns={'apelido_centro':'Estudo/Centro', 'dados_tipo_tipo': 'Monitoria', 'data_estimada_filter': 'Data Estimada','ds_descricao': 'Status'}, inplace=True)
monitorias_pendentes
# Out:
# 2026-03-12 16:41:27,217 | INFO | Iniciando verificação de monitorias pendentes
# 2026-03-12 16:41:27,217 | INFO | Total de monitorias recebidas: 80
# 2026-03-12 16:41:27,217 | INFO | Monitorias pendentes encontradas: 5
# 2026-03-12 16:41:27,217 | INFO |
# Monitorias pendentes:
#      dados_tipo_tipo data_estimada_filter           apelido_protocolo_x  \
# 342        Monitoria           2026-03-13               LIBREXIA-STROKE
# 1188       Monitoria           2026-03-20  EASi-HF reduzido - 1378-0018
# 59         Monitoria           2026-03-31                   EsSCAPE-996
# 743        Monitoria           2026-04-06           EASi-HF - 1378-0020
# 343        Monitoria           2026-04-09               LIBREXIA-STROKE
#
#      ds_descricao                                     apelido_centro
# 342      Pendente  LIBREXIA-STROKE - Maternidade e Cirurgia Nossa...
# 1188     Pendente  EASi-HF reduzido - 1378-0018 - Maternidade e C...
# ...

# %%
monitoria_envio = monitorias_pendentes.drop(columns=['apelido_protocolo_x', 'co_externo', 'dados_tipo', 'apelido_protocolo_y'],errors='ignore')

monitoria_envio = monitoria_envio[
    [
        'Monitoria',
        'id',
        'numero_protocolo',
        'Estudo/Centro',
        'Data Estimada',
        'Status'
    ]
]
monitoria_envio
# Out:
#       Monitoria    id numero_protocolo  \
# 342   Monitoria   169  70033093STR3001
# 1188  Monitoria  2230        1378-0018
# 59    Monitoria  1661      BIOTEST-996
# 743   Monitoria   655        1378-0020
# 343   Monitoria   169  70033093STR3001
#
#                                           Estudo/Centro Data Estimada  \
# 342   LIBREXIA-STROKE - Maternidade e Cirurgia Nossa...    2026-03-13
# 1188  EASi-HF reduzido - 1378-0018 - Maternidade e C...    2026-03-20
# 59    EsSCAPE-996 - Maternidade e Cirurgia Nossa Sen...    2026-03-31
# 743   EASi-HF - 1378-0020 - Maternidade e Cirurgia N...    2026-04-06
# 343   LIBREXIA-STROKE - Maternidade e Cirurgia Nossa...    2026-04-09
#
#         Status
# 342   Pendente
# 1188  Pendente
# 59    Pendente
# 743   Pendente
# 343   Pendente

# %%
def enviar_emails_monitoria(monitoria_envio):

    logger.info("Iniciando rotina de envio de emails de monitoria")

    destinatarios = _parse_destinatarios(envio_para)

    try:
        if monitoria_envio is None or monitoria_envio.empty:
            logger.info("Não há monitorias pendentes para envio de email")
            return

        logger.info(f"Total de monitorias recebidas para envio: {len(monitoria_envio)}")

        colunas = ['Estudo/Centro', 'Monitoria', 'Data Estimada', 'Status']

        logger.info(f"Colunas do dataframe recebido: {monitoria_envio.columns.tolist()}")

        faltantes = [c for c in colunas if c not in monitoria_envio.columns]
        if faltantes:
            logger.error(f"Colunas ausentes no DataFrame de monitoria: {faltantes}")
            return

        tabela_html = monitoria_envio[colunas].to_html(
            index=False,
            escape=False,
            justify="left",
            border=0,
            classes="table"
        )

        logger.info("Tabela HTML de monitorias gerada")

        msg = MIMEMultipart("alternative")
        msg['From']    = email_usuario
        msg['To']      = email_usuario
        msg['Subject'] = "Visitas de Monitoria Pendentes"

        if not destinatarios:
            logger.warning("Nenhum destinatário válido para monitoria. Email não enviado.")
            return

        msg['Bcc'] = ', '.join(destinatarios)
        logger.info(f"Destinatários BCC: {destinatarios}")

        destinatarios_finais = [email_usuario] + destinatarios
        logger.info(f"Lista final de destinatários: {destinatarios_finais}")

        body = f"""
        <html>
            <head>{css_hover}</head>
            <body>
                <p>Olá,</p>
                <p>
                Segue abaixo lista com visitas de monitoria programadas
                para os próximos dias.
                </p>
                {tabela_html}
                <p>
                Este email é gerado automaticamente a partir de
                informações inseridas na Polo Trial.
                </p>
                <p>
                Qualquer dúvida, por favor, contate o
                <strong><span style="text-decoration: underline;">
                time BI - SVRI
                </span></strong>.
                </p>
            </body>
        </html>
        """

        msg.attach(MIMEText(body, 'html'))

        logger.info("Corpo do email criado")
        logger.info(f"Conectando ao servidor SMTP: {smtp_server}:{email_port}")

        with smtplib.SMTP(smtp_server, email_port) as server:
            server.starttls()
            logger.info("TLS iniciado")
            server.login(email_usuario, email_senha)
            logger.info("Login SMTP realizado")
            server.sendmail(email_usuario, destinatarios_finais, msg.as_string())
            logger.info("Email de monitoria enviado com sucesso")

    except Exception as e:
        logger.error(
            f"Erro ao enviar email de monitoria: {str(e)}",
            exc_info=True
        )


# chamada
enviar_emails_monitoria(monitoria_envio)
# Out:
# 2026-03-12 16:41:27,276 | INFO | Iniciando rotina de envio de emails de monitoria
# 2026-03-12 16:41:27,277 | INFO | Total de monitorias recebidas para envio: 5
# 2026-03-12 16:41:27,277 | INFO | Colunas do dataframe recebido: ['Monitoria', 'id', 'numero_protocolo', 'Estudo/Centro', 'Data Estimada', 'Status']
# 2026-03-12 16:41:27,282 | INFO | Tabela HTML de monitorias gerada
# 2026-03-12 16:41:27,283 | WARNING | Variável envio_para não é lista. Nenhum destinatário definido.
# 2026-03-12 16:41:27,283 | INFO | Lista final de destinatários: ['gleice.barros@svriglobal.com']
# 2026-03-12 16:41:27,284 | INFO | Corpo do email criado
# 2026-03-12 16:41:27,285 | INFO | Conectando ao servidor SMTP: smtp.office365.com:587
# 2026-03-12 16:41:27,312 | INFO | TLS iniciado
# 2026-03-12 16:41:27,563 | INFO | Login SMTP realizado
# 2026-03-12 16:41:27,846 | INFO | Email de monitoria enviado com sucesso
